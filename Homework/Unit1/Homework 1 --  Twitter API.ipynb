# %% [markdown]
# ## Homework 1: Advanced Track -- Harvest the Twitter API

# %% [markdown]
# **Objective:** Write a series of functions that allow you to dynamically harvest Twitter data.
#
# **Estimated Time to Complete:** 4-12 hours
#
# #### Sections
#
#  - **Section 1:** Setting up your developer account, using OAuth1 authentication (approx 45-120 minutes)
#  - **Sections 2 & 3:** Navigating the API documentation, getting your first query strings (approx 45-120 minutes)
#  - **Section 3:** Writing your API calls (approx 90 - 360 minutes)
#
# #### What You'll Turn In:
#  - A `.py` (not a Notebook!) file that contains the functions that you were prompted to create.  These should contain comments demonstrating why your code does what it does, and after it's run, the instructor should be able to make the appropriate function calls in Spyder or any other IDE.

# %% [markdown]
# ## Section 1:  Setting Up Your Developer Account

# %% [markdown]
# Most API's require you to do a little pre-work in order to be able to use them, so the first part of this homework assignment will be spent setting up your developer account so you have API Access.

# %% [markdown]
# **Step 1:  Create a Twitter Developer Account**
#
#  - Make sure you have a regular twitter account before you do this
#  - You can apply for a developer account here:  https://developer.twitter.com/en/apply-for-access
#   - Choose either a student or hobbyist/personal account
#   - **note:** these typically get approved right away, but it's possible you might have to wait a little bit......if 15 minutes pass, it might be best to take a break and come back in an hour or so.

# %% [markdown]
# **Step 2:  Create An App**
#
# You don't have to intend to build an official software program to have an app.....this is just a way for you to get authentication keys to use with the API.
#
#  - Go to the menu in the upper right hand corner and click on **Your Name** > **Apps**
#  - Choose **Create An App**
#  - You'll be prompted to enter some information about your app.  Don't worry too much about this, it can say almost anything.  You'll be prompted to list websites where it will be hosted...this can be anything for now.  Use https://generalassemb.ly if you're undecided about what to put.

# %% [markdown]
# **Step 3: Create Your API Tokens**
#
# Now that you have an app, you can use its API tokens to go ahead and make requests like we did in class 3.  Like a lot of API's, the Twitter API uses something called OAuth authentication.
#
# If you didn't wait until the night before this assignment was due and have a spare 30 minutes, you can read a little about it here: https://oauth.net/
#
# In any event, you need API tokens in order to make requests.  Do the following:
#
#  - Go to the **Apps** section of your developer portal
#  - Click on the **Details** button for the app that you just created
#  - Click on the **Keys & Tokens** tab:
#    - Two keys should already be given to you:  **API Key** & **API Secret Key**
#    - Two you have to generate:  **Access token** & **Access token secret**
#  - Generate your Access Token and Access Token Secret keys.  You'll need to write these down when you're done -- you can only see them once.
#
# Now you're ready to make requests to the Twitter api.  Everytime you make a request, you'll need to include the 4 tokens you just created.  (You can always regenerate them for whatever reason).

# %% [markdown]
# **Step 4:  Your First Request**
#
# To make requests to the Twitter API you're going to need a module which is **not** already pre-installed in Anaconda. You'll need to install it via PIP, which is python's package manager.  It's called `requests_oauthlib`.  You can install this via Anaconda Prompt or Terminal by simply typing in the command `pip install requests_oauthlib`, and then you'll be finished.
#
# The logistics of making an OAuth1 authenticated request are very similar to what was done in class 3, but with a few additional steps.  You can see how to do it here:  https://requests.readthedocs.io/en/master/user/authentication/#oauth-1-authentication.  The only thing you'll need to change is the info for your API tokens that are passed into the `OAuth1()` function.
#
# Try making a request to the following URL to confirm that you have things set up correctly: 'https://api.twitter.com/1.1/account/verify_credentials.json'

# %%
# your code here
import requests
from requests_oauthlib import OAuth1
url ='https://api.twitter.com/1.1/account/verify_credentials.json'
auth = OAuth1('DeWbsfI9l3XhzARsLTo1kHYFL','m6JkY76aQv7zgJaApxz9IitfgfnlKCRo1cIkaqK3zqbQanDKk4', '1291070701408002050-ft6VvAOaqSvW77CEr5kWN6NzyHavPy','hXS9DBpTuFXnXwODPfgoPnjNSXcRKmWVqFG72uPXjthlu')

requests.get(url,auth=auth)
# Out:
# <Response [200]>

# %% [markdown]
# If you get your json object back, then you're good to go.

# %% [markdown]
# ## Section 2: Searching Tweets

# %% [markdown]
# Most websites you access will have a long string attached to the end of them that look something like this:  `http://thewebsite.com/?year=2019&color=golden%20yellow&user_id=48549395959438`.
#
# Most people have no reason to pay attention to any of this, but all the special symbols at the end are basically encoded commands that say 'return a website that displays x,y,z characteristics.'
#
# When accessing api data, it basically works the same way.

# %% [markdown]
# **Step 1:  Set Up Your First Query String**

# %% [markdown]
# If you go into Twitter and search for the term `Data Science`, you should be brought to a url that looks like this:  `https://twitter.com/search?q=Data%20Science&src=typed_query`
#
# If you'd like, you can drop the `&src=typed_query` from the url and still get the same results.
#
# There are some important details to pay attention to:
#
#  - Like class 3 when we worked with GitHub, there is a **base url**.  In this case it's `https://twitter.com/search`
#  - Whenever you enter a search for something, the base url will be followed by something that looks like `?q=My%20Search%20Term`
#   - The `?` marks the beginning of the query string.  This basically says 'initiate a request with whatever parameters that follow'
#   - The `q` is a **parameter**, essentially some condition to pass into the query string that determines what results will be given back to you.  In this case, `q` encodes the text you typed in into something the API can understand.
#
# **Useful Thing To Do Right Now:** Go back to the Twitter search page, and just try searching for different things, and notice what shows up after the `q=`.  Here are some questions to ask yourself:
#
#  - How are white spaces encoded?  Ie, if you search for `Jonathan Bechtel` in the search box, what shows up to account for the space between the two words?
#  - What about hash symbols?  If you search for `#MeToo`, `#GirlsWhoCode` or `#DataScience`, what happens with that `#` symbol?
#  - Once you get the hang of this, see if you can just re-create some searches yourself by creating the url directly, and bypassing the search box altogether.  Ie, be familiar enough with how searches are formatted that you know `https://twitter.com/search?q=%23DataScience` will take you to the same page as typing in `#DataScience` into the search box.
#
# Now, let's try and make a request for a search for `Data Science`.
#
# If you look at Twitter's docs, you'll see that the base url for the search API is `'https://api.twitter.com/1.1/search/tweets.json`
#
# This means you have to add the `?q=Whatever%20Word%20%Goes%20Here` to the end to complete the search.
#
# So go ahead, and see if you can create your API call for a search for the term `Data Science`.
#
# If you did it correctly, you should have a dictionary with a key called `statuses`, and it'll be a list with all of the tweets returned by your search.

# %%
# your answer here
url ='https://api.twitter.com/1.1/search/tweets.json?q=data%20science'
datascience=requests.get(url,auth=auth)

# %%
datascience.json()
# Out:
# {'statuses': [{'created_at': 'Mon Aug 10 14:23:55 +0000 2020',
#    'id': 1292829032401317889,
#    'id_str': '1292829032401317889',
#    'text': 'Indeed! My course sequence would be: algebra I-&gt; algebra II -&gt; statistics -&gt; data science https://t.co/GZ5kXuhRT9',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/GZ5kXuhRT9',
#       'expanded_url': 'https://twitter.com/austen/status/1292608488367984640',
#       'display_url': 'twitter.com/austen/status/…',
#       'indices': [99, 122]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 841280011164368897,
#     'id_str': '841280011164368897',
#     'name': 'Angela',
#     'screen_name': 'wokeSTEMteacher',
#     'location': 'Chicago, IL',
#     'description': 'HS Statistics Teacher 👩🏾\u200d🏫 MEd 💁🏾\u200d♀️ EdD Candidate 🎓 Your Favorite Teacher. She/Her/Hers. $AngMc',
#     'url': 'https://t.co/5TGUJKpYrE',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/5TGUJKpYrE',
#         'expanded_url': 'http://www.thewokestemteacher.com',
#         'display_url': 'thewokestemteacher.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4583,
#     'friends_count': 1063,
#     'listed_count': 23,
#     'created_at': 'Mon Mar 13 13:29:19 +0000 2017',
#     'favourites_count': 2298,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2101,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1279984081812545536/N1eZqt0G_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1279984081812545536/N1eZqt0G_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/841280011164368897/1590950149',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1292608488367984640,
#    'quoted_status_id_str': '1292608488367984640',
#    'quoted_status': {'created_at': 'Sun Aug 09 23:47:33 +0000 2020',
#     'id': 1292608488367984640,
#     'id_str': '1292608488367984640',
#     'text': 'The default math class in high school should be Statistics instead of Calculus',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 221838349,
#      'id_str': '221838349',
#      'name': 'Austen Allred',
#      'screen_name': 'Austen',
#      'location': 'The Oasis',
#      'description': 'CEO @LambdaSchool: A CS education with no tuition until you get a job. I have seen the “Memes” and I think they’re very good.',
#      'url': 'https://t.co/SIpIDfqvn4',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/SIpIDfqvn4',
#          'expanded_url': 'http://austenallred.com',
#          'display_url': 'austenallred.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 135739,
#      'friends_count': 608,
#      'listed_count': 2607,
#      'created_at': 'Wed Dec 01 19:13:23 +0000 2010',
#      'favourites_count': 55866,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 16039,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '1A1B1F',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1265419985721020416/PkdGqjLq_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1265419985721020416/PkdGqjLq_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/221838349/1408222178',
#      'profile_link_color': '2FC2EF',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': '252429',
#      'profile_text_color': '666666',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'regular'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2004,
#     'favorite_count': 19929,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Mon Aug 10 14:23:55 +0000 2020',
#    'id': 1292829031855882240,
#    'id_str': '1292829031855882240',
#    'text': 'RT @gp_pulipaka: 13 Python #DataScience and #MachineLearning Libraries You Need to Know. #BigData #Analytics #AI #IoT #IIoT #Python #RStats…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DataScience', 'indices': [27, 39]},
#      {'text': 'MachineLearning', 'indices': [44, 60]},
#      {'text': 'BigData', 'indices': [89, 97]},
#      {'text': 'Analytics', 'indices': [98, 108]},
#      {'text': 'AI', 'indices': [109, 112]},
#      {'text': 'IoT', 'indices': [113, 117]},
#      {'text': 'IIoT', 'indices': [118, 123]},
#      {'text': 'Python', 'indices': [124, 131]},
#      {'text': 'RStats', 'indices': [132, 139]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'gp_pulipaka',
#       'name': 'Dr. Ganapathi Pulipaka',
#       'id': 4263007693,
#       'id_str': '4263007693',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 839455937161277440,
#     'id_str': '839455937161277440',
#     'name': 'Ronit Chawla',
#     'screen_name': 'ronit_chawla21',
#     'location': '',
#     'description': 'Berkeley 🐻💛💙\n\nig : @ronit_chawla21\n\n👨\u200d💻    👨\u200d🍳    🍨    👟    ☕',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 17,
#     'friends_count': 58,
#     'listed_count': 0,
#     'created_at': 'Wed Mar 08 12:41:06 +0000 2017',
#     'favourites_count': 180,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 125,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1290055541222330368/Rj7-zwMI_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1290055541222330368/Rj7-zwMI_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/839455937161277440/1596230478',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 20:10:27 +0000 2020',
#     'id': 1292553854022758400,
#     'id_str': '1292553854022758400',
#     'text': '13 Python #DataScience and #MachineLearning Libraries You Need to Know. #BigData #Analytics #AI #IoT #IIoT #Python… https://t.co/3ntxbyFc8s',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'DataScience', 'indices': [10, 22]},
#       {'text': 'MachineLearning', 'indices': [27, 43]},
#       {'text': 'BigData', 'indices': [72, 80]},
#       {'text': 'Analytics', 'indices': [81, 91]},
#       {'text': 'AI', 'indices': [92, 95]},
#       {'text': 'IoT', 'indices': [96, 100]},
#       {'text': 'IIoT', 'indices': [101, 106]},
#       {'text': 'Python', 'indices': [107, 114]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/3ntxbyFc8s',
#        'expanded_url': 'https://twitter.com/i/web/status/1292553854022758400',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 4263007693,
#      'id_str': '4263007693',
#      'name': 'Dr. Ganapathi Pulipaka',
#      'screen_name': 'gp_pulipaka',
#      'location': 'Redondo Beach, CA',
#      'description': 'Chief AI HPC Scientist | Global Premier Speaker | PostDoc CS, PhD | Bestselling Author | 18.4M Views Per Month | Top Data Science, IIoT Influencer @Onalytica',
#      'url': 'https://t.co/eYyaJsEcfw',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/eYyaJsEcfw',
#          'expanded_url': 'http://www.gppulipaka.org',
#          'display_url': 'gppulipaka.org',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 94557,
#      'friends_count': 26912,
#      'listed_count': 3439,
#      'created_at': 'Tue Nov 17 02:19:09 +0000 2015',
#      'favourites_count': 9,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 57284,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/998301258413850625/9BZwTjgv_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/998301258413850625/9BZwTjgv_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4263007693/1583526136',
#      'profile_link_color': 'DD2E44',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 141,
#     'favorite_count': 131,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 141,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Mon Aug 10 14:23:51 +0000 2020',
#    'id': 1292829015561179137,
#    'id_str': '1292829015561179137',
#    'text': "RT @DataKindUK: Just a couple of days until our #DataScience #Ethics book club about 'Data and Social Change Movements' - time to get readi…",
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DataScience', 'indices': [48, 60]},
#      {'text': 'Ethics', 'indices': [61, 68]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'DataKindUK',
#       'name': 'DataKind UK',
#       'id': 1096083931,
#       'id_str': '1096083931',
#       'indices': [3, 14]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 835940588,
#     'id_str': '835940588',
#     'name': 'نظرة',
#     'screen_name': 'view10001',
#     'location': 'United Arab Emirates  إماراتية',
#     'description': '\u200f\u200fبشر\npeople',
#     'url': 'https://t.co/aZ4RpDmwO4',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/aZ4RpDmwO4',
#         'expanded_url': 'http://bit.ly/3d1peYn',
#         'display_url': 'bit.ly/3d1peYn',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1126,
#     'friends_count': 4246,
#     'listed_count': 230,
#     'created_at': 'Thu Sep 20 16:49:59 +0000 2012',
#     'favourites_count': 45847,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 44960,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '1A1B1F',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1272244491873914880/twTJFpxh_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1272244491873914880/twTJFpxh_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/835940588/1592161701',
#     'profile_link_color': 'F58EA8',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Mon Aug 10 14:20:17 +0000 2020',
#     'id': 1292828116990263304,
#     'id_str': '1292828116990263304',
#     'text': "Just a couple of days until our #DataScience #Ethics book club about 'Data and Social Change Movements' - time to g… https://t.co/t2xIqisloV",
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'DataScience', 'indices': [32, 44]},
#       {'text': 'Ethics', 'indices': [45, 52]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/t2xIqisloV',
#        'expanded_url': 'https://twitter.com/i/web/status/1292828116990263304',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1096083931,
#      'id_str': '1096083931',
#      'name': 'DataKind UK',
#      'screen_name': 'DataKindUK',
#      'location': 'UK',
#      'description': 'UK charity using data in the service of the greater good. We are the UK chapter of @DataKind',
#      'url': 'https://t.co/DhYOBfOtQJ',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/DhYOBfOtQJ',
#          'expanded_url': 'https://www.datakind.org.uk',
#          'display_url': 'datakind.org.uk',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 6757,
#      'friends_count': 1155,
#      'listed_count': 270,
#      'created_at': 'Wed Jan 16 19:08:51 +0000 2013',
#      'favourites_count': 3238,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 3876,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'FF921A',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/501380524942716929/Vo2Qm8id_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/501380524942716929/Vo2Qm8id_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1096083931/1402374636',
#      'profile_link_color': 'FF921A',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Mon Aug 10 14:23:50 +0000 2020',
#    'id': 1292829011295580160,
#    'id_str': '1292829011295580160',
#    'text': 'RT @ScullionToni: Honoured to be part of this amazing initiative  by @InfAtEd 👩\u200d🏫💻Ctrl Alt Teach: promoting computer science teaching caree…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ScullionToni',
#       'name': 'Toni Scullion',
#       'id': 816134192,
#       'id_str': '816134192',
#       'indices': [3, 16]},
#      {'screen_name': 'InfAtEd',
#       'name': 'InformaticsEdinburgh',
#       'id': 90873580,
#       'id_str': '90873580',
#       'indices': [69, 77]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1135499812437135360,
#     'id_str': '1135499812437135360',
#     'name': 'Data Education In Schools',
#     'screen_name': 'data_schools',
#     'location': 'Edinburgh, Scotland',
#     'description': 'Developing data science education programs for Scotland as part of Edinburgh City Region Deal #dataschools',
#     'url': 'https://t.co/YZT0ZXuqRR',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/YZT0ZXuqRR',
#         'expanded_url': 'https://www.de.ed.ac.uk/project/data-education-schools',
#         'display_url': 'de.ed.ac.uk/project/data-e…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 394,
#     'friends_count': 628,
#     'listed_count': 1,
#     'created_at': 'Mon Jun 03 10:53:46 +0000 2019',
#     'favourites_count': 126,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 294,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1191735958703607808/xwCFZ1nT_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1191735958703607808/xwCFZ1nT_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1135499812437135360/1571240973',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 20:41:32 +0000 2020',
#     'id': 1292561676466823168,
#     'id_str': '1292561676466823168',
#     'text': 'Honoured to be part of this amazing initiative  by @InfAtEd 👩\u200d🏫💻Ctrl Alt Teach: promoting computer science teaching… https://t.co/Ymf9fUntYZ',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'InfAtEd',
#        'name': 'InformaticsEdinburgh',
#        'id': 90873580,
#        'id_str': '90873580',
#        'indices': [51, 59]}],
#      'urls': [{'url': 'https://t.co/Ymf9fUntYZ',
#        'expanded_url': 'https://twitter.com/i/web/status/1292561676466823168',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 816134192,
#      'id_str': '816134192',
#      'name': 'Toni Scullion',
#      'screen_name': 'ScullionToni',
#      'location': 'Glasgow',
#      'description': 'Aspiring to make a dent in the Computing Science gender gap in Scotland; aiming to inspire, support and engage pupils.',
#      'url': 'https://t.co/NCRpU2E7mx',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/NCRpU2E7mx',
#          'expanded_url': 'https://www.linkedin.com/in/toni-scullion',
#          'display_url': 'linkedin.com/in/toni-sculli…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1719,
#      'friends_count': 2118,
#      'listed_count': 9,
#      'created_at': 'Mon Sep 10 22:12:01 +0000 2012',
#      'favourites_count': 6243,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 1844,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1088892631709560839/2W2wInfq_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1088892631709560839/2W2wInfq_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/816134192/1548447342',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 5,
#     'favorite_count': 8,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': True,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 5,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Mon Aug 10 14:23:49 +0000 2020',
#    'id': 1292829007218708480,
#    'id_str': '1292829007218708480',
#    'text': 'RT @arn_rafael: Free Data Science #ebooks \n🚀🚀🚀🚀💻💻💻💻\n\n#AI #future #innovation #technology #DataScience #pythonprogramming #Data https://t.co…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'ebooks', 'indices': [34, 41]},
#      {'text': 'AI', 'indices': [53, 56]},
#      {'text': 'future', 'indices': [57, 64]},
#      {'text': 'innovation', 'indices': [65, 76]},
#      {'text': 'technology', 'indices': [77, 88]},
#      {'text': 'DataScience', 'indices': [89, 101]},
#      {'text': 'pythonprogramming', 'indices': [102, 120]},
#      {'text': 'Data', 'indices': [121, 126]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'arn_rafael',
#       'name': 'Rafael Arn',
#       'id': 2158275842,
#       'id_str': '2158275842',
#       'indices': [3, 14]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://addempsea.wordpress.com" rel="nofollow">Twitter for addempsea</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1196874000837816320,
#     'id_str': '1196874000837816320',
#     'name': 'quotesBot',
#     'screen_name': 'nodeQuotesBot',
#     'location': '',
#     'description': 'I am a bot made by @_addempsea  with #nodejs. I post quotes every hour and I retweet #js #javascript and #rustlang post. Kindly follow me',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 994,
#     'friends_count': 1,
#     'listed_count': 33,
#     'created_at': 'Tue Nov 19 19:33:16 +0000 2019',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 152523,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1272605555497078785/WLzdWQ-o_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1272605555497078785/WLzdWQ-o_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1196874000837816320/1577825239',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Mon Aug 10 13:55:42 +0000 2020',
#     'id': 1292821931146776577,
#     'id_str': '1292821931146776577',
#     'text': 'Free Data Science #ebooks \n🚀🚀🚀🚀💻💻💻💻\n\n#AI #future #innovation #technology #DataScience #pythonprogramming #Data https://t.co/WyWA5rkBDd',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'ebooks', 'indices': [18, 25]},
#       {'text': 'AI', 'indices': [37, 40]},
#       {'text': 'future', 'indices': [41, 48]},
#       {'text': 'innovation', 'indices': [49, 60]},
#       {'text': 'technology', 'indices': [61, 72]},
#       {'text': 'DataScience', 'indices': [73, 85]},
#       {'text': 'pythonprogramming', 'indices': [86, 104]},
#       {'text': 'Data', 'indices': [105, 110]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/WyWA5rkBDd',
#        'expanded_url': 'https://twitter.com/theinsaneapp/status/1292385281312661506',
#        'display_url': 'twitter.com/theinsaneapp/s…',
#        'indices': [111, 134]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 2158275842,
#      'id_str': '2158275842',
#      'name': 'Rafael Arn',
#      'screen_name': 'arn_rafael',
#      'location': 'Thun, Switzerland',
#      'description': 'Interested in 🔮 #future | 🚀 #innovation | 🤖 #technology and 💻 #newwork | Works at @swisspost | Inspired by 🎧 #podcast | and try to get started with #python',
#      'url': 'https://t.co/dQ5qsKkUWF',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/dQ5qsKkUWF',
#          'expanded_url': 'http://www.linkedin.com/in/rafael-arn',
#          'display_url': 'linkedin.com/in/rafael-arn',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 86,
#      'friends_count': 392,
#      'listed_count': 9,
#      'created_at': 'Sun Oct 27 06:56:02 +0000 2013',
#      'favourites_count': 803,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 539,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/902086773119045633/MsHth4TL_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/902086773119045633/MsHth4TL_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2158275842/1596572631',
#      'profile_link_color': 'ABB8C2',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': {'id': 'bc7894d10c829746',
#      'url': 'https://api.twitter.com/1.1/geo/id/bc7894d10c829746.json',
#      'place_type': 'city',
#      'name': 'Ostermundigen',
#      'full_name': 'Ostermundigen, Schweiz',
#      'country_code': 'CH',
#      'country': 'Switzerland',
#      'contained_within': [],
#      'bounding_box': {'type': 'Polygon',
#       'coordinates': [[[7.4766007, 46.9402698],
#         [7.5132487, 46.9402698],
#         [7.5132487, 46.9716424],
#         [7.4766007, 46.9716424]]]},
#      'attributes': {}},
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1292385281312661506,
#     'quoted_status_id_str': '1292385281312661506',
#     'quoted_status': {'created_at': 'Sun Aug 09 09:00:37 +0000 2020',
#      'id': 1292385281312661506,
#      'id_str': '1292385281312661506',
#      'text': '20 Free Data Science eBooks - Must Check\n\nList Of Books: https://t.co/OxfeoHLvgB\n\n#theinsaneapp #ML #AI… https://t.co/Oo24YwxcSu',
#      'truncated': True,
#      'entities': {'hashtags': [{'text': 'theinsaneapp', 'indices': [82, 95]},
#        {'text': 'ML', 'indices': [96, 99]},
#        {'text': 'AI', 'indices': [100, 103]}],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/OxfeoHLvgB',
#         'expanded_url': 'https://www.theinsaneapp.com/2020/08/20-free-data-science-ebooks.html',
#         'display_url': 'theinsaneapp.com/2020/08/20-fre…',
#         'indices': [57, 80]},
#        {'url': 'https://t.co/Oo24YwxcSu',
#         'expanded_url': 'https://twitter.com/i/web/status/1292385281312661506',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [105, 128]}]},
#      'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#      'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'user': {'id': 1064407014472744960,
#       'id_str': '1064407014472744960',
#       'name': 'Insane',
#       'screen_name': 'TheInsaneApp',
#       'location': '',
#       'description': 'Feed your curiosity with Facts, Stories, and Summaries! Proudly followed by @MIT_CSAIL',
#       'url': 'https://t.co/UNantImjGP',
#       'entities': {'url': {'urls': [{'url': 'https://t.co/UNantImjGP',
#           'expanded_url': 'http://tryinsane.page.link/TheInsaneApp',
#           'display_url': 'tryinsane.page.link/TheInsaneApp',
#           'indices': [0, 23]}]},
#        'description': {'urls': []}},
#       'protected': False,
#       'followers_count': 8966,
#       'friends_count': 78,
#       'listed_count': 79,
#       'created_at': 'Mon Nov 19 06:36:22 +0000 2018',
#       'favourites_count': 6716,
#       'utc_offset': None,
#       'time_zone': None,
#       'geo_enabled': False,
#       'verified': False,
#       'statuses_count': 1620,
#       'lang': None,
#       'contributors_enabled': False,
#       'is_translator': False,
#       'is_translation_enabled': False,
#       'profile_background_color': 'F5F8FA',
#       'profile_background_image_url': None,
#       'profile_background_image_url_https': None,
#       'profile_background_tile': False,
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/1211253505916166147/ge8jiGt7_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1211253505916166147/ge8jiGt7_normal.jpg',
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1064407014472744960/1585860005',
#       'profile_link_color': '1DA1F2',
#       'profile_sidebar_border_color': 'C0DEED',
#       'profile_sidebar_fill_color': 'DDEEF6',
#       'profile_text_color': '333333',
#       'profile_use_background_image': True,
#       'has_extended_profile': False,
#       'default_profile': True,
#       'default_profile_image': False,
#       'following': False,
#       'follow_request_sent': False,
#       'notifications': False,
#       'translator_type': 'none'},
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 102,
#      'favorite_count': 71,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'retweet_count': 12,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': True,
#    'quoted_status_id': 1292385281312661506,
#    'quoted_status_id_str': '1292385281312661506',
#    'retweet_count': 12,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Mon Aug 10 14:23:45 +0000 2020',
#    'id': 1292828988507852802,
#    'id_str': '1292828988507852802',
#    'text': 'Join us on Discord!\n\nAsk your data science and research software engineering questions. \n\nWe also use the channel f… https://t.co/MFIv9T0UQs',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/MFIv9T0UQs',
#       'expanded_url': 'https://twitter.com/i/web/status/1292828988507852802',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1039560985705701381,
#     'id_str': '1039560985705701381',
#     'name': 'Natalie Thurlby',
#     'screen_name': 'StatalieT',
#     'location': 'Bristol, England',
#     'description': 'Data Scientist @JGIBristol.    \nComp-bio👩\u200d💻🧬.   \nReproducibility✨.     \nData-viz📊.    \nPython🐍.  \nDigital humanities📚.\nSea shanty band ⚓️🧜\u200d♀️🍻. \nFriend to 🐢.',
#     'url': 'https://t.co/t5gjOUXfsP',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/t5gjOUXfsP',
#         'expanded_url': 'https://jean-golding-institute.github.io/maps/',
#         'display_url': 'jean-golding-institute.github.io/maps/',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 214,
#     'friends_count': 275,
#     'listed_count': 1,
#     'created_at': 'Tue Sep 11 17:07:07 +0000 2018',
#     'favourites_count': 576,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 296,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1039586347714072576/EyfkU89O_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1039586347714072576/EyfkU89O_normal.jpg',
#     'profile_link_color': '7FDBB6',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1292801150920646657,
#    'quoted_status_id_str': '1292801150920646657',
#    'quoted_status': {'created_at': 'Mon Aug 10 12:33:08 +0000 2020',
#     'id': 1292801150920646657,
#     'id_str': '1292801150920646657',
#     'text': 'New communication channel for Data Science &amp; Research Computing! https://t.co/9VzPwAfJVC @JGIBristol… https://t.co/15aj4v8CBG',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'JGIBristol',
#        'name': 'JGI Bristol',
#        'id': 789119554190540800,
#        'id_str': '789119554190540800',
#        'indices': [93, 104]}],
#      'urls': [{'url': 'https://t.co/9VzPwAfJVC',
#        'expanded_url': 'https://mailchi.mp/3a1cd6561509/new-communication-channel-for-data-science-research-computing',
#        'display_url': 'mailchi.mp/3a1cd6561509/n…',
#        'indices': [69, 92]},
#       {'url': 'https://t.co/15aj4v8CBG',
#        'expanded_url': 'https://twitter.com/i/web/status/1292801150920646657',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [106, 129]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 789119554190540800,
#      'id_str': '789119554190540800',
#      'name': 'JGI Bristol',
#      'screen_name': 'JGIBristol',
#      'location': 'Bristol, England',
#      'description': 'Jean Golding Institute for data intensive research at the University of Bristol, England, UK. Making data work for everyone. #datascience #AI #Bristol',
#      'url': 'https://t.co/DnutfUpDSU',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/DnutfUpDSU',
#          'expanded_url': 'http://www.bristol.ac.uk/golding/',
#          'display_url': 'bristol.ac.uk/golding/',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1569,
#      'friends_count': 2087,
#      'listed_count': 20,
#      'created_at': 'Thu Oct 20 15:02:17 +0000 2016',
#      'favourites_count': 3103,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 3456,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1273563508186271746/6YGjzp4U_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1273563508186271746/6YGjzp4U_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/789119554190540800/1559138157',
#      'profile_link_color': '981CEB',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 5,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Mon Aug 10 14:23:43 +0000 2020',
#    'id': 1292828980492419074,
#    'id_str': '1292828980492419074',
#    'text': 'RT @arn_rafael: Free Data Science #ebooks \n🚀🚀🚀🚀💻💻💻💻\n\n#AI #future #innovation #technology #DataScience #pythonprogramming #Data https://t.co…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'ebooks', 'indices': [34, 41]},
#      {'text': 'AI', 'indices': [53, 56]},
#      {'text': 'future', 'indices': [57, 64]},
#      {'text': 'innovation', 'indices': [65, 76]},
#      {'text': 'technology', 'indices': [77, 88]},
#      {'text': 'DataScience', 'indices': [89, 101]},
#      {'text': 'pythonprogramming', 'indices': [102, 120]},
#      {'text': 'Data', 'indices': [121, 126]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'arn_rafael',
#       'name': 'Rafael Arn',
#       'id': 2158275842,
#       'id_str': '2158275842',
#       'indices': [3, 14]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 453134179,
#     'id_str': '453134179',
#     'name': 'Frank L. Morales II',
#     'screen_name': 'altf2o',
#     'location': 'Washington, USA',
#     'description': 'Programmer, DevOps, (beginning) InfoSec, father of 3, husband, lover of technology, musician who loves heavy metal & blues guitar, and making hip hop beats!',
#     'url': 'https://t.co/kWJbNQmwxO',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/kWJbNQmwxO',
#         'expanded_url': 'https://github.com/fmoralesii',
#         'display_url': 'github.com/fmoralesii',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 754,
#     'friends_count': 4487,
#     'listed_count': 37,
#     'created_at': 'Mon Jan 02 16:28:14 +0000 2012',
#     'favourites_count': 102708,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 6282,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/3308207915/3308ca06902f7f423056cb165262b2bb_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3308207915/3308ca06902f7f423056cb165262b2bb_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Mon Aug 10 13:55:42 +0000 2020',
#     'id': 1292821931146776577,
#     'id_str': '1292821931146776577',
#     'text': 'Free Data Science #ebooks \n🚀🚀🚀🚀💻💻💻💻\n\n#AI #future #innovation #technology #DataScience #pythonprogramming #Data https://t.co/WyWA5rkBDd',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'ebooks', 'indices': [18, 25]},
#       {'text': 'AI', 'indices': [37, 40]},
#       {'text': 'future', 'indices': [41, 48]},
#       {'text': 'innovation', 'indices': [49, 60]},
#       {'text': 'technology', 'indices': [61, 72]},
#       {'text': 'DataScience', 'indices': [73, 85]},
# ...
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Mon Aug 10 14:22:12 +0000 2020',
#    'id': 1292828601604345858,
#    'id_str': '1292828601604345858',
#    'text': "@Caspineft @JosephHay92 @ClarkeMicah You can keep cherry-picking this handful of studies, but the science hasn't ch… https://t.co/CR8mLIqHtU",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Caspineft',
#       'name': 'Caspineft',
#       'id': 311907295,
#       'id_str': '311907295',
#       'indices': [0, 10]},
#      {'screen_name': 'JosephHay92',
#       'name': 'Joe Cicero',
#       'id': 867417274646396928,
#       'id_str': '867417274646396928',
#       'indices': [11, 23]},
#      {'screen_name': 'ClarkeMicah',
#       'name': 'Peter Hitchens',
#       'id': 405605548,
#       'id_str': '405605548',
#       'indices': [24, 36]}],
#     'urls': [{'url': 'https://t.co/CR8mLIqHtU',
#       'expanded_url': 'https://twitter.com/i/web/status/1292828601604345858',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1292827081064185856,
#    'in_reply_to_status_id_str': '1292827081064185856',
#    'in_reply_to_user_id': 311907295,
#    'in_reply_to_user_id_str': '311907295',
#    'in_reply_to_screen_name': 'Caspineft',
#    'user': {'id': 1099574053,
#     'id_str': '1099574053',
#     'name': 'Robert Warehall',
#     'screen_name': 'RWarehall',
#     'location': '',
#     'description': 'Classic Liberal.  We are the centrists who decide the elections choosing the least extreme and most sensible.  Free speech and liberty for all matters.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 38,
#     'friends_count': 213,
#     'listed_count': 1,
#     'created_at': 'Thu Jan 17 23:54:44 +0000 2013',
#     'favourites_count': 281,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1711,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Mon Aug 10 14:21:23 +0000 2020',
#    'id': 1292828394422284290,
#    'id_str': '1292828394422284290',
#    'text': 'RT @EdinDataScience: Applications are still open for a September 2020 start! Join a growing #online learning community and enhance your car…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'online', 'indices': [92, 99]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'EdinDataScience',
#       'name': 'Data Science, Technology and Innovation',
#       'id': 3395544166,
#       'id_str': '3395544166',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1191342312401428480,
#     'id_str': '1191342312401428480',
#     'name': 'KittenPie',
#     'screen_name': 'petitebonheur8',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 7,
#     'friends_count': 266,
#     'listed_count': 0,
#     'created_at': 'Mon Nov 04 13:12:19 +0000 2019',
#     'favourites_count': 128,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 297,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1191929167157383168/GGRvgShO_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1191929167157383168/GGRvgShO_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Jul 09 11:23:41 +0000 2020',
#     'id': 1281187263976792065,
#     'id_str': '1281187263976792065',
#     'text': 'Applications are still open for a September 2020 start! Join a growing #online learning community and enhance your… https://t.co/CltW7QnkTu',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'online', 'indices': [71, 78]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/CltW7QnkTu',
#        'expanded_url': 'https://twitter.com/i/web/status/1281187263976792065',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://ads-api.twitter.com" rel="nofollow">Twitter for Advertisers</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 3395544166,
#      'id_str': '3395544166',
#      'name': 'Data Science, Technology and Innovation',
#      'screen_name': 'EdinDataScience',
#      'location': 'Edinburgh, Scotland',
#      'description': 'Hosted @BayesCentre, we are a @EdinburghUni - wide online learning postgraduate programme offering different entry points into the world of data science.',
#      'url': 'https://t.co/xD5rZPmNUA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/xD5rZPmNUA',
#          'expanded_url': 'https://www.ed.ac.uk/bayes/about-us/our-work/education/data-science-technology-and-innovation',
#          'display_url': 'ed.ac.uk/bayes/about-us…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 4687,
#      'friends_count': 434,
#      'listed_count': 98,
#      'created_at': 'Thu Jul 30 12:36:20 +0000 2015',
#      'favourites_count': 1820,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 2616,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/641248222443343872/wqiV0rJn_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/641248222443343872/wqiV0rJn_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3395544166/1573819449',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 12,
#     'favorite_count': 42,
#     'favorited': False,
#     'retweeted': False,
#     'scopes': {'followers': False},
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 12,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Mon Aug 10 14:21:16 +0000 2020',
#    'id': 1292828366006034433,
#    'id_str': '1292828366006034433',
#    'text': "RT @ClickOnKaduna: The Data Science Fellowship Programme application window will close on August 31st!\nDon't miss the opportunity to take y…",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ClickOnKaduna',
#       'name': 'Click-On Kaduna',
#       'id': 1005446932045627394,
#       'id_str': '1005446932045627394',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 4782320954,
#     'id_str': '4782320954',
#     'name': 'saifulla ibrahmi',
#     'screen_name': 'SIbrahmi',
#     'location': 'Nigeria',
#     'description': 'front end developer',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 46,
#     'friends_count': 198,
#     'listed_count': 1,
#     'created_at': 'Tue Jan 19 09:26:27 +0000 2016',
#     'favourites_count': 1162,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 357,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1266303203303231488/qGY4vvUx_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1266303203303231488/qGY4vvUx_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Mon Aug 10 14:17:52 +0000 2020',
#     'id': 1292827509566984192,
#     'id_str': '1292827509566984192',
#     'text': "The Data Science Fellowship Programme application window will close on August 31st!\nDon't miss the opportunity to t… https://t.co/eqzHju9hu8",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/eqzHju9hu8',
#        'expanded_url': 'https://twitter.com/i/web/status/1292827509566984192',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1005446932045627394,
#      'id_str': '1005446932045627394',
#      'name': 'Click-On Kaduna',
#      'screen_name': 'ClickOnKaduna',
#      'location': 'Kaduna, Nigeria',
#      'description': 'The Kaduna State Government through the Click-On Kaduna Programme is raising agents for digital transformation across all sectors of the economy.',
#      'url': 'https://t.co/SbtxcQ81r0',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/SbtxcQ81r0',
#          'expanded_url': 'https://datascience.click-onkaduna.ng/',
#          'display_url': 'datascience.click-onkaduna.ng',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 3915,
#      'friends_count': 119,
#      'listed_count': 2,
#      'created_at': 'Sat Jun 09 13:50:03 +0000 2018',
#      'favourites_count': 798,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 1957,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1006111221538533377/Uqb_Lo6__normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1006111221538533377/Uqb_Lo6__normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1005446932045627394/1595889595',
#      'profile_link_color': '19CF86',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 4,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.104,
#   'max_id': 1292829032401317889,
#   'max_id_str': '1292829032401317889',
#   'next_results': '?max_id=1292828366006034432&q=data%20science&include_entities=1',
#   'query': 'data+science',
#   'refresh_url': '?since_id=1292829032401317889&q=data%20science&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# For good measure, try doing a search for tweets relating to `#MeToo` as well.

# %%
# your answer here
url ='https://api.twitter.com/1.1/search/tweets.json?q=%23metoo&src=typed_query'
metoo=requests.get(url,auth=auth)

# %%
metoo.json()
# Out:
# {'statuses': [{'created_at': 'Sun Aug 09 08:53:00 +0000 2020',
#    'id': 1292383364683575298,
#    'id_str': '1292383364683575298',
#    'text': 'RT @Fnordspotting: #RefugeesWelcome, #MeToo, #FridaysForFuture och nu senast #BlackLivesMatter. Ser ni ett mönster här? Detta är de postmod…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'RefugeesWelcome', 'indices': [19, 35]},
#      {'text': 'MeToo', 'indices': [37, 43]},
#      {'text': 'FridaysForFuture', 'indices': [45, 62]},
#      {'text': 'BlackLivesMatter', 'indices': [77, 94]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Fnordspotting',
#       'name': 'Fnordspotting',
#       'id': 1447363795,
#       'id_str': '1447363795',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'sv', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 106851729,
#     'id_str': '106851729',
#     'name': 'Ben',
#     'screen_name': 'Pollock69',
#     'location': '',
#     'description': 'Civ. ing. Chalmers -94. Konservativ.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 333,
#     'friends_count': 1500,
#     'listed_count': 4,
#     'created_at': 'Wed Jan 20 22:13:11 +0000 2010',
#     'favourites_count': 2292,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 5841,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/933413950695276545/clUDBOEa_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/933413950695276545/clUDBOEa_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/106851729/1473962308',
#     'profile_link_color': '4A913C',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 08:44:57 +0000 2020',
#     'id': 1292381339522666496,
#     'id_str': '1292381339522666496',
#     'text': '#RefugeesWelcome, #MeToo, #FridaysForFuture och nu senast #BlackLivesMatter. Ser ni ett mönster här? Detta är de po… https://t.co/cGCXZe6OFu',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'RefugeesWelcome', 'indices': [0, 16]},
#       {'text': 'MeToo', 'indices': [18, 24]},
#       {'text': 'FridaysForFuture', 'indices': [26, 43]},
#       {'text': 'BlackLivesMatter', 'indices': [58, 75]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/cGCXZe6OFu',
#        'expanded_url': 'https://twitter.com/i/web/status/1292381339522666496',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'sv', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1447363795,
#      'id_str': '1447363795',
#      'name': 'Fnordspotting',
#      'screen_name': 'Fnordspotting',
#      'location': 'En ö i trakten av Magora',
#      'description': 'Reaktionär enmansmotståndsrörelse.',
#      'url': 'https://t.co/aeFcmEQRo9',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/aeFcmEQRo9',
#          'expanded_url': 'http://fnordspotting.blogspot.com/',
#          'display_url': 'fnordspotting.blogspot.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 13908,
#      'friends_count': 335,
#      'listed_count': 53,
#      'created_at': 'Tue May 21 21:50:31 +0000 2013',
#      'favourites_count': 38692,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 66955,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/650744955577565184/ZJW9xIbp_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/650744955577565184/ZJW9xIbp_normal.png',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 5,
#     'favorite_count': 25,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'sv'},
#    'is_quote_status': False,
#    'retweet_count': 5,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'sv'},
#   {'created_at': 'Sun Aug 09 08:52:46 +0000 2020',
#    'id': 1292383306990968832,
#    'id_str': '1292383306990968832',
#    'text': 'RT @Fnordspotting: #RefugeesWelcome, #MeToo, #FridaysForFuture och nu senast #BlackLivesMatter. Ser ni ett mönster här? Detta är de postmod…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'RefugeesWelcome', 'indices': [19, 35]},
#      {'text': 'MeToo', 'indices': [37, 43]},
#      {'text': 'FridaysForFuture', 'indices': [45, 62]},
#      {'text': 'BlackLivesMatter', 'indices': [77, 94]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Fnordspotting',
#       'name': 'Fnordspotting',
#       'id': 1447363795,
#       'id_str': '1447363795',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'sv', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2268947125,
#     'id_str': '2268947125',
#     'name': 'Gammal Nordisk kombination 🇸🇪 🇫🇮 🇳🇴',
#     'screen_name': 'Servicegubben',
#     'location': 'Seskarö',
#     'description': 'Multikompetent.',
#     'url': 'https://t.co/b247j20HJs',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/b247j20HJs',
#         'expanded_url': 'http://servicegubben.se',
#         'display_url': 'servicegubben.se',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 566,
#     'friends_count': 739,
#     'listed_count': 7,
#     'created_at': 'Mon Dec 30 14:27:16 +0000 2013',
#     'favourites_count': 134246,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 20201,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1261321730464845825/ChO_deOO_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261321730464845825/ChO_deOO_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2268947125/1440247089',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 08:44:57 +0000 2020',
#     'id': 1292381339522666496,
#     'id_str': '1292381339522666496',
#     'text': '#RefugeesWelcome, #MeToo, #FridaysForFuture och nu senast #BlackLivesMatter. Ser ni ett mönster här? Detta är de po… https://t.co/cGCXZe6OFu',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'RefugeesWelcome', 'indices': [0, 16]},
#       {'text': 'MeToo', 'indices': [18, 24]},
#       {'text': 'FridaysForFuture', 'indices': [26, 43]},
#       {'text': 'BlackLivesMatter', 'indices': [58, 75]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/cGCXZe6OFu',
#        'expanded_url': 'https://twitter.com/i/web/status/1292381339522666496',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'sv', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1447363795,
#      'id_str': '1447363795',
#      'name': 'Fnordspotting',
#      'screen_name': 'Fnordspotting',
#      'location': 'En ö i trakten av Magora',
#      'description': 'Reaktionär enmansmotståndsrörelse.',
#      'url': 'https://t.co/aeFcmEQRo9',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/aeFcmEQRo9',
#          'expanded_url': 'http://fnordspotting.blogspot.com/',
#          'display_url': 'fnordspotting.blogspot.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 13908,
#      'friends_count': 335,
#      'listed_count': 53,
#      'created_at': 'Tue May 21 21:50:31 +0000 2013',
#      'favourites_count': 38692,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 66955,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/650744955577565184/ZJW9xIbp_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/650744955577565184/ZJW9xIbp_normal.png',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 5,
#     'favorite_count': 25,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'sv'},
#    'is_quote_status': False,
#    'retweet_count': 5,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'sv'},
#   {'created_at': 'Sun Aug 09 08:52:26 +0000 2020',
#    'id': 1292383224874795008,
#    'id_str': '1292383224874795008',
#    'text': 'RT @Fnordspotting: #RefugeesWelcome, #MeToo, #FridaysForFuture och nu senast #BlackLivesMatter. Ser ni ett mönster här? Detta är de postmod…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'RefugeesWelcome', 'indices': [19, 35]},
#      {'text': 'MeToo', 'indices': [37, 43]},
#      {'text': 'FridaysForFuture', 'indices': [45, 62]},
#      {'text': 'BlackLivesMatter', 'indices': [77, 94]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Fnordspotting',
#       'name': 'Fnordspotting',
#       'id': 1447363795,
#       'id_str': '1447363795',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'sv', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 123882741,
#     'id_str': '123882741',
#     'name': 'Mises-institutet',
#     'screen_name': 'mises_se',
#     'location': 'Sverige',
#     'description': 'https://t.co/zPBb8MiLq5 är Sveriges frihetligaste tankesmedja. Vi sprider frihetens budskap genom att upplysa om österrikisk ekonomi och libertariansk moralfilosofi.',
#     'url': 'https://t.co/rZ5gYGVy3q',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/rZ5gYGVy3q',
#         'expanded_url': 'https://www.mises.se/',
#         'display_url': 'mises.se',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/zPBb8MiLq5',
#         'expanded_url': 'http://Mises.se',
#         'display_url': 'Mises.se',
#         'indices': [0, 23]}]}},
#     'protected': False,
#     'followers_count': 2364,
#     'friends_count': 22,
#     'listed_count': 23,
#     'created_at': 'Wed Mar 17 14:17:33 +0000 2010',
#     'favourites_count': 2298,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 7399,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '2B80B7',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1290918486332579841/7yOt1hMS_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1290918486332579841/7yOt1hMS_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/123882741/1596575966',
#     'profile_link_color': '3A9BC5',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 08:44:57 +0000 2020',
#     'id': 1292381339522666496,
#     'id_str': '1292381339522666496',
#     'text': '#RefugeesWelcome, #MeToo, #FridaysForFuture och nu senast #BlackLivesMatter. Ser ni ett mönster här? Detta är de po… https://t.co/cGCXZe6OFu',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'RefugeesWelcome', 'indices': [0, 16]},
#       {'text': 'MeToo', 'indices': [18, 24]},
#       {'text': 'FridaysForFuture', 'indices': [26, 43]},
#       {'text': 'BlackLivesMatter', 'indices': [58, 75]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/cGCXZe6OFu',
#        'expanded_url': 'https://twitter.com/i/web/status/1292381339522666496',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'sv', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1447363795,
#      'id_str': '1447363795',
#      'name': 'Fnordspotting',
#      'screen_name': 'Fnordspotting',
#      'location': 'En ö i trakten av Magora',
#      'description': 'Reaktionär enmansmotståndsrörelse.',
#      'url': 'https://t.co/aeFcmEQRo9',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/aeFcmEQRo9',
#          'expanded_url': 'http://fnordspotting.blogspot.com/',
#          'display_url': 'fnordspotting.blogspot.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 13908,
#      'friends_count': 335,
#      'listed_count': 53,
#      'created_at': 'Tue May 21 21:50:31 +0000 2013',
#      'favourites_count': 38692,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 66955,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/650744955577565184/ZJW9xIbp_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/650744955577565184/ZJW9xIbp_normal.png',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 5,
#     'favorite_count': 25,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'sv'},
#    'is_quote_status': False,
#    'retweet_count': 5,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'sv'},
#   {'created_at': 'Sun Aug 09 08:52:12 +0000 2020',
#    'id': 1292383164699217920,
#    'id_str': '1292383164699217920',
#    'text': 'Personajes femeninos de El Quijote reinterpretados en las maravillosas fotografías de Juan Cerón.#fotografia #metoo… https://t.co/I0zX63PKmL',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'fotografia', 'indices': [97, 108]},
#      {'text': 'metoo', 'indices': [109, 115]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/I0zX63PKmL',
#       'expanded_url': 'https://twitter.com/i/web/status/1292383164699217920',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 829435209464573956,
#     'id_str': '829435209464573956',
#     'name': 'Esto No Es Arte',
#     'screen_name': 'noes_arte',
#     'location': '',
#     'description': 'Creemos que hay gente increíble creando piezas maravillosas. Queremos conocerlas y compartirlas contigo.\nPorque queremos seducirte, inspirarte y emocionarte.',
#     'url': 'https://t.co/DGzLhOFBh5',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/DGzLhOFBh5',
#         'expanded_url': 'http://estonoesarte.com',
#         'display_url': 'estonoesarte.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 313,
#     'friends_count': 240,
#     'listed_count': 8,
#     'created_at': 'Wed Feb 08 21:02:18 +0000 2017',
#     'favourites_count': 176,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1167,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/898539669725564928/hp2SFy1v_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/898539669725564928/hp2SFy1v_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/829435209464573956/1503064273',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'es'},
#   {'created_at': 'Sun Aug 09 08:51:59 +0000 2020',
#    'id': 1292383110814994432,
#    'id_str': '1292383110814994432',
#    'text': 'RT @FirstThemNEWS: Man allowed to r-e a child and recieve probation because "he has the mental capacity of a 10 yo."\n🤷🏿\u200d♂️\n#MeToo surely yo…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [123, 129]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'FirstThemNEWS',
#       'name': '#FirstThem NEWS🇺🇸',
#       'id': 996339202647252992,
#       'id_str': '996339202647252992',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1179556145444397057,
#     'id_str': '1179556145444397057',
#     'name': 'ANGIEDEE🇺🇸',
#     'screen_name': 'ANGIEDE48971044',
#     'location': '',
#     'description': 'F.B.A',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 202,
#     'friends_count': 227,
#     'listed_count': 3,
#     'created_at': 'Thu Oct 03 00:38:14 +0000 2019',
#     'favourites_count': 21652,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 5882,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1179575318799159296/M4PMfcCm_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1179575318799159296/M4PMfcCm_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 03:38:46 +0000 2020',
#     'id': 1292304288190889985,
#     'id_str': '1292304288190889985',
#     'text': 'Man allowed to r-e a child and recieve probation because "he has the mental capacity of a 10 yo."\n🤷🏿\u200d♂️\n#MeToo sure… https://t.co/RczOP31DfV',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'MeToo', 'indices': [104, 110]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/RczOP31DfV',
#        'expanded_url': 'https://twitter.com/i/web/status/1292304288190889985',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 996339202647252992,
#      'id_str': '996339202647252992',
#      'name': '#FirstThem NEWS🇺🇸',
#      'screen_name': 'FirstThemNEWS',
#      'location': 'Gadsden’s Wharf, S. Carolina',
#      'description': '#FBA🇺🇸Journalist/Activists use #FirstThem to DESTROY the myth of “Black Rape.” Meanwhile .... the MSM “gaslights” #MeToo w/under-reporting of Sexual Violence.',
#      'url': 'https://t.co/A5PIzepjhZ',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/A5PIzepjhZ',
#          'expanded_url': 'https://firstthemNEWS.com/blog-metoo',
#          'display_url': 'firstthemNEWS.com/blog-metoo',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 6591,
#      'friends_count': 87,
#      'listed_count': 25,
#      'created_at': 'Tue May 15 10:39:11 +0000 2018',
#      'favourites_count': 9461,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 8140,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1241436189963325440/8i9jSYU2_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1241436189963325440/8i9jSYU2_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/996339202647252992/1581849921',
#      'profile_link_color': 'E81C4F',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 78,
#     'favorite_count': 143,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 78,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:51:56 +0000 2020',
#    'id': 1292383098093461505,
#    'id_str': '1292383098093461505',
#    'text': '@JBarbagiannis Whats the name of that oz "journo" who did some expose on sexual harrassment for oz #metoo bs 😂😂',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'metoo', 'indices': [99, 105]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'JBarbagiannis',
#       'name': 'John Barbagiannis',
#       'id': 486375605,
#       'id_str': '486375605',
#       'indices': [0, 14]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1292378234214993920,
#    'in_reply_to_status_id_str': '1292378234214993920',
#    'in_reply_to_user_id': 486375605,
#    'in_reply_to_user_id_str': '486375605',
#    'in_reply_to_screen_name': 'JBarbagiannis',
#    'user': {'id': 1092064874,
#     'id_str': '1092064874',
#     'name': 'Mick',
#     'screen_name': 'MDosNK',
#     'location': 'Sydney',
#     'description': 'Football ⚽⚽⚽⚽',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 738,
#     'friends_count': 2056,
#     'listed_count': 19,
#     'created_at': 'Tue Jan 15 13:18:40 +0000 2013',
#     'favourites_count': 10028,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 21335,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/476702179583995905/0v1GiXHm_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/476702179583995905/0v1GiXHm_normal.jpeg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1092064874/1403168373',
#     'profile_link_color': '3B94D9',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:51:26 +0000 2020',
#    'id': 1292382971987558401,
#    'id_str': '1292382971987558401',
#    'text': "RT @sachiinv7: What happened in Kedarnath movie distribution rights issue?\n\nMumbai Police acted quickly with Vashu Bhagnani's complaint aga…",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'sachiinv7',
#       'name': 'Sachiin Suryavanshi',
#       'id': 1181436953461284866,
#       'id_str': '1181436953461284866',
#       'indices': [3, 13]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3513929053,
#     'id_str': '3513929053',
#     'name': 'SSRian',
#     'screen_name': 'ShrmaRajeshwari',
#     'location': 'patna,bihar',
#     'description': 'workin upon my \nblues💦hues🔥clues💫',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 90,
#     'friends_count': 247,
#     'listed_count': 0,
#     'created_at': 'Thu Sep 10 09:15:56 +0000 2015',
#     'favourites_count': 11037,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 8747,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1286212557347274752/Gf8UIeV7_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1286212557347274752/Gf8UIeV7_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3513929053/1593315867',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 07:15:47 +0000 2020',
#     'id': 1292358898838462471,
#     'id_str': '1292358898838462471',
#     'text': "What happened in Kedarnath movie distribution rights issue?\n\nMumbai Police acted quickly with Vashu Bhagnani's comp… https://t.co/NhkcD7CeXa",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/NhkcD7CeXa',
#        'expanded_url': 'https://twitter.com/i/web/status/1292358898838462471',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1181436953461284866,
#      'id_str': '1181436953461284866',
#      'name': 'Sachiin Suryavanshi',
#      'screen_name': 'sachiinv7',
#      'location': '',
#      'description': '🇮🇳Javandroid Enthusiastic.Founder And Owner of Ksamyatam Softwares, previously Javandroidaholic.Javandroid My Passion Music My Energy @ksamyatam #sachasays',
#      'url': 'https://t.co/DRjhA4X5Pf',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/DRjhA4X5Pf',
#          'expanded_url': 'http://www.ksamyatam.com',
#          'display_url': 'ksamyatam.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 496,
#      'friends_count': 1,
#      'listed_count': 1,
#      'created_at': 'Tue Oct 08 05:13:45 +0000 2019',
#      'favourites_count': 2816,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 5902,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1265981345983012866/WQ-yKO8Y_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1265981345983012866/WQ-yKO8Y_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1181436953461284866/1590668418',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 14,
#     'favorite_count': 26,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 14,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:50:52 +0000 2020',
#    'id': 1292382831461593088,
#    'id_str': '1292382831461593088',
#    'text': 'RT @porwal_vikash: @MiliS62751908 एकपक्षीय कानूनो का दुरुपयोग कर,झुठे केस लगा पुरूष की जिन्दगी बर्बाद करने वाली स्त्रियों को फांसी की सजा…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'porwal_vikash',
#       'name': 'FIGHT for Men rights',
#       'id': 837276296963063808,
#       'id_str': '837276296963063808',
#       'indices': [3, 17]},
#      {'screen_name': 'MiliS62751908',
#       'name': 'Mili S',
#       'id': 1254991387981869057,
#       'id_str': '1254991387981869057',
#       'indices': [19, 33]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'hi', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1259218739943350272,
#     'id_str': '1259218739943350272',
#     'name': 'IaM Not A Rapist!!!!💎',
#     'screen_name': 'ABHAYPA99341117',
#     'location': 'Mysore, Chennai, Silvasa, Goa,',
#     'description': 'Engineer Cable designer by profession....',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 19,
#     'friends_count': 139,
#     'listed_count': 0,
#     'created_at': 'Sat May 09 20:28:49 +0000 2020',
#     'favourites_count': 227,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 260,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1277175024579866625/8DwMH3-o_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1277175024579866625/8DwMH3-o_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1259218739943350272/1590612212',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 12:38:02 +0000 2020',
#     'id': 1292077608264282114,
#     'id_str': '1292077608264282114',
#     'text': '@MiliS62751908 एकपक्षीय कानूनो का दुरुपयोग कर,झुठे केस लगा पुरूष की जिन्दगी बर्बाद करने वाली स्त्रियों को फांसी की… https://t.co/nafngvSLpX',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'MiliS62751908',
#        'name': 'Mili S',
#        'id': 1254991387981869057,
#        'id_str': '1254991387981869057',
#        'indices': [0, 14]}],
#      'urls': [{'url': 'https://t.co/nafngvSLpX',
#        'expanded_url': 'https://twitter.com/i/web/status/1292077608264282114',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'hi', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': 1291695899165351936,
#     'in_reply_to_status_id_str': '1291695899165351936',
#     'in_reply_to_user_id': 1254991387981869057,
#     'in_reply_to_user_id_str': '1254991387981869057',
#     'in_reply_to_screen_name': 'MiliS62751908',
#     'user': {'id': 837276296963063808,
#      'id_str': '837276296963063808',
#      'name': 'FIGHT for Men rights',
#      'screen_name': 'porwal_vikash',
#      'location': 'UP.INDIA',
#      'description': 'VOICE of Indian husband/men 🇮🇳🇮🇳',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 323,
#      'friends_count': 161,
#      'listed_count': 0,
#      'created_at': 'Thu Mar 02 12:19:59 +0000 2017',
#      'favourites_count': 5588,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 13065,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1289736733446123522/6-O6C0lH_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1289736733446123522/6-O6C0lH_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/837276296963063808/1545730064',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 5,
#     'favorite_count': 4,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'hi'},
#    'is_quote_status': False,
#    'retweet_count': 5,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'hi'},
#   {'created_at': 'Sun Aug 09 08:50:40 +0000 2020',
#    'id': 1292382780777799681,
#    'id_str': '1292382780777799681',
#    'text': 'RT @beabri: Grazia lavorava come guida a Napoli Sotterranea. Ha subito violenza da parte del suo capo, ha trovato la forza di denunciare, è…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'beabri',
#       'name': 'Beatrice Brignone',
#       'id': 50584579,
#       'id_str': '50584579',
#       'indices': [3, 10]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'it', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2814991504,
#     'id_str': '2814991504',
#     'name': 'cinzia',
#     'screen_name': 'cinziamartin1',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 406,
#     'friends_count': 427,
#     'listed_count': 0,
#     'created_at': 'Wed Oct 08 10:25:23 +0000 2014',
#     'favourites_count': 47754,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 6999,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/519798372165615618/643LCZTs_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/519798372165615618/643LCZTs_normal.jpeg',
#     'profile_link_color': 'FF691F',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 08 17:23:29 +0000 2020',
#     'id': 1292149446990598144,
#     'id_str': '1292149446990598144',
#     'text': 'Grazia lavorava come guida a Napoli Sotterranea. Ha subito violenza da parte del suo capo, ha trovato la forza di d… https://t.co/NI1JzlyPRk',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/NI1JzlyPRk',
#        'expanded_url': 'https://twitter.com/i/web/status/1292149446990598144',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'it', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 50584579,
#      'id_str': '50584579',
#      'name': 'Beatrice Brignone',
#      'screen_name': 'beabri',
#      'location': 'Senigallia',
#      'description': 'Femminista, ambientalista, animalista, antifascista, segretaria di @Possibileit. Per sostenerci, indica #S36 nel 2*1000 della tua dichiarazione dei redditi.',
#      'url': 'https://t.co/qTRaB3rVb2',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/qTRaB3rVb2',
#          'expanded_url': 'http://www.facebook.com/brignonebea',
#          'display_url': 'facebook.com/brignonebea',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 12714,
#      'friends_count': 867,
#      'listed_count': 69,
#      'created_at': 'Thu Jun 25 07:49:00 +0000 2009',
#      'favourites_count': 9043,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 10225,
#      'lang': None,
#      'contributors_enabled': False,
# ...
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'fa'},
#   {'created_at': 'Sun Aug 09 08:50:10 +0000 2020',
#    'id': 1292382653208039424,
#    'id_str': '1292382653208039424',
#    'text': '@ebonyplusirony Nicht zu vergessen: Das Vergewaltigungsgedicht von #TillLindemann #MeToo',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'TillLindemann', 'indices': [67, 81]},
#      {'text': 'MeToo', 'indices': [82, 88]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ebonyplusirony',
#       'name': 'Quattromilf',
#       'id': 4527949647,
#       'id_str': '4527949647',
#       'indices': [0, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'de', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1292179857711996929,
#    'in_reply_to_status_id_str': '1292179857711996929',
#    'in_reply_to_user_id': 4527949647,
#    'in_reply_to_user_id_str': '4527949647',
#    'in_reply_to_screen_name': 'ebonyplusirony',
#    'user': {'id': 114470557,
#     'id_str': '114470557',
#     'name': 'Jacky O.',
#     'screen_name': 'jackytonic',
#     'location': 'Köln, Deutschland',
#     'description': 'Online-Redakteurin, hier privat\n\nThemen: Demos im Raum Köln, Hambacher Forst',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 25,
#     'friends_count': 67,
#     'listed_count': 0,
#     'created_at': 'Mon Feb 15 14:37:32 +0000 2010',
#     'favourites_count': 600,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 345,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'DBE9ED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme17/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme17/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1098938408376897536/NXwaShr1_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1098938408376897536/NXwaShr1_normal.jpg',
#     'profile_link_color': 'CC3366',
#     'profile_sidebar_border_color': 'DBE9ED',
#     'profile_sidebar_fill_color': 'E6F6F9',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'de'},
#   {'created_at': 'Sun Aug 09 08:49:56 +0000 2020',
#    'id': 1292382593866850305,
#    'id_str': '1292382593866850305',
#    'text': 'RT @FirstThemNEWS: Man allowed to r-e a child and recieve probation because "he has the mental capacity of a 10 yo."\n🤷🏿\u200d♂️\n#MeToo surely yo…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [123, 129]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'FirstThemNEWS',
#       'name': '#FirstThem NEWS🇺🇸',
#       'id': 996339202647252992,
#       'id_str': '996339202647252992',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 542810638,
#     'id_str': '542810638',
#     'name': 'susan evans',
#     'screen_name': 'susanev60231151',
#     'location': '',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 121,
#     'friends_count': 472,
#     'listed_count': 0,
#     'created_at': 'Sun Apr 01 19:57:42 +0000 2012',
#     'favourites_count': 15075,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 7389,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': True,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 03:38:46 +0000 2020',
#     'id': 1292304288190889985,
#     'id_str': '1292304288190889985',
#     'text': 'Man allowed to r-e a child and recieve probation because "he has the mental capacity of a 10 yo."\n🤷🏿\u200d♂️\n#MeToo sure… https://t.co/RczOP31DfV',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'MeToo', 'indices': [104, 110]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/RczOP31DfV',
#        'expanded_url': 'https://twitter.com/i/web/status/1292304288190889985',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 996339202647252992,
#      'id_str': '996339202647252992',
#      'name': '#FirstThem NEWS🇺🇸',
#      'screen_name': 'FirstThemNEWS',
#      'location': 'Gadsden’s Wharf, S. Carolina',
#      'description': '#FBA🇺🇸Journalist/Activists use #FirstThem to DESTROY the myth of “Black Rape.” Meanwhile .... the MSM “gaslights” #MeToo w/under-reporting of Sexual Violence.',
#      'url': 'https://t.co/A5PIzepjhZ',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/A5PIzepjhZ',
#          'expanded_url': 'https://firstthemNEWS.com/blog-metoo',
#          'display_url': 'firstthemNEWS.com/blog-metoo',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 6591,
#      'friends_count': 87,
#      'listed_count': 25,
#      'created_at': 'Tue May 15 10:39:11 +0000 2018',
#      'favourites_count': 9461,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 8140,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1241436189963325440/8i9jSYU2_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1241436189963325440/8i9jSYU2_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/996339202647252992/1581849921',
#      'profile_link_color': 'E81C4F',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 78,
#     'favorite_count': 143,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 78,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:49:53 +0000 2020',
#    'id': 1292382581833347078,
#    'id_str': '1292382581833347078',
#    'text': 'RT @qtaroxxx: 伊藤詩織さんのインタビュー動画があります📣\n\n▼ジャーナリストの伊藤詩織、#MeToo\xa0 のきっかけとなったワインスタイン事件を追った記者にインタビュー（ハーパーズ バザー・オンラインの記事）\nhttps://t.co/vBqJmp1t5P',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [51, 57]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'qtaroxxx',
#       'name': 'Q太郎',
#       'id': 916160922296631296,
#       'id_str': '916160922296631296',
#       'indices': [3, 12]}],
#     'urls': [{'url': 'https://t.co/vBqJmp1t5P',
#       'expanded_url': 'https://www.harpersbazaar.com/jp/lifestyle/womens-life/a33517720/disclosing-the-voice-200808-hbr/',
#       'display_url': 'harpersbazaar.com/jp/lifestyle/w…',
#       'indices': [111, 134]}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1116120704,
#     'id_str': '1116120704',
#     'name': 'ゆきちゃん(Persona Sin valor)',
#     'screen_name': 'chaosjapan',
#     'location': '',
#     'description': 'あらゆる契は大切にすべし。けどもっと自分自身で考えろ。 馴れ合いだけのオトモダチに染まってどうする。 たとえ仲間はずれになってもてめえの「個」を自害するな。 この言葉に価値を見いだせないなら切り捨てればいいさ。',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1003,
#     'friends_count': 1042,
#     'listed_count': 5,
#     'created_at': 'Thu Jan 24 06:33:48 +0000 2013',
#     'favourites_count': 22417,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 60609,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '131516',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1154722626570346496/tteMykQJ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1154722626570346496/tteMykQJ_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1116120704/1564192540',
#     'profile_link_color': '009999',
#     'profile_sidebar_border_color': 'EEEEEE',
#     'profile_sidebar_fill_color': 'EFEFEF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 02:00:13 +0000 2020',
#     'id': 1292279484016558081,
#     'id_str': '1292279484016558081',
#     'text': '伊藤詩織さんのインタビュー動画があります📣\n\n▼ジャーナリストの伊藤詩織、#MeToo\xa0 のきっかけとなったワインスタイン事件を追った記者にインタビュー（ハーパーズ バザー・オンラインの記事）\nhttps://t.co/vBqJmp1t5P',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'MeToo', 'indices': [37, 43]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/vBqJmp1t5P',
#        'expanded_url': 'https://www.harpersbazaar.com/jp/lifestyle/womens-life/a33517720/disclosing-the-voice-200808-hbr/',
#        'display_url': 'harpersbazaar.com/jp/lifestyle/w…',
#        'indices': [97, 120]}]},
#     'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 916160922296631296,
#      'id_str': '916160922296631296',
#      'name': 'Q太郎',
#      'screen_name': 'qtaroxxx',
#      'location': '大阪→川崎→東京→大阪',
#      'description': '',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1281,
#      'friends_count': 1277,
#      'listed_count': 12,
#      'created_at': 'Fri Oct 06 04:39:20 +0000 2017',
#      'favourites_count': 24092,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 23312,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1171765389061083136/eSqJy1bh_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1171765389061083136/eSqJy1bh_normal.jpg',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 17,
#     'favorite_count': 32,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'ja'},
#    'is_quote_status': False,
#    'retweet_count': 17,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'ja'}],
#  'search_metadata': {'completed_in': 0.094,
#   'max_id': 1292383364683575298,
#   'max_id_str': '1292383364683575298',
#   'next_results': '?max_id=1292382581833347077&q=%23metoo&include_entities=1',
#   'query': '%23metoo',
#   'refresh_url': '?since_id=1292383364683575298&q=%23metoo&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# **Step 2:  Adding Parameters to Your Query String**

# %% [markdown]
# Query strings basically have two parts:
#
#  - The `?` initiates the beginning of the API call, and basically says 'everything that follows this will encode something about the information that's going to get returned to you'.
#  - What follows that is are a bunch of symbols followed by `=` signs.  These are parameters.
#  - So when you make an api call to `'https://api.twitter.com/1.1/search/tweets.json?q=My%20Search%20Term`, the `q` is a paremeter.
#  - You can add multiple paremeters to a query string. They are separated by `&`. They dictate what kinds of results are returned.
#   - For example, a parameter you can use in Twitter's search API is `count`, which tells you how many results to return.  The default is 15, but you can return up to 100.  So if we wanted to search for tweets and return 50 results our query string would look like the following:
#     `https://api.twitter.com/1.1/search/tweets.json?q=My%20Search%20String&count=50`
#   - You can add as many of these parameters to your string as you'd like.  So for example, if we wanted to include parameters for `count` and `result_type`, we could do the following: `https://api.twitter.com/1.1/search/tweets.json?q=My%20Search%20String&count=50&result_type=mixed`
#
# To get the hang of this, try searching for tweets that mention the hashtag `#DeepLearning`, and return 75 results.

# %%
url ='https://api.twitter.com/1.1/search/tweets.json?q=%23deeplearning&count=75'
deeplearn=requests.get(url,auth=auth).json()

# %%
deeplearn
# Out:
# {'statuses': [{'created_at': 'Sun Aug 09 08:53:31 +0000 2020',
#    'id': 1292383496636424193,
#    'id_str': '1292383496636424193',
#    'text': 'RT @SamuelAkins12: This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, color e…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SamuelAkins12',
#       'name': 'Samuel Akinosho®',
#       'id': 1053247241618685953,
#       'id_str': '1053247241618685953',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 22000414,
#     'id_str': '22000414',
#     'name': 'Kiwi Paul',
#     'screen_name': 'squashypigeon',
#     'location': 'London, Europe.',
#     'description': 'Grumpy bipedal mammal, 70% water (ish). Homesick Kiwi. Atheist. Foodie.\nCAD, Bushcraft, Space, Homebrew, BBQ, Kites, Making, Eco, Self-sufficiency.\nI RT a LOT!',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 815,
#     'friends_count': 1809,
#     'listed_count': 49,
#     'created_at': 'Thu Feb 26 11:44:14 +0000 2009',
#     'favourites_count': 61588,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 49558,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '510800',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1051607371410227200/k-dFRFay_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1051607371410227200/k-dFRFay_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/22000414/1374073359',
#     'profile_link_color': 'E0912A',
#     'profile_sidebar_border_color': '3D0702',
#     'profile_sidebar_fill_color': '2C1703',
#     'profile_text_color': 'A16A23',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 06:26:45 +0000 2020',
#     'id': 1292346561079513090,
#     'id_str': '1292346561079513090',
#     'text': 'This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, co… https://t.co/mZi6wxZMz1',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mZi6wxZMz1',
#        'expanded_url': 'https://twitter.com/i/web/status/1292346561079513090',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1053247241618685953,
#      'id_str': '1053247241618685953',
#      'name': 'Samuel Akinosho®',
#      'screen_name': 'SamuelAkins12',
#      'location': 'Africa ',
#      'description': "Serial Entrepreneur, Ex. @microsoft @cisco |  AI & IoT Engr. | CEH |Passionate about Africa's development 🌍 #MUFC",
#      'url': 'https://t.co/Hzc0CDYj9g',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Hzc0CDYj9g',
#          'expanded_url': 'https://linktr.ee/SamuelAkinosho',
#          'display_url': 'linktr.ee/SamuelAkinosho',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2379,
#      'friends_count': 1622,
#      'listed_count': 8,
#      'created_at': 'Fri Oct 19 11:31:25 +0000 2018',
#      'favourites_count': 29978,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1053247241618685953/1590793590',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 169,
#     'favorite_count': 346,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 169,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:53:29 +0000 2020',
#    'id': 1292383488642080770,
#    'id_str': '1292383488642080770',
#    'text': 'RT @SamuelAkins12: This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, color e…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SamuelAkins12',
#       'name': 'Samuel Akinosho®',
#       'id': 1053247241618685953,
#       'id_str': '1053247241618685953',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 989752852112293889,
#     'id_str': '989752852112293889',
#     'name': 'Chad Clifton',
#     'screen_name': 'ChadClifton10',
#     'location': 'South West, England',
#     'description': '#FBPE \n\nMorality has never been a huge part of humanity - @missusbojangles',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 214,
#     'friends_count': 747,
#     'listed_count': 2,
#     'created_at': 'Fri Apr 27 06:27:23 +0000 2018',
#     'favourites_count': 4101,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 5027,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1208500687153356806/6Xyv2uSf_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1208500687153356806/6Xyv2uSf_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/989752852112293889/1546551542',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 06:26:45 +0000 2020',
#     'id': 1292346561079513090,
#     'id_str': '1292346561079513090',
#     'text': 'This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, co… https://t.co/mZi6wxZMz1',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mZi6wxZMz1',
#        'expanded_url': 'https://twitter.com/i/web/status/1292346561079513090',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1053247241618685953,
#      'id_str': '1053247241618685953',
#      'name': 'Samuel Akinosho®',
#      'screen_name': 'SamuelAkins12',
#      'location': 'Africa ',
#      'description': "Serial Entrepreneur, Ex. @microsoft @cisco |  AI & IoT Engr. | CEH |Passionate about Africa's development 🌍 #MUFC",
#      'url': 'https://t.co/Hzc0CDYj9g',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Hzc0CDYj9g',
#          'expanded_url': 'https://linktr.ee/SamuelAkinosho',
#          'display_url': 'linktr.ee/SamuelAkinosho',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2379,
#      'friends_count': 1622,
#      'listed_count': 8,
#      'created_at': 'Fri Oct 19 11:31:25 +0000 2018',
#      'favourites_count': 29978,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1053247241618685953/1590793590',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 169,
#     'favorite_count': 346,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 169,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:53:23 +0000 2020',
#    'id': 1292383461664346112,
#    'id_str': '1292383461664346112',
#    'text': 'RT @SamuelAkins12: This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, color e…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SamuelAkins12',
#       'name': 'Samuel Akinosho®',
#       'id': 1053247241618685953,
#       'id_str': '1053247241618685953',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 63523564,
#     'id_str': '63523564',
#     'name': 'Chris',
#     'screen_name': 'chrishughesuk',
#     'location': 'England',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 437,
#     'friends_count': 1106,
#     'listed_count': 9,
#     'created_at': 'Thu Aug 06 19:56:34 +0000 2009',
#     'favourites_count': 2213,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 1002,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1285961035585859586/tCXBFXbe_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1285961035585859586/tCXBFXbe_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 06:26:45 +0000 2020',
#     'id': 1292346561079513090,
#     'id_str': '1292346561079513090',
#     'text': 'This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, co… https://t.co/mZi6wxZMz1',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mZi6wxZMz1',
#        'expanded_url': 'https://twitter.com/i/web/status/1292346561079513090',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1053247241618685953,
#      'id_str': '1053247241618685953',
#      'name': 'Samuel Akinosho®',
#      'screen_name': 'SamuelAkins12',
#      'location': 'Africa ',
#      'description': "Serial Entrepreneur, Ex. @microsoft @cisco |  AI & IoT Engr. | CEH |Passionate about Africa's development 🌍 #MUFC",
#      'url': 'https://t.co/Hzc0CDYj9g',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Hzc0CDYj9g',
#          'expanded_url': 'https://linktr.ee/SamuelAkinosho',
#          'display_url': 'linktr.ee/SamuelAkinosho',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2379,
#      'friends_count': 1622,
#      'listed_count': 8,
#      'created_at': 'Fri Oct 19 11:31:25 +0000 2018',
#      'favourites_count': 29978,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1053247241618685953/1590793590',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 169,
#     'favorite_count': 346,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 169,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:53:21 +0000 2020',
#    'id': 1292383455989379073,
#    'id_str': '1292383455989379073',
#    'text': 'RT @SamuelAkins12: This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, color e…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SamuelAkins12',
#       'name': 'Samuel Akinosho®',
#       'id': 1053247241618685953,
#       'id_str': '1053247241618685953',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 26011538,
#     'id_str': '26011538',
#     'name': 'SallyfortheEU 3.5% #RejoinEU #FBPE',
#     'screen_name': 'sallydipple',
#     'location': 'Wirksworth, England',
#     'description': 'You can take the girl out of the EU but you can’t take the EU out of the girl. #RemainersWereRight',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3124,
#     'friends_count': 3111,
#     'listed_count': 19,
#     'created_at': 'Mon Mar 23 14:34:59 +0000 2009',
#     'favourites_count': 92882,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 87347,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'DBE9ED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme17/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme17/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1167001895866687488/_0_9u0Pk_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1167001895866687488/_0_9u0Pk_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/26011538/1567069909',
#     'profile_link_color': 'FF691F',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 06:26:45 +0000 2020',
#     'id': 1292346561079513090,
#     'id_str': '1292346561079513090',
#     'text': 'This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, co… https://t.co/mZi6wxZMz1',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mZi6wxZMz1',
#        'expanded_url': 'https://twitter.com/i/web/status/1292346561079513090',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1053247241618685953,
#      'id_str': '1053247241618685953',
#      'name': 'Samuel Akinosho®',
#      'screen_name': 'SamuelAkins12',
#      'location': 'Africa ',
#      'description': "Serial Entrepreneur, Ex. @microsoft @cisco |  AI & IoT Engr. | CEH |Passionate about Africa's development 🌍 #MUFC",
#      'url': 'https://t.co/Hzc0CDYj9g',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Hzc0CDYj9g',
#          'expanded_url': 'https://linktr.ee/SamuelAkinosho',
#          'display_url': 'linktr.ee/SamuelAkinosho',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2379,
#      'friends_count': 1622,
#      'listed_count': 8,
#      'created_at': 'Fri Oct 19 11:31:25 +0000 2018',
#      'favourites_count': 29978,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1053247241618685953/1590793590',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 169,
#     'favorite_count': 346,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 169,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:53:20 +0000 2020',
#    'id': 1292383448229961730,
#    'id_str': '1292383448229961730',
#    'text': 'RT @SamuelAkins12: This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, color e…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SamuelAkins12',
#       'name': 'Samuel Akinosho®',
#       'id': 1053247241618685953,
#       'id_str': '1053247241618685953',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2724931139,
#     'id_str': '2724931139',
#     'name': 'mumma smurf 💙❤️💙❤️💙❤️💙',
#     'screen_name': 'MummaSmurf01',
#     'location': ' Stratford upon Avon, England',
#     'description': "I'm a girl. For animal rights, against animal cruelty.",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 177,
#     'friends_count': 501,
#     'listed_count': 3,
#     'created_at': 'Sat Jul 26 06:22:13 +0000 2014',
#     'favourites_count': 22340,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 6551,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/620682727784906752/dgtF-flK_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/620682727784906752/dgtF-flK_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2724931139/1420277000',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 06:26:45 +0000 2020',
#     'id': 1292346561079513090,
#     'id_str': '1292346561079513090',
#     'text': 'This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, co… https://t.co/mZi6wxZMz1',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mZi6wxZMz1',
#        'expanded_url': 'https://twitter.com/i/web/status/1292346561079513090',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1053247241618685953,
#      'id_str': '1053247241618685953',
#      'name': 'Samuel Akinosho®',
#      'screen_name': 'SamuelAkins12',
#      'location': 'Africa ',
#      'description': "Serial Entrepreneur, Ex. @microsoft @cisco |  AI & IoT Engr. | CEH |Passionate about Africa's development 🌍 #MUFC",
#      'url': 'https://t.co/Hzc0CDYj9g',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Hzc0CDYj9g',
#          'expanded_url': 'https://linktr.ee/SamuelAkinosho',
#          'display_url': 'linktr.ee/SamuelAkinosho',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2379,
#      'friends_count': 1622,
#      'listed_count': 8,
#      'created_at': 'Fri Oct 19 11:31:25 +0000 2018',
#      'favourites_count': 29978,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1053247241618685953/1590793590',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 169,
#     'favorite_count': 346,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 169,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:53:18 +0000 2020',
#    'id': 1292383441879801856,
#    'id_str': '1292383441879801856',
#    'text': 'RT @SamuelAkins12: This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, color e…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SamuelAkins12',
#       'name': 'Samuel Akinosho®',
#       'id': 1053247241618685953,
#       'id_str': '1053247241618685953',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 209965204,
#     'id_str': '209965204',
#     'name': 'Ed Sweetman',
#     'screen_name': 'humanpilot',
#     'location': 'England',
#     'description': 'Photographer at Getty, Adobe, Dreamstime and Shutterstock. Illustrator. Bookworm. Cinema. We are in the arena of the absurd.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2835,
#     'friends_count': 2850,
#     'listed_count': 143,
#     'created_at': 'Sat Oct 30 07:46:45 +0000 2010',
#     'favourites_count': 82340,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 33347,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1286400468185501698/swFtPMuO_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1286400468185501698/swFtPMuO_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/209965204/1596664672',
#     'profile_link_color': 'E81C4F',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 06:26:45 +0000 2020',
#     'id': 1292346561079513090,
#     'id_str': '1292346561079513090',
#     'text': 'This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, co… https://t.co/mZi6wxZMz1',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mZi6wxZMz1',
#        'expanded_url': 'https://twitter.com/i/web/status/1292346561079513090',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1053247241618685953,
#      'id_str': '1053247241618685953',
#      'name': 'Samuel Akinosho®',
#      'screen_name': 'SamuelAkins12',
#      'location': 'Africa ',
#      'description': "Serial Entrepreneur, Ex. @microsoft @cisco |  AI & IoT Engr. | CEH |Passionate about Africa's development 🌍 #MUFC",
#      'url': 'https://t.co/Hzc0CDYj9g',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Hzc0CDYj9g',
#          'expanded_url': 'https://linktr.ee/SamuelAkinosho',
#          'display_url': 'linktr.ee/SamuelAkinosho',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2379,
#      'friends_count': 1622,
#      'listed_count': 8,
#      'created_at': 'Fri Oct 19 11:31:25 +0000 2018',
#      'favourites_count': 29978,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1053247241618685953/1590793590',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 169,
#     'favorite_count': 346,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 169,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:53:04 +0000 2020',
#    'id': 1292383382672990208,
#    'id_str': '1292383382672990208',
#    'text': 'RT @IntisarMahee: I just published 5 Stunning Reasons to Learn Python in 2020 https://t.co/oB8QKogCm9 \n.\n.\n.\n.\n.\n.\n.\n#BigData #Analytics #D…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'BigData', 'indices': [117, 125]},
#      {'text': 'Analytics', 'indices': [126, 136]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'IntisarMahee',
#       'name': 'Intisar Mahee',
#       'id': 118302422,
#       'id_str': '118302422',
#       'indices': [3, 16]}],
#     'urls': [{'url': 'https://t.co/oB8QKogCm9',
#       'expanded_url': 'https://link.medium.com/e2PryCRLN8',
#       'display_url': 'link.medium.com/e2PryCRLN8',
#       'indices': [78, 101]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twinybots.com" rel="nofollow">TwinyBots</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1154381411614416906,
#     'id_str': '1154381411614416906',
#     'name': 'Well, that’s interesting tech',
#     'screen_name': '1nterestingTech',
#     'location': 'United Kingdom',
#     'description': 'Life’s too short for boring #tech. I write articles to demystifying tech one example at a time. Themes cover - #Tech4Good #AI #IOT, #5G, and other #EmergingTech',
#     'url': 'https://t.co/r7nD8V7XJX',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/r7nD8V7XJX',
#         'expanded_url': 'http://wellthatsinteresting.tech',
#         'display_url': 'wellthatsinteresting.tech',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 656,
#     'friends_count': 1940,
#     'listed_count': 28,
#     'created_at': 'Thu Jul 25 13:22:30 +0000 2019',
#     'favourites_count': 10344,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 50396,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1154383562088599552/RbyNTvSg_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1154383562088599552/RbyNTvSg_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1154381411614416906/1564600386',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 05:09:01 +0000 2020',
#     'id': 1292326997222281216,
#     'id_str': '1292326997222281216',
#     'text': 'I just published 5 Stunning Reasons to Learn Python in 2020 https://t.co/oB8QKogCm9 \n.\n.\n.\n.\n.\n.\n.\n#BigData… https://t.co/RHG50szYif',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'BigData', 'indices': [99, 107]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/oB8QKogCm9',
#        'expanded_url': 'https://link.medium.com/e2PryCRLN8',
#        'display_url': 'link.medium.com/e2PryCRLN8',
#        'indices': [60, 83]},
#       {'url': 'https://t.co/RHG50szYif',
#        'expanded_url': 'https://twitter.com/i/web/status/1292326997222281216',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [109, 132]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 118302422,
#      'id_str': '118302422',
#      'name': 'Intisar Mahee',
#      'screen_name': 'IntisarMahee',
#      'location': 'Dhaka, Bangladesh',
#      'description': 'Mechatronics Engineer • Digital Marketer • Photographer • Content Writer',
#      'url': 'https://t.co/8tp3sKETaI',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/8tp3sKETaI',
#          'expanded_url': 'https://intisar-mahee.weebly.com/',
#          'display_url': 'intisar-mahee.weebly.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 20,
#      'friends_count': 25,
#      'listed_count': 0,
#      'created_at': 'Sun Feb 28 06:48:51 +0000 2010',
#      'favourites_count': 30,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 39,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1270697402912014337/VhYIU6XU_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1270697402912014337/VhYIU6XU_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/118302422/1594223839',
#      'profile_link_color': '19CF86',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 32,
#     'favorite_count': 18,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 32,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:52:53 +0000 2020',
#    'id': 1292383338267848704,
#    'id_str': '1292383338267848704',
#    'text': 'RT @KirkDBorne: Here are some of my favorite books &amp; things: https://t.co/fmHsJvad9P\n...covering #BigData #DataScience #AI #Bots #MachineLe…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'BigData', 'indices': [101, 109]},
#      {'text': 'DataScience', 'indices': [110, 122]},
#      {'text': 'AI', 'indices': [123, 126]},
#      {'text': 'Bots', 'indices': [127, 132]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'KirkDBorne',
#       'name': 'Kirk Borne',
#       'id': 534563976,
#       'id_str': '534563976',
#       'indices': [3, 14]}],
#     'urls': [{'url': 'https://t.co/fmHsJvad9P',
#       'expanded_url': 'https://bit.ly/2WcVqzo',
#       'display_url': 'bit.ly/2WcVqzo',
#       'indices': [65, 88]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 934812420,
#     'id_str': '934812420',
#     'name': 'Naeem Zafar',
#     'screen_name': 'Naeem_Zaffar',
#     'location': 'Lahore, Pakistan',
#     'description': "UET, Engineer, \nThe truth is hard to swallow when you're choking on your Pride.",
#     'url': 'https://t.co/HLYVaUHL3m',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/HLYVaUHL3m',
#         'expanded_url': 'http://www.facebook.com/naem.zafar',
#         'display_url': 'facebook.com/naem.zafar',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 49,
#     'friends_count': 279,
#     'listed_count': 1,
#     'created_at': 'Thu Nov 08 15:59:23 +0000 2012',
#     'favourites_count': 68,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 101,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/895610248135942145/qFXEReIp_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/895610248135942145/qFXEReIp_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/934812420/1439813592',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 05:02:35 +0000 2020',
#     'id': 1292325381295558656,
#     'id_str': '1292325381295558656',
#     'text': 'Here are some of my favorite books &amp; things: https://t.co/fmHsJvad9P\n...covering #BigData #DataScience #AI #Bots… https://t.co/cC8QR8yNh9',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'BigData', 'indices': [85, 93]},
#       {'text': 'DataScience', 'indices': [94, 106]},
#       {'text': 'AI', 'indices': [107, 110]},
#       {'text': 'Bots', 'indices': [111, 116]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/fmHsJvad9P',
#        'expanded_url': 'https://bit.ly/2WcVqzo',
#        'display_url': 'bit.ly/2WcVqzo',
#        'indices': [49, 72]},
#       {'url': 'https://t.co/cC8QR8yNh9',
#        'expanded_url': 'https://twitter.com/i/web/status/1292325381295558656',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [118, 141]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
# ...
#          'display_url': 'linktr.ee/SamuelAkinosho',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2379,
#      'friends_count': 1622,
#      'listed_count': 8,
#      'created_at': 'Fri Oct 19 11:31:25 +0000 2018',
#      'favourites_count': 29978,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1053247241618685953/1590793590',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 169,
#     'favorite_count': 346,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 169,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:42:04 +0000 2020',
#    'id': 1292380613304037377,
#    'id_str': '1292380613304037377',
#    'text': 'RT @_asifbhat_: Before we put $100 billion into AI … https://t.co/9arrtge7vP\n\n#ArtificialIntelligence #AI #DataScience #MachineLearning\xa0 #D…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'ArtificialIntelligence',
#       'indices': [78, 101]},
#      {'text': 'AI', 'indices': [102, 105]},
#      {'text': 'DataScience', 'indices': [106, 118]},
#      {'text': 'MachineLearning', 'indices': [119, 135]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': '_asifbhat_',
#       'name': 'Asif Bhat',
#       'id': 1170802004655894528,
#       'id_str': '1170802004655894528',
#       'indices': [3, 14]}],
#     'urls': [{'url': 'https://t.co/9arrtge7vP',
#       'expanded_url': 'https://venturebeat.com/2020/08/08/before-we-put-100-billion-into-ai/',
#       'display_url': 'venturebeat.com/2020/08/08/bef…',
#       'indices': [53, 76]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://www.calcaware.com/" rel="nofollow">Calcaware</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 709564705304498176,
#     'id_str': '709564705304498176',
#     'name': 'Christopher Burnette',
#     'screen_name': 'Calcaware',
#     'location': 'Austin, TX',
#     'description': 'https://t.co/xMjqdfEYQu',
#     'url': 'https://t.co/7ekOVPTWDa',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/7ekOVPTWDa',
#         'expanded_url': 'https://www.calcaware.com/',
#         'display_url': 'calcaware.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/xMjqdfEYQu',
#         'expanded_url': 'https://www.calcaware.com',
#         'display_url': 'calcaware.com',
#         'indices': [0, 23]}]}},
#     'protected': False,
#     'followers_count': 8092,
#     'friends_count': 385,
#     'listed_count': 623,
#     'created_at': 'Tue Mar 15 02:19:43 +0000 2016',
#     'favourites_count': 115214,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 494678,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '031116',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1251314003629965314/LgyiBrv9_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1251314003629965314/LgyiBrv9_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/709564705304498176/1587171374',
#     'profile_link_color': '4D70FF',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 08:05:03 +0000 2020',
#     'id': 1292371300904820737,
#     'id_str': '1292371300904820737',
#     'text': 'Before we put $100 billion into AI … https://t.co/9arrtge7vP\n\n#ArtificialIntelligence #AI #DataScience… https://t.co/OJBw4rIpfW',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'ArtificialIntelligence',
#        'indices': [62, 85]},
#       {'text': 'AI', 'indices': [86, 89]},
#       {'text': 'DataScience', 'indices': [90, 102]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/9arrtge7vP',
#        'expanded_url': 'https://venturebeat.com/2020/08/08/before-we-put-100-billion-into-ai/',
#        'display_url': 'venturebeat.com/2020/08/08/bef…',
#        'indices': [37, 60]},
#       {'url': 'https://t.co/OJBw4rIpfW',
#        'expanded_url': 'https://twitter.com/i/web/status/1292371300904820737',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [104, 127]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1170802004655894528,
#      'id_str': '1170802004655894528',
#      'name': 'Asif Bhat',
#      'screen_name': '_asifbhat_',
#      'location': 'Pune, India',
#      'description': 'Data Analyst , SAP BI ,YellowFin BI , Python ,Docker , Kubernetes | Interests - #datascience #machinelearning #deeplearning #AI #Robotics #BusinessIntelligence',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1478,
#      'friends_count': 231,
#      'listed_count': 16,
#      'created_at': 'Sun Sep 08 20:52:22 +0000 2019',
#      'favourites_count': 163,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 3308,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1170802393077780480/l2yBVnxv_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1170802393077780480/l2yBVnxv_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1170802004655894528/1586775929',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:41:56 +0000 2020',
#    'id': 1292380583302033408,
#    'id_str': '1292380583302033408',
#    'text': 'RT @_asifbhat_: Before we put $100 billion into AI … https://t.co/9arrtge7vP\n\n#ArtificialIntelligence #AI #DataScience #MachineLearning\xa0 #D…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'ArtificialIntelligence',
#       'indices': [78, 101]},
#      {'text': 'AI', 'indices': [102, 105]},
#      {'text': 'DataScience', 'indices': [106, 118]},
#      {'text': 'MachineLearning', 'indices': [119, 135]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': '_asifbhat_',
#       'name': 'Asif Bhat',
#       'id': 1170802004655894528,
#       'id_str': '1170802004655894528',
#       'indices': [3, 14]}],
#     'urls': [{'url': 'https://t.co/9arrtge7vP',
#       'expanded_url': 'https://venturebeat.com/2020/08/08/before-we-put-100-billion-into-ai/',
#       'display_url': 'venturebeat.com/2020/08/08/bef…',
#       'indices': [53, 76]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 737142202481016832,
#     'id_str': '737142202481016832',
#     'name': 'Chidambara .ML.',
#     'screen_name': 'chidambara09',
#     'location': 'Mysore  and  BERLIN',
#     'description': 'Be happy  Be healthy Be smile Be cool Be good human',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 7123,
#     'friends_count': 13,
#     'listed_count': 4427,
#     'created_at': 'Mon May 30 04:42:51 +0000 2016',
#     'favourites_count': 193,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 1099614,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/760774125522518016/jhzjWv0i_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/760774125522518016/jhzjWv0i_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/737142202481016832/1538216794',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 08:05:03 +0000 2020',
#     'id': 1292371300904820737,
#     'id_str': '1292371300904820737',
#     'text': 'Before we put $100 billion into AI … https://t.co/9arrtge7vP\n\n#ArtificialIntelligence #AI #DataScience… https://t.co/OJBw4rIpfW',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'ArtificialIntelligence',
#        'indices': [62, 85]},
#       {'text': 'AI', 'indices': [86, 89]},
#       {'text': 'DataScience', 'indices': [90, 102]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/9arrtge7vP',
#        'expanded_url': 'https://venturebeat.com/2020/08/08/before-we-put-100-billion-into-ai/',
#        'display_url': 'venturebeat.com/2020/08/08/bef…',
#        'indices': [37, 60]},
#       {'url': 'https://t.co/OJBw4rIpfW',
#        'expanded_url': 'https://twitter.com/i/web/status/1292371300904820737',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [104, 127]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1170802004655894528,
#      'id_str': '1170802004655894528',
#      'name': 'Asif Bhat',
#      'screen_name': '_asifbhat_',
#      'location': 'Pune, India',
#      'description': 'Data Analyst , SAP BI ,YellowFin BI , Python ,Docker , Kubernetes | Interests - #datascience #machinelearning #deeplearning #AI #Robotics #BusinessIntelligence',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1478,
#      'friends_count': 231,
#      'listed_count': 16,
#      'created_at': 'Sun Sep 08 20:52:22 +0000 2019',
#      'favourites_count': 163,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 3308,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1170802393077780480/l2yBVnxv_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1170802393077780480/l2yBVnxv_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1170802004655894528/1586775929',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.129,
#   'max_id': 1292383496636424193,
#   'max_id_str': '1292383496636424193',
#   'next_results': '?max_id=1292380583302033407&q=%23deeplearning&count=75&include_entities=1',
#   'query': '%23deeplearning',
#   'refresh_url': '?since_id=1292383496636424193&q=%23deeplearning&include_entities=1',
#   'count': 75,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# Try adding a second parameter.  You can find the list here:  https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets

# %%
url ='https://api.twitter.com/1.1/search/tweets.json?q=%23deeplearning&count=75&result_type=recent'
deeplearn=requests.get(url,auth=auth).json()

# %%
deeplearn
# Out:
# {'statuses': [{'created_at': 'Sun Aug 09 08:53:31 +0000 2020',
#    'id': 1292383496636424193,
#    'id_str': '1292383496636424193',
#    'text': 'RT @SamuelAkins12: This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, color e…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SamuelAkins12',
#       'name': 'Samuel Akinosho®',
#       'id': 1053247241618685953,
#       'id_str': '1053247241618685953',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 22000414,
#     'id_str': '22000414',
#     'name': 'Kiwi Paul',
#     'screen_name': 'squashypigeon',
#     'location': 'London, Europe.',
#     'description': 'Grumpy bipedal mammal, 70% water (ish). Homesick Kiwi. Atheist. Foodie.\nCAD, Bushcraft, Space, Homebrew, BBQ, Kites, Making, Eco, Self-sufficiency.\nI RT a LOT!',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 815,
#     'friends_count': 1809,
#     'listed_count': 49,
#     'created_at': 'Thu Feb 26 11:44:14 +0000 2009',
#     'favourites_count': 61588,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 49558,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '510800',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1051607371410227200/k-dFRFay_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1051607371410227200/k-dFRFay_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/22000414/1374073359',
#     'profile_link_color': 'E0912A',
#     'profile_sidebar_border_color': '3D0702',
#     'profile_sidebar_fill_color': '2C1703',
#     'profile_text_color': 'A16A23',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 06:26:45 +0000 2020',
#     'id': 1292346561079513090,
#     'id_str': '1292346561079513090',
#     'text': 'This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, co… https://t.co/mZi6wxZMz1',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mZi6wxZMz1',
#        'expanded_url': 'https://twitter.com/i/web/status/1292346561079513090',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1053247241618685953,
#      'id_str': '1053247241618685953',
#      'name': 'Samuel Akinosho®',
#      'screen_name': 'SamuelAkins12',
#      'location': 'Africa ',
#      'description': "Serial Entrepreneur, Ex. @microsoft @cisco |  AI & IoT Engr. | CEH |Passionate about Africa's development 🌍 #MUFC",
#      'url': 'https://t.co/Hzc0CDYj9g',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Hzc0CDYj9g',
#          'expanded_url': 'https://linktr.ee/SamuelAkinosho',
#          'display_url': 'linktr.ee/SamuelAkinosho',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2379,
#      'friends_count': 1622,
#      'listed_count': 8,
#      'created_at': 'Fri Oct 19 11:31:25 +0000 2018',
#      'favourites_count': 29978,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1053247241618685953/1590793590',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 169,
#     'favorite_count': 346,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 169,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:53:29 +0000 2020',
#    'id': 1292383488642080770,
#    'id_str': '1292383488642080770',
#    'text': 'RT @SamuelAkins12: This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, color e…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SamuelAkins12',
#       'name': 'Samuel Akinosho®',
#       'id': 1053247241618685953,
#       'id_str': '1053247241618685953',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 989752852112293889,
#     'id_str': '989752852112293889',
#     'name': 'Chad Clifton',
#     'screen_name': 'ChadClifton10',
#     'location': 'South West, England',
#     'description': '#FBPE \n\nMorality has never been a huge part of humanity - @missusbojangles',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 214,
#     'friends_count': 747,
#     'listed_count': 2,
#     'created_at': 'Fri Apr 27 06:27:23 +0000 2018',
#     'favourites_count': 4101,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 5027,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1208500687153356806/6Xyv2uSf_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1208500687153356806/6Xyv2uSf_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/989752852112293889/1546551542',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 06:26:45 +0000 2020',
#     'id': 1292346561079513090,
#     'id_str': '1292346561079513090',
#     'text': 'This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, co… https://t.co/mZi6wxZMz1',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mZi6wxZMz1',
#        'expanded_url': 'https://twitter.com/i/web/status/1292346561079513090',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1053247241618685953,
#      'id_str': '1053247241618685953',
#      'name': 'Samuel Akinosho®',
#      'screen_name': 'SamuelAkins12',
#      'location': 'Africa ',
#      'description': "Serial Entrepreneur, Ex. @microsoft @cisco |  AI & IoT Engr. | CEH |Passionate about Africa's development 🌍 #MUFC",
#      'url': 'https://t.co/Hzc0CDYj9g',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Hzc0CDYj9g',
#          'expanded_url': 'https://linktr.ee/SamuelAkinosho',
#          'display_url': 'linktr.ee/SamuelAkinosho',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2379,
#      'friends_count': 1622,
#      'listed_count': 8,
#      'created_at': 'Fri Oct 19 11:31:25 +0000 2018',
#      'favourites_count': 29978,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1053247241618685953/1590793590',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 169,
#     'favorite_count': 346,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 169,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:53:23 +0000 2020',
#    'id': 1292383461664346112,
#    'id_str': '1292383461664346112',
#    'text': 'RT @SamuelAkins12: This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, color e…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SamuelAkins12',
#       'name': 'Samuel Akinosho®',
#       'id': 1053247241618685953,
#       'id_str': '1053247241618685953',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 63523564,
#     'id_str': '63523564',
#     'name': 'Chris',
#     'screen_name': 'chrishughesuk',
#     'location': 'England',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 437,
#     'friends_count': 1106,
#     'listed_count': 9,
#     'created_at': 'Thu Aug 06 19:56:34 +0000 2009',
#     'favourites_count': 2213,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 1002,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1285961035585859586/tCXBFXbe_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1285961035585859586/tCXBFXbe_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 06:26:45 +0000 2020',
#     'id': 1292346561079513090,
#     'id_str': '1292346561079513090',
#     'text': 'This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, co… https://t.co/mZi6wxZMz1',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mZi6wxZMz1',
#        'expanded_url': 'https://twitter.com/i/web/status/1292346561079513090',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1053247241618685953,
#      'id_str': '1053247241618685953',
#      'name': 'Samuel Akinosho®',
#      'screen_name': 'SamuelAkins12',
#      'location': 'Africa ',
#      'description': "Serial Entrepreneur, Ex. @microsoft @cisco |  AI & IoT Engr. | CEH |Passionate about Africa's development 🌍 #MUFC",
#      'url': 'https://t.co/Hzc0CDYj9g',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Hzc0CDYj9g',
#          'expanded_url': 'https://linktr.ee/SamuelAkinosho',
#          'display_url': 'linktr.ee/SamuelAkinosho',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2379,
#      'friends_count': 1622,
#      'listed_count': 8,
#      'created_at': 'Fri Oct 19 11:31:25 +0000 2018',
#      'favourites_count': 29978,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1053247241618685953/1590793590',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 169,
#     'favorite_count': 346,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 169,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:53:21 +0000 2020',
#    'id': 1292383455989379073,
#    'id_str': '1292383455989379073',
#    'text': 'RT @SamuelAkins12: This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, color e…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SamuelAkins12',
#       'name': 'Samuel Akinosho®',
#       'id': 1053247241618685953,
#       'id_str': '1053247241618685953',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 26011538,
#     'id_str': '26011538',
#     'name': 'SallyfortheEU 3.5% #RejoinEU #FBPE',
#     'screen_name': 'sallydipple',
#     'location': 'Wirksworth, England',
#     'description': 'You can take the girl out of the EU but you can’t take the EU out of the girl. #RemainersWereRight',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3124,
#     'friends_count': 3111,
#     'listed_count': 19,
#     'created_at': 'Mon Mar 23 14:34:59 +0000 2009',
#     'favourites_count': 92882,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 87347,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'DBE9ED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme17/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme17/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1167001895866687488/_0_9u0Pk_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1167001895866687488/_0_9u0Pk_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/26011538/1567069909',
#     'profile_link_color': 'FF691F',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 06:26:45 +0000 2020',
#     'id': 1292346561079513090,
#     'id_str': '1292346561079513090',
#     'text': 'This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, co… https://t.co/mZi6wxZMz1',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mZi6wxZMz1',
#        'expanded_url': 'https://twitter.com/i/web/status/1292346561079513090',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1053247241618685953,
#      'id_str': '1053247241618685953',
#      'name': 'Samuel Akinosho®',
#      'screen_name': 'SamuelAkins12',
#      'location': 'Africa ',
#      'description': "Serial Entrepreneur, Ex. @microsoft @cisco |  AI & IoT Engr. | CEH |Passionate about Africa's development 🌍 #MUFC",
#      'url': 'https://t.co/Hzc0CDYj9g',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Hzc0CDYj9g',
#          'expanded_url': 'https://linktr.ee/SamuelAkinosho',
#          'display_url': 'linktr.ee/SamuelAkinosho',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2379,
#      'friends_count': 1622,
#      'listed_count': 8,
#      'created_at': 'Fri Oct 19 11:31:25 +0000 2018',
#      'favourites_count': 29978,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1053247241618685953/1590793590',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 169,
#     'favorite_count': 346,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 169,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:53:20 +0000 2020',
#    'id': 1292383448229961730,
#    'id_str': '1292383448229961730',
#    'text': 'RT @SamuelAkins12: This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, color e…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SamuelAkins12',
#       'name': 'Samuel Akinosho®',
#       'id': 1053247241618685953,
#       'id_str': '1053247241618685953',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2724931139,
#     'id_str': '2724931139',
#     'name': 'mumma smurf 💙❤️💙❤️💙❤️💙',
#     'screen_name': 'MummaSmurf01',
#     'location': ' Stratford upon Avon, England',
#     'description': "I'm a girl. For animal rights, against animal cruelty.",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 177,
#     'friends_count': 501,
#     'listed_count': 3,
#     'created_at': 'Sat Jul 26 06:22:13 +0000 2014',
#     'favourites_count': 22340,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 6551,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/620682727784906752/dgtF-flK_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/620682727784906752/dgtF-flK_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2724931139/1420277000',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 06:26:45 +0000 2020',
#     'id': 1292346561079513090,
#     'id_str': '1292346561079513090',
#     'text': 'This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, co… https://t.co/mZi6wxZMz1',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mZi6wxZMz1',
#        'expanded_url': 'https://twitter.com/i/web/status/1292346561079513090',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1053247241618685953,
#      'id_str': '1053247241618685953',
#      'name': 'Samuel Akinosho®',
#      'screen_name': 'SamuelAkins12',
#      'location': 'Africa ',
#      'description': "Serial Entrepreneur, Ex. @microsoft @cisco |  AI & IoT Engr. | CEH |Passionate about Africa's development 🌍 #MUFC",
#      'url': 'https://t.co/Hzc0CDYj9g',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Hzc0CDYj9g',
#          'expanded_url': 'https://linktr.ee/SamuelAkinosho',
#          'display_url': 'linktr.ee/SamuelAkinosho',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2379,
#      'friends_count': 1622,
#      'listed_count': 8,
#      'created_at': 'Fri Oct 19 11:31:25 +0000 2018',
#      'favourites_count': 29978,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1053247241618685953/1590793590',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 169,
#     'favorite_count': 346,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 169,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:53:18 +0000 2020',
#    'id': 1292383441879801856,
#    'id_str': '1292383441879801856',
#    'text': 'RT @SamuelAkins12: This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, color e…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SamuelAkins12',
#       'name': 'Samuel Akinosho®',
#       'id': 1053247241618685953,
#       'id_str': '1053247241618685953',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 209965204,
#     'id_str': '209965204',
#     'name': 'Ed Sweetman',
#     'screen_name': 'humanpilot',
#     'location': 'England',
#     'description': 'Photographer at Getty, Adobe, Dreamstime and Shutterstock. Illustrator. Bookworm. Cinema. We are in the arena of the absurd.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2835,
#     'friends_count': 2850,
#     'listed_count': 143,
#     'created_at': 'Sat Oct 30 07:46:45 +0000 2010',
#     'favourites_count': 82340,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 33347,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1286400468185501698/swFtPMuO_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1286400468185501698/swFtPMuO_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/209965204/1596664672',
#     'profile_link_color': 'E81C4F',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 06:26:45 +0000 2020',
#     'id': 1292346561079513090,
#     'id_str': '1292346561079513090',
#     'text': 'This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, co… https://t.co/mZi6wxZMz1',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mZi6wxZMz1',
#        'expanded_url': 'https://twitter.com/i/web/status/1292346561079513090',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1053247241618685953,
#      'id_str': '1053247241618685953',
#      'name': 'Samuel Akinosho®',
#      'screen_name': 'SamuelAkins12',
#      'location': 'Africa ',
#      'description': "Serial Entrepreneur, Ex. @microsoft @cisco |  AI & IoT Engr. | CEH |Passionate about Africa's development 🌍 #MUFC",
#      'url': 'https://t.co/Hzc0CDYj9g',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Hzc0CDYj9g',
#          'expanded_url': 'https://linktr.ee/SamuelAkinosho',
#          'display_url': 'linktr.ee/SamuelAkinosho',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2379,
#      'friends_count': 1622,
#      'listed_count': 8,
#      'created_at': 'Fri Oct 19 11:31:25 +0000 2018',
#      'favourites_count': 29978,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1053247241618685953/1590793590',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 169,
#     'favorite_count': 346,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 169,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:53:04 +0000 2020',
#    'id': 1292383382672990208,
#    'id_str': '1292383382672990208',
#    'text': 'RT @IntisarMahee: I just published 5 Stunning Reasons to Learn Python in 2020 https://t.co/oB8QKogCm9 \n.\n.\n.\n.\n.\n.\n.\n#BigData #Analytics #D…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'BigData', 'indices': [117, 125]},
#      {'text': 'Analytics', 'indices': [126, 136]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'IntisarMahee',
#       'name': 'Intisar Mahee',
#       'id': 118302422,
#       'id_str': '118302422',
#       'indices': [3, 16]}],
#     'urls': [{'url': 'https://t.co/oB8QKogCm9',
#       'expanded_url': 'https://link.medium.com/e2PryCRLN8',
#       'display_url': 'link.medium.com/e2PryCRLN8',
#       'indices': [78, 101]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twinybots.com" rel="nofollow">TwinyBots</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1154381411614416906,
#     'id_str': '1154381411614416906',
#     'name': 'Well, that’s interesting tech',
#     'screen_name': '1nterestingTech',
#     'location': 'United Kingdom',
#     'description': 'Life’s too short for boring #tech. I write articles to demystifying tech one example at a time. Themes cover - #Tech4Good #AI #IOT, #5G, and other #EmergingTech',
#     'url': 'https://t.co/r7nD8V7XJX',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/r7nD8V7XJX',
#         'expanded_url': 'http://wellthatsinteresting.tech',
#         'display_url': 'wellthatsinteresting.tech',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 656,
#     'friends_count': 1940,
#     'listed_count': 28,
#     'created_at': 'Thu Jul 25 13:22:30 +0000 2019',
#     'favourites_count': 10344,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 50396,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1154383562088599552/RbyNTvSg_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1154383562088599552/RbyNTvSg_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1154381411614416906/1564600386',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 05:09:01 +0000 2020',
#     'id': 1292326997222281216,
#     'id_str': '1292326997222281216',
#     'text': 'I just published 5 Stunning Reasons to Learn Python in 2020 https://t.co/oB8QKogCm9 \n.\n.\n.\n.\n.\n.\n.\n#BigData… https://t.co/RHG50szYif',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'BigData', 'indices': [99, 107]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/oB8QKogCm9',
#        'expanded_url': 'https://link.medium.com/e2PryCRLN8',
#        'display_url': 'link.medium.com/e2PryCRLN8',
#        'indices': [60, 83]},
#       {'url': 'https://t.co/RHG50szYif',
#        'expanded_url': 'https://twitter.com/i/web/status/1292326997222281216',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [109, 132]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 118302422,
#      'id_str': '118302422',
#      'name': 'Intisar Mahee',
#      'screen_name': 'IntisarMahee',
#      'location': 'Dhaka, Bangladesh',
#      'description': 'Mechatronics Engineer • Digital Marketer • Photographer • Content Writer',
#      'url': 'https://t.co/8tp3sKETaI',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/8tp3sKETaI',
#          'expanded_url': 'https://intisar-mahee.weebly.com/',
#          'display_url': 'intisar-mahee.weebly.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 20,
#      'friends_count': 25,
#      'listed_count': 0,
#      'created_at': 'Sun Feb 28 06:48:51 +0000 2010',
#      'favourites_count': 30,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 39,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1270697402912014337/VhYIU6XU_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1270697402912014337/VhYIU6XU_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/118302422/1594223839',
#      'profile_link_color': '19CF86',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 32,
#     'favorite_count': 18,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 32,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:52:53 +0000 2020',
#    'id': 1292383338267848704,
#    'id_str': '1292383338267848704',
#    'text': 'RT @KirkDBorne: Here are some of my favorite books &amp; things: https://t.co/fmHsJvad9P\n...covering #BigData #DataScience #AI #Bots #MachineLe…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'BigData', 'indices': [101, 109]},
#      {'text': 'DataScience', 'indices': [110, 122]},
#      {'text': 'AI', 'indices': [123, 126]},
#      {'text': 'Bots', 'indices': [127, 132]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'KirkDBorne',
#       'name': 'Kirk Borne',
#       'id': 534563976,
#       'id_str': '534563976',
#       'indices': [3, 14]}],
#     'urls': [{'url': 'https://t.co/fmHsJvad9P',
#       'expanded_url': 'https://bit.ly/2WcVqzo',
#       'display_url': 'bit.ly/2WcVqzo',
#       'indices': [65, 88]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 934812420,
#     'id_str': '934812420',
#     'name': 'Naeem Zafar',
#     'screen_name': 'Naeem_Zaffar',
#     'location': 'Lahore, Pakistan',
#     'description': "UET, Engineer, \nThe truth is hard to swallow when you're choking on your Pride.",
#     'url': 'https://t.co/HLYVaUHL3m',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/HLYVaUHL3m',
#         'expanded_url': 'http://www.facebook.com/naem.zafar',
#         'display_url': 'facebook.com/naem.zafar',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 49,
#     'friends_count': 279,
#     'listed_count': 1,
#     'created_at': 'Thu Nov 08 15:59:23 +0000 2012',
#     'favourites_count': 68,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 101,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/895610248135942145/qFXEReIp_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/895610248135942145/qFXEReIp_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/934812420/1439813592',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 05:02:35 +0000 2020',
#     'id': 1292325381295558656,
#     'id_str': '1292325381295558656',
#     'text': 'Here are some of my favorite books &amp; things: https://t.co/fmHsJvad9P\n...covering #BigData #DataScience #AI #Bots… https://t.co/cC8QR8yNh9',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'BigData', 'indices': [85, 93]},
#       {'text': 'DataScience', 'indices': [94, 106]},
#       {'text': 'AI', 'indices': [107, 110]},
#       {'text': 'Bots', 'indices': [111, 116]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/fmHsJvad9P',
#        'expanded_url': 'https://bit.ly/2WcVqzo',
#        'display_url': 'bit.ly/2WcVqzo',
#        'indices': [49, 72]},
#       {'url': 'https://t.co/cC8QR8yNh9',
#        'expanded_url': 'https://twitter.com/i/web/status/1292325381295558656',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [118, 141]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
# ...
#          'display_url': 'linktr.ee/SamuelAkinosho',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2379,
#      'friends_count': 1622,
#      'listed_count': 8,
#      'created_at': 'Fri Oct 19 11:31:25 +0000 2018',
#      'favourites_count': 29978,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1053247241618685953/1590793590',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 169,
#     'favorite_count': 346,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 169,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:42:04 +0000 2020',
#    'id': 1292380613304037377,
#    'id_str': '1292380613304037377',
#    'text': 'RT @_asifbhat_: Before we put $100 billion into AI … https://t.co/9arrtge7vP\n\n#ArtificialIntelligence #AI #DataScience #MachineLearning\xa0 #D…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'ArtificialIntelligence',
#       'indices': [78, 101]},
#      {'text': 'AI', 'indices': [102, 105]},
#      {'text': 'DataScience', 'indices': [106, 118]},
#      {'text': 'MachineLearning', 'indices': [119, 135]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': '_asifbhat_',
#       'name': 'Asif Bhat',
#       'id': 1170802004655894528,
#       'id_str': '1170802004655894528',
#       'indices': [3, 14]}],
#     'urls': [{'url': 'https://t.co/9arrtge7vP',
#       'expanded_url': 'https://venturebeat.com/2020/08/08/before-we-put-100-billion-into-ai/',
#       'display_url': 'venturebeat.com/2020/08/08/bef…',
#       'indices': [53, 76]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://www.calcaware.com/" rel="nofollow">Calcaware</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 709564705304498176,
#     'id_str': '709564705304498176',
#     'name': 'Christopher Burnette',
#     'screen_name': 'Calcaware',
#     'location': 'Austin, TX',
#     'description': 'https://t.co/xMjqdfEYQu',
#     'url': 'https://t.co/7ekOVPTWDa',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/7ekOVPTWDa',
#         'expanded_url': 'https://www.calcaware.com/',
#         'display_url': 'calcaware.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/xMjqdfEYQu',
#         'expanded_url': 'https://www.calcaware.com',
#         'display_url': 'calcaware.com',
#         'indices': [0, 23]}]}},
#     'protected': False,
#     'followers_count': 8092,
#     'friends_count': 385,
#     'listed_count': 623,
#     'created_at': 'Tue Mar 15 02:19:43 +0000 2016',
#     'favourites_count': 115214,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 494678,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '031116',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1251314003629965314/LgyiBrv9_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1251314003629965314/LgyiBrv9_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/709564705304498176/1587171374',
#     'profile_link_color': '4D70FF',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 08:05:03 +0000 2020',
#     'id': 1292371300904820737,
#     'id_str': '1292371300904820737',
#     'text': 'Before we put $100 billion into AI … https://t.co/9arrtge7vP\n\n#ArtificialIntelligence #AI #DataScience… https://t.co/OJBw4rIpfW',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'ArtificialIntelligence',
#        'indices': [62, 85]},
#       {'text': 'AI', 'indices': [86, 89]},
#       {'text': 'DataScience', 'indices': [90, 102]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/9arrtge7vP',
#        'expanded_url': 'https://venturebeat.com/2020/08/08/before-we-put-100-billion-into-ai/',
#        'display_url': 'venturebeat.com/2020/08/08/bef…',
#        'indices': [37, 60]},
#       {'url': 'https://t.co/OJBw4rIpfW',
#        'expanded_url': 'https://twitter.com/i/web/status/1292371300904820737',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [104, 127]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1170802004655894528,
#      'id_str': '1170802004655894528',
#      'name': 'Asif Bhat',
#      'screen_name': '_asifbhat_',
#      'location': 'Pune, India',
#      'description': 'Data Analyst , SAP BI ,YellowFin BI , Python ,Docker , Kubernetes | Interests - #datascience #machinelearning #deeplearning #AI #Robotics #BusinessIntelligence',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1478,
#      'friends_count': 231,
#      'listed_count': 16,
#      'created_at': 'Sun Sep 08 20:52:22 +0000 2019',
#      'favourites_count': 163,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 3308,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1170802393077780480/l2yBVnxv_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1170802393077780480/l2yBVnxv_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1170802004655894528/1586775929',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:41:56 +0000 2020',
#    'id': 1292380583302033408,
#    'id_str': '1292380583302033408',
#    'text': 'RT @_asifbhat_: Before we put $100 billion into AI … https://t.co/9arrtge7vP\n\n#ArtificialIntelligence #AI #DataScience #MachineLearning\xa0 #D…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'ArtificialIntelligence',
#       'indices': [78, 101]},
#      {'text': 'AI', 'indices': [102, 105]},
#      {'text': 'DataScience', 'indices': [106, 118]},
#      {'text': 'MachineLearning', 'indices': [119, 135]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': '_asifbhat_',
#       'name': 'Asif Bhat',
#       'id': 1170802004655894528,
#       'id_str': '1170802004655894528',
#       'indices': [3, 14]}],
#     'urls': [{'url': 'https://t.co/9arrtge7vP',
#       'expanded_url': 'https://venturebeat.com/2020/08/08/before-we-put-100-billion-into-ai/',
#       'display_url': 'venturebeat.com/2020/08/08/bef…',
#       'indices': [53, 76]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 737142202481016832,
#     'id_str': '737142202481016832',
#     'name': 'Chidambara .ML.',
#     'screen_name': 'chidambara09',
#     'location': 'Mysore  and  BERLIN',
#     'description': 'Be happy  Be healthy Be smile Be cool Be good human',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 7123,
#     'friends_count': 13,
#     'listed_count': 4427,
#     'created_at': 'Mon May 30 04:42:51 +0000 2016',
#     'favourites_count': 193,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 1099614,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/760774125522518016/jhzjWv0i_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/760774125522518016/jhzjWv0i_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/737142202481016832/1538216794',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 08:05:03 +0000 2020',
#     'id': 1292371300904820737,
#     'id_str': '1292371300904820737',
#     'text': 'Before we put $100 billion into AI … https://t.co/9arrtge7vP\n\n#ArtificialIntelligence #AI #DataScience… https://t.co/OJBw4rIpfW',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'ArtificialIntelligence',
#        'indices': [62, 85]},
#       {'text': 'AI', 'indices': [86, 89]},
#       {'text': 'DataScience', 'indices': [90, 102]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/9arrtge7vP',
#        'expanded_url': 'https://venturebeat.com/2020/08/08/before-we-put-100-billion-into-ai/',
#        'display_url': 'venturebeat.com/2020/08/08/bef…',
#        'indices': [37, 60]},
#       {'url': 'https://t.co/OJBw4rIpfW',
#        'expanded_url': 'https://twitter.com/i/web/status/1292371300904820737',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [104, 127]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1170802004655894528,
#      'id_str': '1170802004655894528',
#      'name': 'Asif Bhat',
#      'screen_name': '_asifbhat_',
#      'location': 'Pune, India',
#      'description': 'Data Analyst , SAP BI ,YellowFin BI , Python ,Docker , Kubernetes | Interests - #datascience #machinelearning #deeplearning #AI #Robotics #BusinessIntelligence',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1478,
#      'friends_count': 231,
#      'listed_count': 16,
#      'created_at': 'Sun Sep 08 20:52:22 +0000 2019',
#      'favourites_count': 163,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 3308,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1170802393077780480/l2yBVnxv_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1170802393077780480/l2yBVnxv_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1170802004655894528/1586775929',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.133,
#   'max_id': 1292383496636424193,
#   'max_id_str': '1292383496636424193',
#   'next_results': '?max_id=1292380583302033407&q=%23deeplearning&count=75&include_entities=1&result_type=recent',
#   'query': '%23deeplearning',
#   'refresh_url': '?since_id=1292383496636424193&q=%23deeplearning&result_type=recent&include_entities=1',
#   'count': 75,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# ## Section 3: Searching Users

# %% [markdown]
# The last section of the API you'll need to get the hang of before you're let loose is the users API, which allows you to search for users and get their followers, friends, etc, as opposed to tweets which fit a particular criteria.  This part is pretty similar to the advanced lab in class 3, so if you saw how that worked then you shouldn't need much instruction.
#
# But if you're seeing this with fresh eyes, you'll want to spend 15-20 minutes to make sure you understand this part.
#
# Official documentation can be found here:  https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/overview
#
# So, as an example, if you want to get a list of someone's followers, you use the base url `https://api.twitter.com/1.1/followers/list.json` and then enter your query string to get a list of that person's followers.
#
# List of parameters to use can be found here:  https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/api-reference/get-followers-list
#
# One possible parameter to use is `screen_name`, so if you wanted to get a list of someone's followers based on their screen name (the handle that begins with an @), then you would set up your API call to look something like:
#
# `https://api.twitter.com/1.1/followers/list.json?screen_name=persons_screenname`
#
# Note that you exclude the `@`.
#
# **Your turn:** Pull in the list of General Assembly's followers.  General Assembly's handle is `@GA`.
#
# Note that this won't return the whole list of GA's users.  If you want to do that you have to use cursoring:  https://developer.twitter.com/en/docs/basics/cursoring.  This is the topic of your bonus assignment.

# %%
# your answer here
url ='https://api.twitter.com/1.1/followers/list.json?screen_name=GA'
GA=requests.get(url,auth=auth).json()

# %%
url ='https://api.twitter.com/1.1/users/show.json?screen_name=GA'

GAuser=requests.get(url,auth=auth).json()

# %%
GAuser
# Out:
# {'id': 170393291,
#  'id_str': '170393291',
#  'name': 'General Assembly',
#  'screen_name': 'GA',
#  'location': '',
#  'profile_location': None,
#  'description': 'We transform careers and teams — including more than one third of the Fortune 100 — through dynamic courses in coding, data, design, and business.',
#  'url': 'https://t.co/YQeEXPxJ4H',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/YQeEXPxJ4H',
#      'expanded_url': 'http://ga.co/Twitter',
#      'display_url': 'ga.co/Twitter',
#      'indices': [0, 23]}]},
#   'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 165519,
#  'friends_count': 5416,
#  'listed_count': 3263,
#  'created_at': 'Sat Jul 24 18:19:59 +0000 2010',
#  'favourites_count': 36405,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': True,
#  'statuses_count': 22756,
#  'lang': None,
#  'status': {'created_at': 'Sat Aug 08 17:27:02 +0000 2020',
#   'id': 1292150339995607045,
#   'id_str': '1292150339995607045',
#   'text': '5 benefits of coding that can be useful in other aspects of your life:\n✅ Problem solving\n✅ Attention to detail\n✅ La… https://t.co/6ydISO2O1M',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/6ydISO2O1M',
#      'expanded_url': 'https://twitter.com/i/web/status/1292150339995607045',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 4,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'FFFFFF',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': True,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1267818300416745472/A3qO4Fer_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1267818300416745472/A3qO4Fer_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/170393291/1480618900',
#  'profile_link_color': 'DE2233',
#  'profile_sidebar_border_color': 'FFFFFF',
#  'profile_sidebar_fill_color': 'FFFFFF',
#  'profile_text_color': '000000',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %%
GA
# Out:
# {'users': [{'id': 14868552,
#    'id_str': '14868552',
#    'name': 'Игорб',
#    'screen_name': 'huipizdayebatsy',
#    'location': 'Moscow',
#    'description': 'https://t.co/5PajhCpOCg',
#    'url': None,
#    'entities': {'description': {'urls': [{'url': 'https://t.co/5PajhCpOCg',
#        'expanded_url': 'https://ttttt.me/poshel_na_hui',
#        'display_url': 'ttttt.me/poshel_na_hui',
#        'indices': [0, 23]}]}},
#    'protected': False,
#    'followers_count': 1686,
#    'friends_count': 755,
#    'listed_count': 28,
#    'created_at': 'Thu May 22 14:06:48 +0000 2008',
#    'favourites_count': 6546,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 34306,
#    'lang': None,
#    'status': {'created_at': 'Sat Aug 08 21:57:35 +0000 2020',
#     'id': 1292218423812988931,
#     'id_str': '1292218423812988931',
#     'text': 'RT @UKRaveComments: Why do tigers get lost all the time?\n...\n...\n...\n...\n...\nBecause the jungle is massive!',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'UKRaveComments',
#        'name': 'UK Rave YouTube Comments',
#        'id': 1256255217810788354,
#        'id_str': '1256255217810788354',
#        'indices': [3, 18]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Sat Aug 08 21:31:05 +0000 2020',
#      'id': 1292211755880521729,
#      'id_str': '1292211755880521729',
#      'text': 'Why do tigers get lost all the time?\n...\n...\n...\n...\n...\nBecause the jungle is massive!',
#      'truncated': False,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': []},
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 26,
#      'favorite_count': 171,
#      'favorited': False,
#      'retweeted': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 26,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000797',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/976475727188123648/HfRCrztm_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/976475727188123648/HfRCrztm_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14868552/1519252398',
#    'profile_link_color': '000000',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'FFFFFF',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1292338271930863616,
#    'id_str': '1292338271930863616',
#    'name': 'karly smith',
#    'screen_name': 'karlymsdev',
#    'location': 'Seattle, WA',
#    'description': 'developing things, having fun w/ machine learning, interested in tech justice!',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1,
#    'friends_count': 25,
#    'listed_count': 0,
#    'created_at': 'Sun Aug 09 05:54:02 +0000 2020',
#    'favourites_count': 0,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1,
#    'lang': None,
#    'status': {'created_at': 'Sun Aug 09 06:06:45 +0000 2020',
#     'id': 1292341526979174401,
#     'id_str': '1292341526979174401',
#     'text': 'hi y’all! this is my new twitter account for professional access/networking and for me to hype up cool tech stuff :-)',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1292338495478890497/_0O-1HbL_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1292338495478890497/_0O-1HbL_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1292338271930863616/1596953153',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1043978460,
#    'id_str': '1043978460',
#    'name': 'German Diaz',
#    'screen_name': 'gdiaz324',
#    'location': 'Coconut Creek, FL',
#    'description': 'leaning on optimism. data-driven marketing entrepreneur.\n**\\U/** 🇪🇨 🇺🇲',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 112,
#    'friends_count': 727,
#    'listed_count': 6,
#    'created_at': 'Sat Dec 29 06:16:20 +0000 2012',
#    'favourites_count': 264,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 422,
#    'lang': None,
#    'status': {'created_at': 'Mon Jul 27 15:36:18 +0000 2020',
#     'id': 1287773816484134914,
#     'id_str': '1287773816484134914',
#     'text': "@Forbes Let's see if they keep their stores closed on Thanksgiving Day after 2020. You know, when a pandemic is not… https://t.co/2Z5Ne2w2qt",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'Forbes',
#        'name': 'Forbes',
#        'id': 91478624,
#        'id_str': '91478624',
#        'indices': [0, 7]}],
#      'urls': [{'url': 'https://t.co/2Z5Ne2w2qt',
#        'expanded_url': 'https://twitter.com/i/web/status/1287773816484134914',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': 1287741728229920770,
#     'in_reply_to_status_id_str': '1287741728229920770',
#     'in_reply_to_user_id': 91478624,
#     'in_reply_to_user_id_str': '91478624',
#     'in_reply_to_screen_name': 'Forbes',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1148000916525735940/_nyJdq8N_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1148000916525735940/_nyJdq8N_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1043978460/1562539722',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1291919127293169665,
#    'id_str': '1291919127293169665',
#    'name': 'Elizabeth',
#    'screen_name': 'puffdivastarr',
#    'location': 'Houston, TX',
#    'description': 'student',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 2,
#    'friends_count': 34,
#    'listed_count': 0,
#    'created_at': 'Sat Aug 08 02:08:29 +0000 2020',
#    'favourites_count': 17,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 5,
#    'lang': None,
#    'status': {'created_at': 'Sun Aug 09 02:55:33 +0000 2020',
#     'id': 1292293409953198081,
#     'id_str': '1292293409953198081',
#     'text': '@SimonsCat Luna Belle, Athena and Chloe https://t.co/jdl5GcHJyi',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'SimonsCat',
#        'name': "Simon's Cat",
#        'id': 53112502,
#        'id_str': '53112502',
#        'indices': [0, 10]}],
#      'urls': [],
#      'media': [{'id': 1292293404274176000,
#        'id_str': '1292293404274176000',
#        'indices': [40, 63],
#        'media_url': 'http://pbs.twimg.com/media/Ee8mARtXsAAHT_M.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/Ee8mARtXsAAHT_M.jpg',
#        'url': 'https://t.co/jdl5GcHJyi',
#        'display_url': 'pic.twitter.com/jdl5GcHJyi',
#        'expanded_url': 'https://twitter.com/puffdivastarr/status/1292293409953198081/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 772, 'h': 772, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#         'large': {'w': 772, 'h': 772, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1292293404274176000,
#        'id_str': '1292293404274176000',
#        'indices': [40, 63],
#        'media_url': 'http://pbs.twimg.com/media/Ee8mARtXsAAHT_M.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/Ee8mARtXsAAHT_M.jpg',
#        'url': 'https://t.co/jdl5GcHJyi',
#        'display_url': 'pic.twitter.com/jdl5GcHJyi',
#        'expanded_url': 'https://twitter.com/puffdivastarr/status/1292293409953198081/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 772, 'h': 772, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#         'large': {'w': 772, 'h': 772, 'resize': 'fit'}}},
#       {'id': 1292293404269989894,
#        'id_str': '1292293404269989894',
#        'indices': [40, 63],
#        'media_url': 'http://pbs.twimg.com/media/Ee8mARsX0AYu_2y.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/Ee8mARsX0AYu_2y.jpg',
#        'url': 'https://t.co/jdl5GcHJyi',
#        'display_url': 'pic.twitter.com/jdl5GcHJyi',
#        'expanded_url': 'https://twitter.com/puffdivastarr/status/1292293409953198081/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 510, 'resize': 'fit'},
#         'medium': {'w': 1200, 'h': 900, 'resize': 'fit'},
#         'large': {'w': 2048, 'h': 1536, 'resize': 'fit'}}}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1292034063348498432,
#     'in_reply_to_status_id_str': '1292034063348498432',
#     'in_reply_to_user_id': 53112502,
#     'in_reply_to_user_id_str': '53112502',
#     'in_reply_to_screen_name': 'SimonsCat',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1291926824327536642/Hmu5dfsm_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1291926824327536642/Hmu5dfsm_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1291919127293169665/1596854797',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1663409790,
#    'id_str': '1663409790',
#    'name': 'HURPSY IMAGERY 📸',
#    'screen_name': 'hurpsy4eva',
#    'location': 'Washington, DC',
#    'description': 'Let preserve your memories',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': True,
#    'followers_count': 249,
#    'friends_count': 2511,
#    'listed_count': 1,
#    'created_at': 'Sun Aug 11 20:55:29 +0000 2013',
#    'favourites_count': 5916,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 452,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/766645334973960194/8RqSfM9g_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/766645334973960194/8RqSfM9g_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1663409790/1531040331',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1279561757258846208,
#    'id_str': '1279561757258846208',
#    'name': 'Denise Bagans 🧛\u200d♀️🧡🧛\u200d♂️',
#    'screen_name': 'BagansDenise',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': True,
#    'followers_count': 64,
#    'friends_count': 165,
#    'listed_count': 0,
#    'created_at': 'Sat Jul 04 23:45:16 +0000 2020',
#    'favourites_count': 2241,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 2408,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1279564177003200512/GnfUdx0v_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1279564177003200512/GnfUdx0v_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1279561757258846208/1593906923',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1286605723271483392,
#    'id_str': '1286605723271483392',
#    'name': 'WeDiversify',
#    'screen_name': 'WeDiversifyMe',
#    'location': '',
#    'description': 'Creating a more diverse and inclusive workplace for communities. Seminars, workshops, D&I and unconscious bias training programs. #DiversityMatters DMs open.',
#    'url': 'https://t.co/jBavhoQHd0',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/jBavhoQHd0',
#        'expanded_url': 'https://wediversify.blogspot.com/',
#        'display_url': 'wediversify.blogspot.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 7,
#    'friends_count': 102,
#    'listed_count': 0,
#    'created_at': 'Fri Jul 24 10:15:02 +0000 2020',
#    'favourites_count': 0,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 5,
#    'lang': None,
#    'status': {'created_at': 'Sat Aug 08 21:11:08 +0000 2020',
#     'id': 1292206735545884672,
#     'id_str': '1292206735545884672',
#     'text': '@WeDiversifyInt works with business leaders in all industries to build more diverse work spaces, because #diversitymatters',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'diversitymatters',
#        'indices': [105, 122]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': 1292206460663816193,
#     'in_reply_to_status_id_str': '1292206460663816193',
#     'in_reply_to_user_id': 1286605723271483392,
#     'in_reply_to_user_id_str': '1286605723271483392',
#     'in_reply_to_screen_name': 'WeDiversifyMe',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1292152379354181632/tu0OrTut_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1292152379354181632/tu0OrTut_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1286605723271483392/1596908918',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1268596546553208832,
#    'id_str': '1268596546553208832',
#    'name': 'Priya',
#    'screen_name': 'PriyaKour007',
#    'location': 'London, United Kingdom',
#    'description': 'Social Entrepreneur I Activist I Youth Leader I Influencer I Online Education Promoter',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 429,
#    'friends_count': 1062,
#    'listed_count': 0,
#    'created_at': 'Thu Jun 04 17:39:14 +0000 2020',
#    'favourites_count': 243,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 271,
#    'lang': None,
#    'status': {'created_at': 'Sun Aug 09 07:23:06 +0000 2020',
#     'id': 1292360740582699008,
#     'id_str': '1292360740582699008',
#     'text': "Every day may not be good, but there's something good in every day.",
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1269340049683947520/F2U2KAHM_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1269340049683947520/F2U2KAHM_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1268596546553208832/1593499882',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1168327059111915521,
#    'id_str': '1168327059111915521',
#    'name': 'Principe Cabrera',
#    'screen_name': 'PrincipeCabrera',
#    'location': '',
#    'description': 'Techy millenial intrigued by the unknown and music lover. Dominican the nationality, Bachata what I dance the best.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 5,
#    'friends_count': 127,
#    'listed_count': 0,
#    'created_at': 'Mon Sep 02 00:57:39 +0000 2019',
#    'favourites_count': 26,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 3,
#    'lang': None,
#    'status': {'created_at': 'Sat Aug 08 18:43:27 +0000 2020',
#     'id': 1292169570736910336,
#     'id_str': '1292169570736910336',
#     'text': 'RT @unrealgaurav: Son, before you learn frameworks, learn the basics of Javascript.\n#javascript #DEVCommunity #100DaysOfCode https://t.co/M…',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'javascript', 'indices': [84, 95]},
#       {'text': 'DEVCommunity', 'indices': [96, 109]},
#       {'text': '100DaysOfCode', 'indices': [110, 124]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'unrealgaurav',
#        'name': 'Gaurav 🇮🇳',
#        'id': 66121916,
#        'id_str': '66121916',
#        'indices': [3, 16]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Sat Aug 08 06:05:20 +0000 2020',
#      'id': 1291978783885389826,
#      'id_str': '1291978783885389826',
#      'text': 'Son, before you learn frameworks, learn the basics of Javascript.\n#javascript #DEVCommunity #100DaysOfCode https://t.co/MECqspDxdi',
#      'truncated': False,
#      'entities': {'hashtags': [{'text': 'javascript', 'indices': [66, 77]},
#        {'text': 'DEVCommunity', 'indices': [78, 91]},
#        {'text': '100DaysOfCode', 'indices': [92, 106]}],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [],
#       'media': [{'id': 1291978781171752960,
#         'id_str': '1291978781171752960',
#         'indices': [107, 130],
#         'media_url': 'http://pbs.twimg.com/media/Ee4H2zUVoAAoD_I.jpg',
#         'media_url_https': 'https://pbs.twimg.com/media/Ee4H2zUVoAAoD_I.jpg',
#         'url': 'https://t.co/MECqspDxdi',
#         'display_url': 'pic.twitter.com/MECqspDxdi',
#         'expanded_url': 'https://twitter.com/unrealgaurav/status/1291978783885389826/photo/1',
#         'type': 'photo',
#         'sizes': {'medium': {'w': 680, 'h': 422, 'resize': 'fit'},
#          'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#          'large': {'w': 680, 'h': 422, 'resize': 'fit'},
#          'small': {'w': 680, 'h': 422, 'resize': 'fit'}}}]},
#      'extended_entities': {'media': [{'id': 1291978781171752960,
#         'id_str': '1291978781171752960',
#         'indices': [107, 130],
#         'media_url': 'http://pbs.twimg.com/media/Ee4H2zUVoAAoD_I.jpg',
#         'media_url_https': 'https://pbs.twimg.com/media/Ee4H2zUVoAAoD_I.jpg',
#         'url': 'https://t.co/MECqspDxdi',
#         'display_url': 'pic.twitter.com/MECqspDxdi',
#         'expanded_url': 'https://twitter.com/unrealgaurav/status/1291978783885389826/photo/1',
#         'type': 'photo',
#         'sizes': {'medium': {'w': 680, 'h': 422, 'resize': 'fit'},
#          'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#          'large': {'w': 680, 'h': 422, 'resize': 'fit'},
#          'small': {'w': 680, 'h': 422, 'resize': 'fit'}}}]},
#      'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 188,
#      'favorite_count': 703,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 188,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': True,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 920658279923109888,
#    'id_str': '920658279923109888',
#    'name': 'Cameron Baumgartner',
#    'screen_name': 'cameronhbg',
#    'location': 'Charlottesville, VA',
#    'description': 'Writer. Editorial consultant and reader of slush piles @CraftLiterary. MFA @vcfa // BA @uva. Hard of hearing & ❤️💜💙 & happy. Hire me!',
#    'url': 'https://t.co/M3Cvp3dWnv',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/M3Cvp3dWnv',
#        'expanded_url': 'http://cameronbaumgartner.com',
#        'display_url': 'cameronbaumgartner.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 229,
#    'friends_count': 543,
#    'listed_count': 2,
#    'created_at': 'Wed Oct 18 14:30:13 +0000 2017',
#    'favourites_count': 7294,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 3523,
#    'lang': None,
#    'status': {'created_at': 'Sun Aug 09 00:14:54 +0000 2020',
#     'id': 1292252982894092288,
#     'id_str': '1292252982894092288',
#     'text': "@RavenLeilani Looking lustrous! Can't wait to read the book, everyone's buzzing about it!",
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'RavenLeilani',
#        'name': 'Raven Leilani',
#        'id': 2786195945,
#        'id_str': '2786195945',
#        'indices': [0, 13]}],
#      'urls': []},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': 1292223658178547713,
#     'in_reply_to_status_id_str': '1292223658178547713',
#     'in_reply_to_user_id': 2786195945,
#     'in_reply_to_user_id_str': '2786195945',
#     'in_reply_to_screen_name': 'RavenLeilani',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1286397608177565698/p2gwkUSG_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1286397608177565698/p2gwkUSG_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/920658279923109888/1578371512',
#    'profile_link_color': 'F58EA8',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 747039316669456385,
#    'id_str': '747039316669456385',
#    'name': 'elizabeth paier',
#    'screen_name': 'ElizabethPaier',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 158,
#    'friends_count': 1161,
#    'listed_count': 6,
#    'created_at': 'Sun Jun 26 12:10:27 +0000 2016',
#    'favourites_count': 111,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 16304,
#    'lang': None,
#    'status': {'created_at': 'Sun Aug 09 08:22:00 +0000 2020',
#     'id': 1292375562795847680,
#     'id_str': '1292375562795847680',
#     'text': 'RT @AdrianNormanDC: The left: "If you don\'t listen to us, we will...\n\n...shut off your water.\n\n...shut off your electricity.\n\n...burn your…',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'AdrianNormanDC',
#        'name': 'Adrian Norman',
#        'id': 829383694976643072,
#        'id_str': '829383694976643072',
#        'indices': [3, 18]}],
#      'urls': []},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Thu Aug 06 23:37:08 +0000 2020',
#      'id': 1291518702119051264,
#      'id_str': '1291518702119051264',
#      'text': 'The left: "If you don\'t listen to us, we will...\n\n...shut off your water.\n\n...shut off your electricity.\n\n...burn y… https://t.co/BLplTsGjF6',
#      'truncated': True,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/BLplTsGjF6',
#         'expanded_url': 'https://twitter.com/i/web/status/1291518702119051264',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [117, 140]}]},
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 2751,
#      'favorite_count': 4695,
#      'favorited': False,
#      'retweeted': False,
#      'lang': 'en'},
#     'is_quote_status': False,
#     'retweet_count': 2751,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/985719297052884992/x-ulEtk1_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/985719297052884992/x-ulEtk1_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/747039316669456385/1479013822',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 3048715706,
#    'id_str': '3048715706',
#    'name': 'Usman Saeed',
#    'screen_name': 'musmansaeed38',
#    'location': 'Lahore, Pakistan',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 69,
#    'friends_count': 2354,
#    'listed_count': 0,
#    'created_at': 'Sat Feb 28 05:09:58 +0000 2015',
#    'favourites_count': 241,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 68,
#    'lang': None,
#    'status': {'created_at': 'Sat Aug 01 16:12:26 +0000 2020',
#     'id': 1289594850443030528,
#     'id_str': '1289594850443030528',
#     'text': '@SP_Atif_Nazir خیر مبارک اور آپ کو بھی عید الاضحٰی مبارک ہو',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'SP_Atif_Nazir',
#        'name': 'SP Atif Nazir',
#        'id': 1151995616,
#        'id_str': '1151995616',
#        'indices': [0, 14]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': 1289429482411970561,
#     'in_reply_to_status_id_str': '1289429482411970561',
#     'in_reply_to_user_id': 1151995616,
#     'in_reply_to_user_id_str': '1151995616',
#     'in_reply_to_screen_name': 'SP_Atif_Nazir',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'ur'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1065250090388983809/nDSCQKo3_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1065250090388983809/nDSCQKo3_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3048715706/1550438184',
#    'profile_link_color': '19CF86',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1283154888759939072,
#    'id_str': '1283154888759939072',
#    'name': 'Slider - The Startup Showcase',
#    'screen_name': 'StartupSlider',
#    'location': '',
#    'description': "We're building a network to help connect startups and venture capital investors all over the world. Join our mailing list to stay up to date!",
#    'url': 'https://t.co/Yys74HXDEU',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/Yys74HXDEU',
#        'expanded_url': 'https://www.startupslider.com',
#        'display_url': 'startupslider.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 11,
#    'friends_count': 301,
#    'listed_count': 0,
#    'created_at': 'Tue Jul 14 21:42:27 +0000 2020',
#    'favourites_count': 3,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 5,
#    'lang': None,
#    'status': {'created_at': 'Sat Aug 08 17:00:51 +0000 2020',
#     'id': 1292143751914168320,
#     'id_str': '1292143751914168320',
#     'text': "Who's working on a cool new idea?",
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': []},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1290050105890938881/TBInTiah_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1290050105890938881/TBInTiah_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1283154888759939072/1596960660',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1292055415136583681,
#    'id_str': '1292055415136583681',
#    'name': 'Mayola Tyler',
#    'screen_name': 'tyler_mayola',
#    'location': '',
#    'description': 'Total explorer. Hipster-friendly entrepreneur. Amateur analyst. Troublemaker. Internet ninja.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 0,
#    'friends_count': 11,
#    'listed_count': 0,
#    'created_at': 'Sat Aug 08 11:09:55 +0000 2020',
#    'favourites_count': 0,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 0,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1292055563250077696/IA2Bo6bh_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1292055563250077696/IA2Bo6bh_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1030536043148259328,
#    'id_str': '1030536043148259328',
#    'name': 'Elias',
#    'screen_name': 'Elias60960250',
#    'location': 'Addis Ababa',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1,
#    'friends_count': 39,
#    'listed_count': 0,
#    'created_at': 'Fri Aug 17 19:25:13 +0000 2018',
#    'favourites_count': 128,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 37,
#    'lang': None,
#    'status': {'created_at': 'Mon Apr 22 22:16:11 +0000 2019',
#     'id': 1120451257745981440,
#     'id_str': '1120451257745981440',
#     'text': '@StumblerFunny @StumblerTop Why is this funny?',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'StumblerFunny',
#        'name': 'Stumbler USA',
#        'id': 1112632763755032577,
#        'id_str': '1112632763755032577',
#        'indices': [0, 14]},
#       {'screen_name': 'StumblerTop',
#        'name': 'Stumbler Top',
#        'id': 345811633,
#        'id_str': '345811633',
#        'indices': [15, 27]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1120432420011085824,
#     'in_reply_to_status_id_str': '1120432420011085824',
#     'in_reply_to_user_id': 1112632763755032577,
#     'in_reply_to_user_id_str': '1112632763755032577',
#     'in_reply_to_screen_name': 'StumblerFunny',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1225149645137072134/-A_HXCM-_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1225149645137072134/-A_HXCM-_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 97211785,
#    'id_str': '97211785',
#    'name': 'Marco Ogliengo',
#    'screen_name': 'mogliengo',
#    'location': 'Milano, Italy',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 80,
#    'friends_count': 113,
#    'listed_count': 0,
#    'created_at': 'Wed Dec 16 13:47:31 +0000 2009',
#    'favourites_count': 31,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 13,
#    'lang': None,
#    'status': {'created_at': 'Sat May 16 18:58:24 +0000 2020',
#     'id': 1261732753168650245,
#     'id_str': '1261732753168650245',
#     'text': 'RT @DennisHong17: Ecommerce Penetration https://t.co/SDnMggQrJz',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'DennisHong17',
#        'name': 'Dennis Hong',
#        'id': 1125462195494686720,
#        'id_str': '1125462195494686720',
#        'indices': [3, 16]}],
#      'urls': [],
#      'media': [{'id': 1261492528186036226,
#        'id_str': '1261492528186036226',
#        'indices': [40, 63],
#        'media_url': 'http://pbs.twimg.com/media/EYG4xU1WkAIevtD.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EYG4xU1WkAIevtD.jpg',
#        'url': 'https://t.co/SDnMggQrJz',
#        'display_url': 'pic.twitter.com/SDnMggQrJz',
#        'expanded_url': 'https://twitter.com/DennisHong17/status/1261492532690763777/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 439, 'resize': 'fit'},
#         'medium': {'w': 791, 'h': 511, 'resize': 'fit'},
#         'large': {'w': 791, 'h': 511, 'resize': 'fit'}},
#        'source_status_id': 1261492532690763777,
#        'source_status_id_str': '1261492532690763777',
#        'source_user_id': 1125462195494686720,
#        'source_user_id_str': '1125462195494686720'}]},
#     'extended_entities': {'media': [{'id': 1261492528186036226,
#        'id_str': '1261492528186036226',
#        'indices': [40, 63],
#        'media_url': 'http://pbs.twimg.com/media/EYG4xU1WkAIevtD.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EYG4xU1WkAIevtD.jpg',
#        'url': 'https://t.co/SDnMggQrJz',
# ...
#      'truncated': False,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [],
#       'media': [{'id': 1261492528186036226,
#         'id_str': '1261492528186036226',
#         'indices': [22, 45],
#         'media_url': 'http://pbs.twimg.com/media/EYG4xU1WkAIevtD.jpg',
#         'media_url_https': 'https://pbs.twimg.com/media/EYG4xU1WkAIevtD.jpg',
#         'url': 'https://t.co/SDnMggQrJz',
#         'display_url': 'pic.twitter.com/SDnMggQrJz',
#         'expanded_url': 'https://twitter.com/DennisHong17/status/1261492532690763777/photo/1',
#         'type': 'photo',
#         'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#          'small': {'w': 680, 'h': 439, 'resize': 'fit'},
#          'medium': {'w': 791, 'h': 511, 'resize': 'fit'},
#          'large': {'w': 791, 'h': 511, 'resize': 'fit'}}}]},
#      'extended_entities': {'media': [{'id': 1261492528186036226,
#         'id_str': '1261492528186036226',
#         'indices': [22, 45],
#         'media_url': 'http://pbs.twimg.com/media/EYG4xU1WkAIevtD.jpg',
#         'media_url_https': 'https://pbs.twimg.com/media/EYG4xU1WkAIevtD.jpg',
#         'url': 'https://t.co/SDnMggQrJz',
#         'display_url': 'pic.twitter.com/SDnMggQrJz',
#         'expanded_url': 'https://twitter.com/DennisHong17/status/1261492532690763777/photo/1',
#         'type': 'photo',
#         'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#          'small': {'w': 680, 'h': 439, 'resize': 'fit'},
#          'medium': {'w': 791, 'h': 511, 'resize': 'fit'},
#          'large': {'w': 791, 'h': 511, 'resize': 'fit'}}}]},
#      'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 148,
#      'favorite_count': 459,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'fr'},
#     'is_quote_status': False,
#     'retweet_count': 148,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'fr'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/599682829291753472/M5I3an4A_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/599682829291753472/M5I3an4A_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 376406877,
#    'id_str': '376406877',
#    'name': 'gluix',
#    'screen_name': 'gluix1',
#    'location': 'Münster',
#    'description': 'MAKE NORMALITY NORMAL AGAIN. \nC#/Angular/Typescript/HTML5/SCSS/GIT/Blockchain/MECH-Keyboards/-Enthusiast, Rocker, Pirat, Blader, Held der Informatik...',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 51,
#    'friends_count': 527,
#    'listed_count': 0,
#    'created_at': 'Mon Sep 19 20:46:39 +0000 2011',
#    'favourites_count': 398,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 173,
#    'lang': None,
#    'status': {'created_at': 'Mon Mar 30 17:32:54 +0000 2020',
#     'id': 1244679007087603713,
#     'id_str': '1244679007087603713',
#     'text': 'RT @UK_Muenster: Wir suchen gesundete Corona-PatientInnen für Studie: Personen, die Corona-Infektion hatten und jetzt einen negativen Coron…',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'UK_Muenster',
#        'name': 'Uniklinik Münster',
#        'id': 3004024965,
#        'id_str': '3004024965',
#        'indices': [3, 15]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'retweeted_status': {'created_at': 'Sun Mar 29 09:32:13 +0000 2020',
#      'id': 1244195651254132736,
#      'id_str': '1244195651254132736',
#      'text': 'Wir suchen gesundete Corona-PatientInnen für Studie: Personen, die Corona-Infektion hatten und jetzt einen negative… https://t.co/Ec3m97bQMV',
#      'truncated': True,
#      'entities': {'hashtags': [],
#       'symbols': [],
#       'user_mentions': [],
#       'urls': [{'url': 'https://t.co/Ec3m97bQMV',
#         'expanded_url': 'https://twitter.com/i/web/status/1244195651254132736',
#         'display_url': 'twitter.com/i/web/status/1…',
#         'indices': [117, 140]}]},
#      'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#      'in_reply_to_status_id': None,
#      'in_reply_to_status_id_str': None,
#      'in_reply_to_user_id': None,
#      'in_reply_to_user_id_str': None,
#      'in_reply_to_screen_name': None,
#      'geo': None,
#      'coordinates': None,
#      'place': None,
#      'contributors': None,
#      'is_quote_status': False,
#      'retweet_count': 1416,
#      'favorite_count': 905,
#      'favorited': False,
#      'retweeted': False,
#      'possibly_sensitive': False,
#      'lang': 'de'},
#     'is_quote_status': False,
#     'retweet_count': 1416,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'de'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'DEDEDE',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/3228335013/3ee0a616a2daf1e13ac517a62abbc151_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3228335013/3ee0a616a2daf1e13ac517a62abbc151_normal.png',
#    'profile_link_color': '747F82',
#    'profile_sidebar_border_color': '181A1E',
#    'profile_sidebar_fill_color': '252429',
#    'profile_text_color': '666666',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1105584574216704011,
#    'id_str': '1105584574216704011',
#    'name': 'Crypto Cantabria',
#    'screen_name': 'CryptoCantabria',
#    'location': '',
#    'description': 'Primera escuela de formación de Cantabria especializada en el uso de las cryptomonedas',
#    'url': 'https://t.co/uuWTKP5frz',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/uuWTKP5frz',
#        'expanded_url': 'http://www.cryptocan.es',
#        'display_url': 'cryptocan.es',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 204,
#    'friends_count': 785,
#    'listed_count': 2,
#    'created_at': 'Tue Mar 12 21:41:18 +0000 2019',
#    'favourites_count': 197,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 69,
#    'lang': None,
#    'status': {'created_at': 'Fri Aug 07 22:48:42 +0000 2020',
#     'id': 1291868900754432001,
#     'id_str': '1291868900754432001',
#     'text': '@barrysilbert @Grayscale @nitWitty It seems incredible to us what you are doing, it is essential to disseminate and train.',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'barrysilbert',
#        'name': 'Barry Silbert',
#        'id': 396045469,
#        'id_str': '396045469',
#        'indices': [0, 13]},
#       {'screen_name': 'Grayscale',
#        'name': 'Grayscale',
#        'id': 2800345565,
#        'id_str': '2800345565',
#        'indices': [14, 24]},
#       {'screen_name': 'nitWitty',
#        'name': 'Arnold, Marissa',
#        'id': 17472882,
#        'id_str': '17472882',
#        'indices': [25, 34]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1291710737291841543,
#     'in_reply_to_status_id_str': '1291710737291841543',
#     'in_reply_to_user_id': 396045469,
#     'in_reply_to_user_id_str': '396045469',
#     'in_reply_to_screen_name': 'barrysilbert',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1105584726545498115/jUdlwSty_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1105584726545498115/jUdlwSty_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1105584574216704011/1552502323',
#    'profile_link_color': 'FAB81E',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 18942864,
#    'id_str': '18942864',
#    'name': 'Ali Khayrallah',
#    'screen_name': 'alisk',
#    'location': 'California',
#    'description': 'Working away at the G’s of mobile. Technology trends, big picture, strategery. Question everything. Views my own, unencumbered by fact. Go Blue! Go AUB!',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 87,
#    'friends_count': 1334,
#    'listed_count': 2,
#    'created_at': 'Tue Jan 13 16:26:29 +0000 2009',
#    'favourites_count': 19,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 819,
#    'lang': None,
#    'status': {'created_at': 'Sun Aug 09 01:56:34 +0000 2020',
#     'id': 1292278568022470656,
#     'id_str': '1292278568022470656',
#     'text': '@sahouraxo @reecheverria For those in the US may I suggest this way. The Lebanese Red Cross is among the supported… https://t.co/KjnVmXVKb8',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'sahouraxo',
#        'name': 'Sarah Abdallah',
#        'id': 3293406121,
#        'id_str': '3293406121',
#        'indices': [0, 10]},
#       {'screen_name': 'reecheverria',
#        'name': 'Rafa',
#        'id': 362659577,
#        'id_str': '362659577',
#        'indices': [11, 24]}],
#      'urls': [{'url': 'https://t.co/KjnVmXVKb8',
#        'expanded_url': 'https://twitter.com/i/web/status/1292278568022470656',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': 1291859212759216129,
#     'in_reply_to_status_id_str': '1291859212759216129',
#     'in_reply_to_user_id': 3293406121,
#     'in_reply_to_user_id_str': '3293406121',
#     'in_reply_to_screen_name': 'sahouraxo',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1291762952354193409,
#     'quoted_status_id_str': '1291762952354193409',
#     'retweet_count': 0,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/839963598533226497/JQdSDpTI_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/839963598533226497/JQdSDpTI_normal.jpg',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'},
#   {'id': 1290342410048995333,
#    'id_str': '1290342410048995333',
#    'name': 'Queen 👸 Tiffany',
#    'screen_name': 'QueenTi62831950',
#    'location': '',
#    'description': 'Just I and my son',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 6,
#    'friends_count': 210,
#    'listed_count': 0,
#    'created_at': 'Mon Aug 03 17:43:50 +0000 2020',
#    'favourites_count': 2,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 0,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1290343364525723648/CJLjOVMq_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1290343364525723648/CJLjOVMq_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1290342410048995333/1596477315',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'live_following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'muting': False,
#    'blocking': False,
#    'blocked_by': False,
#    'translator_type': 'none'}],
#  'next_cursor': 1674393596705404560,
#  'next_cursor_str': '1674393596705404560',
#  'previous_cursor': 0,
#  'previous_cursor_str': '0',
#  'total_count': None}

# %%
url ='https://api.twitter.com/1.1/followers/list.json?screen_name=GA&cursor=1674310506286027278'
GA2=requests.get(url,auth=auth).json()

# %%
url ='https://api.twitter.com/1.1/followers/list.json?screen_name=GA&cursor=1674254494235162030'
GA3=requests.get(url,auth=auth).json()

# %%
def find_user(user):
    import requests
    user=user.strip('@')
    d={}
    url =f'https://api.twitter.com/1.1/users/show.json?screen_name={user}'
    userdata=requests.get(url,auth=auth).json()
    d ={
        'Name': [userdata['name']],
        'screen_name' : [userdata['screen_name']],
        'followers_count'  : [userdata['followers_count']],
        'friends_count' : [userdata['friends_count']]
        }
    return d

# %%
url =f'https://api.twitter.com/1.1/users/show.json?screen_name=GA'
userdata=requests.get(url,auth=auth).json()

# %%
url =f'https://api.twitter.com/1.1/users/show.json?screen_name=GA'
requests.get(url, auth=auth).json()
# Out:
# {'id': 170393291,
#  'id_str': '170393291',
#  'name': 'General Assembly',
#  'screen_name': 'GA',
#  'location': '',
#  'profile_location': None,
#  'description': 'We transform careers and teams — including more than one third of the Fortune 100 — through dynamic courses in coding, data, design, and business.',
#  'url': 'https://t.co/YQeEXPxJ4H',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/YQeEXPxJ4H',
#      'expanded_url': 'http://ga.co/Twitter',
#      'display_url': 'ga.co/Twitter',
#      'indices': [0, 23]}]},
#   'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 165519,
#  'friends_count': 5416,
#  'listed_count': 3263,
#  'created_at': 'Sat Jul 24 18:19:59 +0000 2010',
#  'favourites_count': 36405,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': True,
#  'statuses_count': 22756,
#  'lang': None,
#  'status': {'created_at': 'Sat Aug 08 17:27:02 +0000 2020',
#   'id': 1292150339995607045,
#   'id_str': '1292150339995607045',
#   'text': '5 benefits of coding that can be useful in other aspects of your life:\n✅ Problem solving\n✅ Attention to detail\n✅ La… https://t.co/6ydISO2O1M',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/6ydISO2O1M',
#      'expanded_url': 'https://twitter.com/i/web/status/1292150339995607045',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 4,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'FFFFFF',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': True,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1267818300416745472/A3qO4Fer_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1267818300416745472/A3qO4Fer_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/170393291/1480618900',
#  'profile_link_color': 'DE2233',
#  'profile_sidebar_border_color': 'FFFFFF',
#  'profile_sidebar_fill_color': 'FFFFFF',
#  'profile_text_color': '000000',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %%
def find_user(user, keys=None):
    user=user.strip('@')
    url =f'https://api.twitter.com/1.1/users/show.json?screen_name={user}'
    userdata=requests.get(url,auth=auth).json()
    
    if keys != None:
       #userdata = {}
        #print(userdata)
        for key in keys:
            print(key)
            userdata_keys = userdata[key]
            return userdata_keys
    else:
        return userdata

# %%
def find_user(user, keys=None):
    user=user.strip('@')
    url =f'https://api.twitter.com/1.1/users/show.json?screen_name={user}'
    userdata=requests.get(url,auth=auth).json()
    
    if keys != None:
        userdata_keys = {}
        for key in keys:
            userdata_keys[key] = userdata[key]
        return userdata_keys
    else:
        return userdata

# %%
find_user('GA',  keys=['name', 'url', 'created_at'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4fcb75fe0e06> in <module>
# ----> 1 find_user('GA',  keys=['name', 'url', 'created_at'])
#
# <ipython-input-1-67bf16f75f4e> in find_user(user, keys)
#       2     user=user.strip('@')
#       3     url =f'https://api.twitter.com/1.1/users/show.json?screen_name={user}'
# ----> 4     userdata=requests.get(url,auth=auth).json()
#       5
#       6     if keys != None:
#
# NameError: name 'requests' is not defined

# %%
url ='https://api.twitter.com/1.1/search/tweets.json?q=%23deeplearning&count=75&result_type=recent,popular'
requests.get(url,auth=auth).json()
# Out:
# {'statuses': [{'created_at': 'Sun Aug 09 08:54:07 +0000 2020',
#    'id': 1292383645915701249,
#    'id_str': '1292383645915701249',
#    'text': '#Unsplash’s #dataset is now #opensource #images #DeepLearning https://t.co/QmZQScEuaM',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Unsplash', 'indices': [0, 9]},
#      {'text': 'dataset', 'indices': [12, 20]},
#      {'text': 'opensource', 'indices': [28, 39]},
#      {'text': 'images', 'indices': [40, 47]},
#      {'text': 'DeepLearning', 'indices': [48, 61]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/QmZQScEuaM',
#       'expanded_url': 'https://unsplash.com/blog/the-unsplash-dataset/',
#       'display_url': 'unsplash.com/blog/the-unspl…',
#       'indices': [62, 85]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 34489311,
#     'id_str': '34489311',
#     'name': 'Ganesh Bhat',
#     'screen_name': 'ganesh3',
#     'location': 'Mumbai, India',
#     'description': '#CX | #Mfg | #Bank | #FinTech | #Strategy | #OpenSource | #Environment | #Analytics | #IoT | #awscertified  Previously @TCS @Infosys @SPJainGlobal',
#     'url': 'https://t.co/yocpBM00N2',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/yocpBM00N2',
#         'expanded_url': 'http://iotechstory.wordpress.com',
#         'display_url': 'iotechstory.wordpress.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 563,
#     'friends_count': 937,
#     'listed_count': 119,
#     'created_at': 'Thu Apr 23 01:58:05 +0000 2009',
#     'favourites_count': 2399,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 19801,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '0F0A02',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme12/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme12/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1188462850118995968/yUKtjg_o_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1188462850118995968/yUKtjg_o_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/34489311/1501338512',
#     'profile_link_color': '19CF86',
#     'profile_sidebar_border_color': 'BCB302',
#     'profile_sidebar_fill_color': '171106',
#     'profile_text_color': '473623',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:54:04 +0000 2020',
#    'id': 1292383633723068418,
#    'id_str': '1292383633723068418',
#    'text': 'RT @SamuelAkins12: This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, color e…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SamuelAkins12',
#       'name': 'Samuel Akinosho®',
#       'id': 1053247241618685953,
#       'id_str': '1053247241618685953',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 202791468,
#     'id_str': '202791468',
#     'name': '𝕶𝖗𝖎𝖘𝖙𝖎𝖓𝖊 𝕾𝖑𝖎𝖘𝖆𝖓𝖊',
#     'screen_name': 'dixie_chick19',
#     'location': '',
#     'description': '𝖓𝖔𝖙 𝖌𝖗𝖊𝖆𝖙,\n𝖓𝖔𝖙 𝖙𝖊𝖗𝖗𝖎𝖇𝖑𝖊',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 161,
#     'friends_count': 1281,
#     'listed_count': 2,
#     'created_at': 'Thu Oct 14 20:50:05 +0000 2010',
#     'favourites_count': 12170,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 3205,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1288961216271056902/MJKODYTl_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1288961216271056902/MJKODYTl_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/202791468/1443903003',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 06:26:45 +0000 2020',
#     'id': 1292346561079513090,
#     'id_str': '1292346561079513090',
#     'text': 'This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, co… https://t.co/mZi6wxZMz1',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mZi6wxZMz1',
#        'expanded_url': 'https://twitter.com/i/web/status/1292346561079513090',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1053247241618685953,
#      'id_str': '1053247241618685953',
#      'name': 'Samuel Akinosho®',
#      'screen_name': 'SamuelAkins12',
#      'location': 'Africa ',
#      'description': "Serial Entrepreneur, Ex. @microsoft @cisco |  AI & IoT Engr. | CEH |Passionate about Africa's development 🌍 #MUFC",
#      'url': 'https://t.co/Hzc0CDYj9g',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Hzc0CDYj9g',
#          'expanded_url': 'https://linktr.ee/SamuelAkinosho',
#          'display_url': 'linktr.ee/SamuelAkinosho',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2379,
#      'friends_count': 1622,
#      'listed_count': 8,
#      'created_at': 'Fri Oct 19 11:31:25 +0000 2018',
#      'favourites_count': 29978,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1053247241618685953/1590793590',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 169,
#     'favorite_count': 346,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 169,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:53:31 +0000 2020',
#    'id': 1292383496636424193,
#    'id_str': '1292383496636424193',
#    'text': 'RT @SamuelAkins12: This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, color e…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SamuelAkins12',
#       'name': 'Samuel Akinosho®',
#       'id': 1053247241618685953,
#       'id_str': '1053247241618685953',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 22000414,
#     'id_str': '22000414',
#     'name': 'Kiwi Paul',
#     'screen_name': 'squashypigeon',
#     'location': 'London, Europe.',
#     'description': 'Grumpy bipedal mammal, 70% water (ish). Homesick Kiwi. Atheist. Foodie.\nCAD, Bushcraft, Space, Homebrew, BBQ, Kites, Making, Eco, Self-sufficiency.\nI RT a LOT!',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 815,
#     'friends_count': 1809,
#     'listed_count': 49,
#     'created_at': 'Thu Feb 26 11:44:14 +0000 2009',
#     'favourites_count': 61588,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 49558,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '510800',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1051607371410227200/k-dFRFay_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1051607371410227200/k-dFRFay_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/22000414/1374073359',
#     'profile_link_color': 'E0912A',
#     'profile_sidebar_border_color': '3D0702',
#     'profile_sidebar_fill_color': '2C1703',
#     'profile_text_color': 'A16A23',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 06:26:45 +0000 2020',
#     'id': 1292346561079513090,
#     'id_str': '1292346561079513090',
#     'text': 'This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, co… https://t.co/mZi6wxZMz1',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mZi6wxZMz1',
#        'expanded_url': 'https://twitter.com/i/web/status/1292346561079513090',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1053247241618685953,
#      'id_str': '1053247241618685953',
#      'name': 'Samuel Akinosho®',
#      'screen_name': 'SamuelAkins12',
#      'location': 'Africa ',
#      'description': "Serial Entrepreneur, Ex. @microsoft @cisco |  AI & IoT Engr. | CEH |Passionate about Africa's development 🌍 #MUFC",
#      'url': 'https://t.co/Hzc0CDYj9g',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Hzc0CDYj9g',
#          'expanded_url': 'https://linktr.ee/SamuelAkinosho',
#          'display_url': 'linktr.ee/SamuelAkinosho',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2379,
#      'friends_count': 1622,
#      'listed_count': 8,
#      'created_at': 'Fri Oct 19 11:31:25 +0000 2018',
#      'favourites_count': 29978,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1053247241618685953/1590793590',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 169,
#     'favorite_count': 346,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 169,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:53:29 +0000 2020',
#    'id': 1292383488642080770,
#    'id_str': '1292383488642080770',
#    'text': 'RT @SamuelAkins12: This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, color e…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SamuelAkins12',
#       'name': 'Samuel Akinosho®',
#       'id': 1053247241618685953,
#       'id_str': '1053247241618685953',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 989752852112293889,
#     'id_str': '989752852112293889',
#     'name': 'Chad Clifton',
#     'screen_name': 'ChadClifton10',
#     'location': 'South West, England',
#     'description': '#FBPE \n\nMorality has never been a huge part of humanity - @missusbojangles',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 214,
#     'friends_count': 747,
#     'listed_count': 2,
#     'created_at': 'Fri Apr 27 06:27:23 +0000 2018',
#     'favourites_count': 4101,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 5027,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1208500687153356806/6Xyv2uSf_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1208500687153356806/6Xyv2uSf_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/989752852112293889/1546551542',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 06:26:45 +0000 2020',
#     'id': 1292346561079513090,
#     'id_str': '1292346561079513090',
#     'text': 'This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, co… https://t.co/mZi6wxZMz1',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mZi6wxZMz1',
#        'expanded_url': 'https://twitter.com/i/web/status/1292346561079513090',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1053247241618685953,
#      'id_str': '1053247241618685953',
#      'name': 'Samuel Akinosho®',
#      'screen_name': 'SamuelAkins12',
#      'location': 'Africa ',
#      'description': "Serial Entrepreneur, Ex. @microsoft @cisco |  AI & IoT Engr. | CEH |Passionate about Africa's development 🌍 #MUFC",
#      'url': 'https://t.co/Hzc0CDYj9g',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Hzc0CDYj9g',
#          'expanded_url': 'https://linktr.ee/SamuelAkinosho',
#          'display_url': 'linktr.ee/SamuelAkinosho',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2379,
#      'friends_count': 1622,
#      'listed_count': 8,
#      'created_at': 'Fri Oct 19 11:31:25 +0000 2018',
#      'favourites_count': 29978,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1053247241618685953/1590793590',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 169,
#     'favorite_count': 346,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 169,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:53:23 +0000 2020',
#    'id': 1292383461664346112,
#    'id_str': '1292383461664346112',
#    'text': 'RT @SamuelAkins12: This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, color e…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SamuelAkins12',
#       'name': 'Samuel Akinosho®',
#       'id': 1053247241618685953,
#       'id_str': '1053247241618685953',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 63523564,
#     'id_str': '63523564',
#     'name': 'Chris',
#     'screen_name': 'chrishughesuk',
#     'location': 'England',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 437,
#     'friends_count': 1106,
#     'listed_count': 9,
#     'created_at': 'Thu Aug 06 19:56:34 +0000 2009',
#     'favourites_count': 2213,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 1002,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1285961035585859586/tCXBFXbe_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1285961035585859586/tCXBFXbe_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 06:26:45 +0000 2020',
#     'id': 1292346561079513090,
#     'id_str': '1292346561079513090',
#     'text': 'This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, co… https://t.co/mZi6wxZMz1',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mZi6wxZMz1',
#        'expanded_url': 'https://twitter.com/i/web/status/1292346561079513090',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1053247241618685953,
#      'id_str': '1053247241618685953',
#      'name': 'Samuel Akinosho®',
#      'screen_name': 'SamuelAkins12',
#      'location': 'Africa ',
#      'description': "Serial Entrepreneur, Ex. @microsoft @cisco |  AI & IoT Engr. | CEH |Passionate about Africa's development 🌍 #MUFC",
#      'url': 'https://t.co/Hzc0CDYj9g',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Hzc0CDYj9g',
#          'expanded_url': 'https://linktr.ee/SamuelAkinosho',
#          'display_url': 'linktr.ee/SamuelAkinosho',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2379,
#      'friends_count': 1622,
#      'listed_count': 8,
#      'created_at': 'Fri Oct 19 11:31:25 +0000 2018',
#      'favourites_count': 29978,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1053247241618685953/1590793590',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 169,
#     'favorite_count': 346,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 169,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:53:21 +0000 2020',
#    'id': 1292383455989379073,
#    'id_str': '1292383455989379073',
#    'text': 'RT @SamuelAkins12: This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, color e…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SamuelAkins12',
#       'name': 'Samuel Akinosho®',
#       'id': 1053247241618685953,
#       'id_str': '1053247241618685953',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 26011538,
#     'id_str': '26011538',
#     'name': 'SallyfortheEU 3.5% #RejoinEU #FBPE',
#     'screen_name': 'sallydipple',
#     'location': 'Wirksworth, England',
#     'description': 'You can take the girl out of the EU but you can’t take the EU out of the girl. #RemainersWereRight',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3124,
#     'friends_count': 3111,
#     'listed_count': 19,
#     'created_at': 'Mon Mar 23 14:34:59 +0000 2009',
#     'favourites_count': 92882,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 87347,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'DBE9ED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme17/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme17/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1167001895866687488/_0_9u0Pk_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1167001895866687488/_0_9u0Pk_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/26011538/1567069909',
#     'profile_link_color': 'FF691F',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 06:26:45 +0000 2020',
#     'id': 1292346561079513090,
#     'id_str': '1292346561079513090',
#     'text': 'This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, co… https://t.co/mZi6wxZMz1',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mZi6wxZMz1',
#        'expanded_url': 'https://twitter.com/i/web/status/1292346561079513090',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1053247241618685953,
#      'id_str': '1053247241618685953',
#      'name': 'Samuel Akinosho®',
#      'screen_name': 'SamuelAkins12',
#      'location': 'Africa ',
#      'description': "Serial Entrepreneur, Ex. @microsoft @cisco |  AI & IoT Engr. | CEH |Passionate about Africa's development 🌍 #MUFC",
#      'url': 'https://t.co/Hzc0CDYj9g',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Hzc0CDYj9g',
#          'expanded_url': 'https://linktr.ee/SamuelAkinosho',
#          'display_url': 'linktr.ee/SamuelAkinosho',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2379,
#      'friends_count': 1622,
#      'listed_count': 8,
#      'created_at': 'Fri Oct 19 11:31:25 +0000 2018',
#      'favourites_count': 29978,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1053247241618685953/1590793590',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 169,
#     'favorite_count': 346,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 169,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:53:20 +0000 2020',
#    'id': 1292383448229961730,
#    'id_str': '1292383448229961730',
#    'text': 'RT @SamuelAkins12: This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, color e…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SamuelAkins12',
#       'name': 'Samuel Akinosho®',
#       'id': 1053247241618685953,
#       'id_str': '1053247241618685953',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2724931139,
#     'id_str': '2724931139',
#     'name': 'mumma smurf 💙❤️💙❤️💙❤️💙',
#     'screen_name': 'MummaSmurf01',
#     'location': ' Stratford upon Avon, England',
#     'description': "I'm a girl. For animal rights, against animal cruelty.",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 177,
#     'friends_count': 501,
#     'listed_count': 3,
#     'created_at': 'Sat Jul 26 06:22:13 +0000 2014',
#     'favourites_count': 22340,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 6551,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/620682727784906752/dgtF-flK_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/620682727784906752/dgtF-flK_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2724931139/1420277000',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 06:26:45 +0000 2020',
#     'id': 1292346561079513090,
#     'id_str': '1292346561079513090',
#     'text': 'This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, co… https://t.co/mZi6wxZMz1',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mZi6wxZMz1',
#        'expanded_url': 'https://twitter.com/i/web/status/1292346561079513090',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1053247241618685953,
#      'id_str': '1053247241618685953',
#      'name': 'Samuel Akinosho®',
#      'screen_name': 'SamuelAkins12',
#      'location': 'Africa ',
#      'description': "Serial Entrepreneur, Ex. @microsoft @cisco |  AI & IoT Engr. | CEH |Passionate about Africa's development 🌍 #MUFC",
#      'url': 'https://t.co/Hzc0CDYj9g',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Hzc0CDYj9g',
#          'expanded_url': 'https://linktr.ee/SamuelAkinosho',
#          'display_url': 'linktr.ee/SamuelAkinosho',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2379,
#      'friends_count': 1622,
#      'listed_count': 8,
#      'created_at': 'Fri Oct 19 11:31:25 +0000 2018',
#      'favourites_count': 29978,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1053247241618685953/1590793590',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 169,
#     'favorite_count': 346,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 169,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:53:18 +0000 2020',
#    'id': 1292383441879801856,
#    'id_str': '1292383441879801856',
#    'text': 'RT @SamuelAkins12: This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, color e…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SamuelAkins12',
#       'name': 'Samuel Akinosho®',
#       'id': 1053247241618685953,
#       'id_str': '1053247241618685953',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 209965204,
#     'id_str': '209965204',
#     'name': 'Ed Sweetman',
#     'screen_name': 'humanpilot',
#     'location': 'England',
#     'description': 'Photographer at Getty, Adobe, Dreamstime and Shutterstock. Illustrator. Bookworm. Cinema. We are in the arena of the absurd.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2835,
#     'friends_count': 2850,
#     'listed_count': 143,
#     'created_at': 'Sat Oct 30 07:46:45 +0000 2010',
#     'favourites_count': 82340,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 33347,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1286400468185501698/swFtPMuO_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1286400468185501698/swFtPMuO_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/209965204/1596664672',
#     'profile_link_color': 'E81C4F',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 06:26:45 +0000 2020',
#     'id': 1292346561079513090,
#     'id_str': '1292346561079513090',
#     'text': 'This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, co… https://t.co/mZi6wxZMz1',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mZi6wxZMz1',
#        'expanded_url': 'https://twitter.com/i/web/status/1292346561079513090',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1053247241618685953,
#      'id_str': '1053247241618685953',
#      'name': 'Samuel Akinosho®',
#      'screen_name': 'SamuelAkins12',
#      'location': 'Africa ',
#      'description': "Serial Entrepreneur, Ex. @microsoft @cisco |  AI & IoT Engr. | CEH |Passionate about Africa's development 🌍 #MUFC",
#      'url': 'https://t.co/Hzc0CDYj9g',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Hzc0CDYj9g',
#          'expanded_url': 'https://linktr.ee/SamuelAkinosho',
#          'display_url': 'linktr.ee/SamuelAkinosho',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2379,
#      'friends_count': 1622,
#      'listed_count': 8,
#      'created_at': 'Fri Oct 19 11:31:25 +0000 2018',
#      'favourites_count': 29978,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1053247241618685953/1590793590',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 169,
#     'favorite_count': 346,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 169,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:53:04 +0000 2020',
#    'id': 1292383382672990208,
#    'id_str': '1292383382672990208',
#    'text': 'RT @IntisarMahee: I just published 5 Stunning Reasons to Learn Python in 2020 https://t.co/oB8QKogCm9 \n.\n.\n.\n.\n.\n.\n.\n#BigData #Analytics #D…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'BigData', 'indices': [117, 125]},
#      {'text': 'Analytics', 'indices': [126, 136]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'IntisarMahee',
#       'name': 'Intisar Mahee',
#       'id': 118302422,
#       'id_str': '118302422',
#       'indices': [3, 16]}],
#     'urls': [{'url': 'https://t.co/oB8QKogCm9',
#       'expanded_url': 'https://link.medium.com/e2PryCRLN8',
#       'display_url': 'link.medium.com/e2PryCRLN8',
#       'indices': [78, 101]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twinybots.com" rel="nofollow">TwinyBots</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1154381411614416906,
#     'id_str': '1154381411614416906',
#     'name': 'Well, that’s interesting tech',
#     'screen_name': '1nterestingTech',
#     'location': 'United Kingdom',
#     'description': 'Life’s too short for boring #tech. I write articles to demystifying tech one example at a time. Themes cover - #Tech4Good #AI #IOT, #5G, and other #EmergingTech',
#     'url': 'https://t.co/r7nD8V7XJX',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/r7nD8V7XJX',
#         'expanded_url': 'http://wellthatsinteresting.tech',
# ...
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mZi6wxZMz1',
#        'expanded_url': 'https://twitter.com/i/web/status/1292346561079513090',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1053247241618685953,
#      'id_str': '1053247241618685953',
#      'name': 'Samuel Akinosho®',
#      'screen_name': 'SamuelAkins12',
#      'location': 'Africa ',
#      'description': "Serial Entrepreneur, Ex. @microsoft @cisco |  AI & IoT Engr. | CEH |Passionate about Africa's development 🌍 #MUFC",
#      'url': 'https://t.co/Hzc0CDYj9g',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Hzc0CDYj9g',
#          'expanded_url': 'https://linktr.ee/SamuelAkinosho',
#          'display_url': 'linktr.ee/SamuelAkinosho',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2379,
#      'friends_count': 1622,
#      'listed_count': 8,
#      'created_at': 'Fri Oct 19 11:31:25 +0000 2018',
#      'favourites_count': 29978,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1053247241618685953/1590793590',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 169,
#     'favorite_count': 346,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 169,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:42:17 +0000 2020',
#    'id': 1292380670011072512,
#    'id_str': '1292380670011072512',
#    'text': 'RT @SamuelAkins12: This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, color e…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SamuelAkins12',
#       'name': 'Samuel Akinosho®',
#       'id': 1053247241618685953,
#       'id_str': '1053247241618685953',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 39275167,
#     'id_str': '39275167',
#     'name': 'Joumana Medlej',
#     'screen_name': 'joumajnouna',
#     'location': 'London, England',
#     'description': 'Artist specialised in Kufic scripts/natural materials. Londoner transplanted from Beirut. Earth lover, plastic-free, slow living. Shop: https://t.co/5FBNjrQIQW',
#     'url': 'https://t.co/7ZAQzhp4pJ',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/7ZAQzhp4pJ',
#         'expanded_url': 'http://majnouna.com',
#         'display_url': 'majnouna.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/5FBNjrQIQW',
#         'expanded_url': 'http://majnouna.com/shop',
#         'display_url': 'majnouna.com/shop',
#         'indices': [136, 159]}]}},
#     'protected': False,
#     'followers_count': 4090,
#     'friends_count': 269,
#     'listed_count': 192,
#     'created_at': 'Mon May 11 15:44:52 +0000 2009',
#     'favourites_count': 6348,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 40106,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '3B94D9',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1285508715538456579/RLe4SuXg_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1285508715538456579/RLe4SuXg_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/39275167/1595324300',
#     'profile_link_color': '89C9FA',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 06:26:45 +0000 2020',
#     'id': 1292346561079513090,
#     'id_str': '1292346561079513090',
#     'text': 'This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, co… https://t.co/mZi6wxZMz1',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mZi6wxZMz1',
#        'expanded_url': 'https://twitter.com/i/web/status/1292346561079513090',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1053247241618685953,
#      'id_str': '1053247241618685953',
#      'name': 'Samuel Akinosho®',
#      'screen_name': 'SamuelAkins12',
#      'location': 'Africa ',
#      'description': "Serial Entrepreneur, Ex. @microsoft @cisco |  AI & IoT Engr. | CEH |Passionate about Africa's development 🌍 #MUFC",
#      'url': 'https://t.co/Hzc0CDYj9g',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Hzc0CDYj9g',
#          'expanded_url': 'https://linktr.ee/SamuelAkinosho',
#          'display_url': 'linktr.ee/SamuelAkinosho',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2379,
#      'friends_count': 1622,
#      'listed_count': 8,
#      'created_at': 'Fri Oct 19 11:31:25 +0000 2018',
#      'favourites_count': 29978,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1053247241618685953/1590793590',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 169,
#     'favorite_count': 346,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 169,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:42:05 +0000 2020',
#    'id': 1292380618941255681,
#    'id_str': '1292380618941255681',
#    'text': 'RT @SamuelAkins12: This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, color e…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SamuelAkins12',
#       'name': 'Samuel Akinosho®',
#       'id': 1053247241618685953,
#       'id_str': '1053247241618685953',
#       'indices': [3, 17]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1190237405925847040,
#     'id_str': '1190237405925847040',
#     'name': 'Jarbo',
#     'screen_name': 'Jarbo92592799',
#     'location': '',
#     'description': 'More woke than cunt',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 82,
#     'friends_count': 161,
#     'listed_count': 1,
#     'created_at': 'Fri Nov 01 12:01:54 +0000 2019',
#     'favourites_count': 12288,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 3921,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1193492018170880000/lmHdTCsE_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1193492018170880000/lmHdTCsE_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 06:26:45 +0000 2020',
#     'id': 1292346561079513090,
#     'id_str': '1292346561079513090',
#     'text': 'This is a day at the beach in 1896!!  All hail 👉🏾 Deep learning algorithms for enhanced image interpolation, HD, co… https://t.co/mZi6wxZMz1',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/mZi6wxZMz1',
#        'expanded_url': 'https://twitter.com/i/web/status/1292346561079513090',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1053247241618685953,
#      'id_str': '1053247241618685953',
#      'name': 'Samuel Akinosho®',
#      'screen_name': 'SamuelAkins12',
#      'location': 'Africa ',
#      'description': "Serial Entrepreneur, Ex. @microsoft @cisco |  AI & IoT Engr. | CEH |Passionate about Africa's development 🌍 #MUFC",
#      'url': 'https://t.co/Hzc0CDYj9g',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Hzc0CDYj9g',
#          'expanded_url': 'https://linktr.ee/SamuelAkinosho',
#          'display_url': 'linktr.ee/SamuelAkinosho',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2379,
#      'friends_count': 1622,
#      'listed_count': 8,
#      'created_at': 'Fri Oct 19 11:31:25 +0000 2018',
#      'favourites_count': 29978,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 4478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261443161001529345/2ee65DjC_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1053247241618685953/1590793590',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 169,
#     'favorite_count': 346,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 169,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.139,
#   'max_id': 1292383645915701249,
#   'max_id_str': '1292383645915701249',
#   'next_results': '?max_id=1292380618941255680&q=%23deeplearning&count=75&include_entities=1&result_type=recent%2Cpopular',
#   'query': '%23deeplearning',
#   'refresh_url': '?since_id=1292383645915701249&q=%23deeplearning&result_type=recent%2Cpopular&include_entities=1',
#   'count': 75,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
def find_hashtag(hashtag, count=None, search_type=None):
   
    if not hashtag.startswith('#'):
        hashtag='%23'+hashtag
    else:
        hashtag='%23' + hashtag.strip('#')

    if search_type != None:
        searchtype=search_type.replace('/', ',')
        url =f'https://api.twitter.com/1.1/search/tweets.json?q={hashtag}&count={count}&result_type={searchtype}'
        hashtag_search=requests.get(url,auth=auth).json()
    else:
        url =f'https://api.twitter.com/1.1/search/tweets.json?q={hashtag}&count={count}'
    return requests.get(url,auth=auth).json()

# %%
find_hashtag('#DataScience', count=50)
# Out:
# {'statuses': [{'created_at': 'Sun Aug 09 08:54:10 +0000 2020',
#    'id': 1292383660604358657,
#    'id_str': '1292383660604358657',
#    'text': "RT @realColinMac: 💠 Did you hear about the #programmer arrested before they could check their #code?...Arrested for a crime; they didn't co…",
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'programmer', 'indices': [43, 54]},
#      {'text': 'code', 'indices': [94, 99]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'realColinMac',
#       'name': 'Colin McGuire',
#       'id': 892214142672683008,
#       'id_str': '892214142672683008',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://labnol.org/" rel="nofollow">Web design Retweet</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1266908988127481862,
#     'id_str': '1266908988127481862',
#     'name': 'Kishan Pindariya Ahir',
#     'screen_name': 'BeingKishna',
#     'location': 'Rajkot, India',
#     'description': '👨\u200d💻 Software Engineer 🌍 Web Designer 🖼️ Graphics Designer 📝 Blogger. 💻 Designing from 1⃣6⃣ years of age.\n#javascript • #designer • #devbhumidwarka • #ahir',
#     'url': 'https://t.co/uvzVeOGqr5',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/uvzVeOGqr5',
#         'expanded_url': 'https://www.designhub4u.com',
#         'display_url': 'designhub4u.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 277,
#     'friends_count': 264,
#     'listed_count': 3,
#     'created_at': 'Sun May 31 01:47:10 +0000 2020',
#     'favourites_count': 162,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 2364,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1285234509097529344/1qQKcO7T_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1285234509097529344/1qQKcO7T_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1266908988127481862/1596901511',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 08:43:42 +0000 2020',
#     'id': 1292381027206180865,
#     'id_str': '1292381027206180865',
#     'text': '💠 Did you hear about the #programmer arrested before they could check their #code?...Arrested for a crime; they did… https://t.co/B6dMi6fCSz',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'programmer', 'indices': [25, 36]},
#       {'text': 'code', 'indices': [76, 81]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/B6dMi6fCSz',
#        'expanded_url': 'https://twitter.com/i/web/status/1292381027206180865',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 892214142672683008,
#      'id_str': '892214142672683008',
#      'name': 'Colin McGuire',
#      'screen_name': 'realColinMac',
#      'location': 'Canada, mainly #YXE #YEG',
#      'description': '💡Entrepreneur/💵 Investor - 🇨🇦 #TechEvangelist - #Futurist -\n- Foodie - Animal lover 🐈 🐕 #cdntech #AI #AR #VR #VC #Startup',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 13152,
#      'friends_count': 7917,
#      'listed_count': 148,
#      'created_at': 'Tue Aug 01 02:43:22 +0000 2017',
#      'favourites_count': 84324,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 42681,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1013521217540837376/3BmkgDBO_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1013521217540837376/3BmkgDBO_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/892214142672683008/1504399114',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 16,
#     'favorite_count': 6,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 16,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:53:56 +0000 2020',
#    'id': 1292383603167436802,
#    'id_str': '1292383603167436802',
#    'text': 'Doing Data Science: Straight Talk from the Frontline https://t.co/pcBpO4J4rn #DataScience',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DataScience', 'indices': [77, 89]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/pcBpO4J4rn',
#       'expanded_url': 'https://amzn.to/2SRt2BJ',
#       'display_url': 'amzn.to/2SRt2BJ',
#       'indices': [53, 76]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://twitter.com/DD_FaFa_" rel="nofollow">FAFA_DD_App_2</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2728657237,
#     'id_str': '2728657237',
#     'name': 'fafa.👩🏻\u200d💻',
#     'screen_name': 'DD_FaFa_',
#     'location': 'Melbourne Australia',
#     'description': 'Customer Insights Director @DATAFYiNG \nI tweet mostly about #DataScience with #Coffee',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 23619,
#     'friends_count': 12613,
#     'listed_count': 729,
#     'created_at': 'Wed Aug 13 05:22:09 +0000 2014',
#     'favourites_count': 48714,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 99577,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/917289210289176576/JzqB9ZW6_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/917289210289176576/JzqB9ZW6_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2728657237/1409832944',
#     'profile_link_color': 'D81E5B',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:53:04 +0000 2020',
#    'id': 1292383382672990208,
#    'id_str': '1292383382672990208',
#    'text': 'RT @IntisarMahee: I just published 5 Stunning Reasons to Learn Python in 2020 https://t.co/oB8QKogCm9 \n.\n.\n.\n.\n.\n.\n.\n#BigData #Analytics #D…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'BigData', 'indices': [117, 125]},
#      {'text': 'Analytics', 'indices': [126, 136]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'IntisarMahee',
#       'name': 'Intisar Mahee',
#       'id': 118302422,
#       'id_str': '118302422',
#       'indices': [3, 16]}],
#     'urls': [{'url': 'https://t.co/oB8QKogCm9',
#       'expanded_url': 'https://link.medium.com/e2PryCRLN8',
#       'display_url': 'link.medium.com/e2PryCRLN8',
#       'indices': [78, 101]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twinybots.com" rel="nofollow">TwinyBots</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1154381411614416906,
#     'id_str': '1154381411614416906',
#     'name': 'Well, that’s interesting tech',
#     'screen_name': '1nterestingTech',
#     'location': 'United Kingdom',
#     'description': 'Life’s too short for boring #tech. I write articles to demystifying tech one example at a time. Themes cover - #Tech4Good #AI #IOT, #5G, and other #EmergingTech',
#     'url': 'https://t.co/r7nD8V7XJX',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/r7nD8V7XJX',
#         'expanded_url': 'http://wellthatsinteresting.tech',
#         'display_url': 'wellthatsinteresting.tech',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 656,
#     'friends_count': 1940,
#     'listed_count': 28,
#     'created_at': 'Thu Jul 25 13:22:30 +0000 2019',
#     'favourites_count': 10344,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 50396,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1154383562088599552/RbyNTvSg_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1154383562088599552/RbyNTvSg_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1154381411614416906/1564600386',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 05:09:01 +0000 2020',
#     'id': 1292326997222281216,
#     'id_str': '1292326997222281216',
#     'text': 'I just published 5 Stunning Reasons to Learn Python in 2020 https://t.co/oB8QKogCm9 \n.\n.\n.\n.\n.\n.\n.\n#BigData… https://t.co/RHG50szYif',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'BigData', 'indices': [99, 107]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/oB8QKogCm9',
#        'expanded_url': 'https://link.medium.com/e2PryCRLN8',
#        'display_url': 'link.medium.com/e2PryCRLN8',
#        'indices': [60, 83]},
#       {'url': 'https://t.co/RHG50szYif',
#        'expanded_url': 'https://twitter.com/i/web/status/1292326997222281216',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [109, 132]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 118302422,
#      'id_str': '118302422',
#      'name': 'Intisar Mahee',
#      'screen_name': 'IntisarMahee',
#      'location': 'Dhaka, Bangladesh',
#      'description': 'Mechatronics Engineer • Digital Marketer • Photographer • Content Writer',
#      'url': 'https://t.co/8tp3sKETaI',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/8tp3sKETaI',
#          'expanded_url': 'https://intisar-mahee.weebly.com/',
#          'display_url': 'intisar-mahee.weebly.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 20,
#      'friends_count': 25,
#      'listed_count': 0,
#      'created_at': 'Sun Feb 28 06:48:51 +0000 2010',
#      'favourites_count': 30,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 39,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1270697402912014337/VhYIU6XU_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1270697402912014337/VhYIU6XU_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/118302422/1594223839',
#      'profile_link_color': '19CF86',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 32,
#     'favorite_count': 18,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 32,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:52:53 +0000 2020',
#    'id': 1292383338267848704,
#    'id_str': '1292383338267848704',
#    'text': 'RT @KirkDBorne: Here are some of my favorite books &amp; things: https://t.co/fmHsJvad9P\n...covering #BigData #DataScience #AI #Bots #MachineLe…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'BigData', 'indices': [101, 109]},
#      {'text': 'DataScience', 'indices': [110, 122]},
#      {'text': 'AI', 'indices': [123, 126]},
#      {'text': 'Bots', 'indices': [127, 132]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'KirkDBorne',
#       'name': 'Kirk Borne',
#       'id': 534563976,
#       'id_str': '534563976',
#       'indices': [3, 14]}],
#     'urls': [{'url': 'https://t.co/fmHsJvad9P',
#       'expanded_url': 'https://bit.ly/2WcVqzo',
#       'display_url': 'bit.ly/2WcVqzo',
#       'indices': [65, 88]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 934812420,
#     'id_str': '934812420',
#     'name': 'Naeem Zafar',
#     'screen_name': 'Naeem_Zaffar',
#     'location': 'Lahore, Pakistan',
#     'description': "UET, Engineer, \nThe truth is hard to swallow when you're choking on your Pride.",
#     'url': 'https://t.co/HLYVaUHL3m',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/HLYVaUHL3m',
#         'expanded_url': 'http://www.facebook.com/naem.zafar',
#         'display_url': 'facebook.com/naem.zafar',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 49,
#     'friends_count': 279,
#     'listed_count': 1,
#     'created_at': 'Thu Nov 08 15:59:23 +0000 2012',
#     'favourites_count': 68,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 101,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme8/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme8/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/895610248135942145/qFXEReIp_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/895610248135942145/qFXEReIp_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/934812420/1439813592',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 05:02:35 +0000 2020',
#     'id': 1292325381295558656,
#     'id_str': '1292325381295558656',
#     'text': 'Here are some of my favorite books &amp; things: https://t.co/fmHsJvad9P\n...covering #BigData #DataScience #AI #Bots… https://t.co/cC8QR8yNh9',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'BigData', 'indices': [85, 93]},
#       {'text': 'DataScience', 'indices': [94, 106]},
#       {'text': 'AI', 'indices': [107, 110]},
#       {'text': 'Bots', 'indices': [111, 116]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/fmHsJvad9P',
#        'expanded_url': 'https://bit.ly/2WcVqzo',
#        'display_url': 'bit.ly/2WcVqzo',
#        'indices': [49, 72]},
#       {'url': 'https://t.co/cC8QR8yNh9',
#        'expanded_url': 'https://twitter.com/i/web/status/1292325381295558656',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [118, 141]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 534563976,
#      'id_str': '534563976',
#      'name': 'Kirk Borne',
#      'screen_name': 'KirkDBorne',
#      'location': 'Maryland, USA',
#      'description': 'Principal Data Scientist @BoozAllen. Global Speaker. Top #BigData #DataScience #AI Influencer. PhD Astrophysicist. (Views = my own) https://t.co/abP8DkYJY2 📊🔭',
#      'url': 'https://t.co/tWlmeuTlR7',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/tWlmeuTlR7',
#          'expanded_url': 'http://www.linkedin.com/in/kirkdborne',
#          'display_url': 'linkedin.com/in/kirkdborne',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/abP8DkYJY2',
#          'expanded_url': 'http://rocketdatascience.org',
#          'display_url': 'rocketdatascience.org',
#          'indices': [132, 155]}]}},
#      'protected': False,
#      'followers_count': 265299,
#      'friends_count': 10880,
#      'listed_count': 8072,
#      'created_at': 'Fri Mar 23 16:35:17 +0000 2012',
#      'favourites_count': 203868,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 122621,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/534563976/1590790599',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 69,
#     'favorite_count': 146,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 69,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:52:20 +0000 2020',
#    'id': 1292383197376860162,
#    'id_str': '1292383197376860162',
#    'text': 'RT @DataScienceFr: What are Classification and Regression in ML? - https://t.co/yTXtd6BMZX - thanks @RichardEudes #DataScience #DS,#BigData…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DataScience', 'indices': [114, 126]},
#      {'text': 'DS', 'indices': [127, 130]},
#      {'text': 'BigData', 'indices': [131, 139]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'DataScienceFr',
#       'name': 'Data Scientists',
#       'id': 1269383796,
#       'id_str': '1269383796',
#       'indices': [3, 17]},
#      {'screen_name': 'RichardEudes',
#       'name': 'Richard Eudes, PhD',
#       'id': 49427323,
#       'id_str': '49427323',
#       'indices': [100, 113]}],
#     'urls': [{'url': 'https://t.co/yTXtd6BMZX',
#       'expanded_url': 'https://bit.ly/2XHYgA1',
#       'display_url': 'bit.ly/2XHYgA1',
#       'indices': [67, 90]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://www.fabricio-dev.com.br/" rel="nofollow">twitter-bot-fab</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1051649960,
#     'id_str': '1051649960',
#     'name': 'Fabricio Cavalcante',
#     'screen_name': 'Fabriciosx',
#     'location': 'Rio de janeiro',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 348,
#     'friends_count': 110,
#     'listed_count': 4,
#     'created_at': 'Tue Jan 01 02:32:07 +0000 2013',
#     'favourites_count': 1,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 35148,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '9FB272',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/445285336663326720/Xc9HLhJB_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/445285336663326720/Xc9HLhJB_normal.jpeg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1051649960/1357242372',
#     'profile_link_color': '799A7B',
#     'profile_sidebar_border_color': 'D0C9AF',
#     'profile_sidebar_fill_color': '292C25',
#     'profile_text_color': '457079',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 07:56:23 +0000 2020',
#     'id': 1292369117597532161,
#     'id_str': '1292369117597532161',
#     'text': 'What are Classification and Regression in ML? - https://t.co/yTXtd6BMZX - thanks @RichardEudes #DataScience #DS,… https://t.co/nZpZz0MUY8',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'DataScience', 'indices': [95, 107]},
#       {'text': 'DS', 'indices': [108, 111]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'RichardEudes',
#        'name': 'Richard Eudes, PhD',
#        'id': 49427323,
#        'id_str': '49427323',
#        'indices': [81, 94]}],
#      'urls': [{'url': 'https://t.co/yTXtd6BMZX',
#        'expanded_url': 'https://bit.ly/2XHYgA1',
#        'display_url': 'bit.ly/2XHYgA1',
#        'indices': [48, 71]},
#       {'url': 'https://t.co/nZpZz0MUY8',
#        'expanded_url': 'https://twitter.com/i/web/status/1292369117597532161',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [114, 137]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1269383796,
#      'id_str': '1269383796',
#      'name': 'Data Scientists',
#      'screen_name': 'DataScienceFr',
#      'location': 'Paris, France',
#      'description': '#BigData #DataScience #Analytics #Statistics #PredictiveModeling #ComputerScience #MachineLearning',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2350,
#      'friends_count': 140,
#      'listed_count': 280,
#      'created_at': 'Fri Mar 15 10:33:24 +0000 2013',
#      'favourites_count': 5,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 30611,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/584756112773226496/djAQtEO5_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/584756112773226496/djAQtEO5_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1269383796/1428251696',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:52:04 +0000 2020',
#    'id': 1292383132331769857,
#    'id_str': '1292383132331769857',
#    'text': 'RT @chidambara09: https://t.co/4ZQzSBIOvh @MailOnline\n\nCrowded bars R most dangers, spreading #Covid19,\nthan #flights\n\n#bigdata \n\n#dataScie…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Covid19', 'indices': [94, 102]},
#      {'text': 'flights', 'indices': [109, 117]},
#      {'text': 'bigdata', 'indices': [119, 127]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'chidambara09',
#       'name': 'Chidambara .ML.',
#       'id': 737142202481016832,
#       'id_str': '737142202481016832',
#       'indices': [3, 16]},
#      {'screen_name': 'MailOnline',
#       'name': 'Daily Mail Online',
#       'id': 15438913,
#       'id_str': '15438913',
#       'indices': [42, 53]}],
#     'urls': [{'url': 'https://t.co/4ZQzSBIOvh',
#       'expanded_url': 'https://www.dailymail.co.uk/news/article-8608059/Drinkers-pack-pubs-clubs-day-beaches-wheres-social-distancing.html?ito=amp_twitter_share-top',
#       'display_url': 'dailymail.co.uk/news/article-8…',
#       'indices': [18, 41]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twinybots.com" rel="nofollow">TwinyBots</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1168192787990425600,
#     'id_str': '1168192787990425600',
#     'name': 'Hackingdom',
#     'screen_name': 'Hackingdom_io',
#     'location': 'Bordeaux',
#     'description': 'The Kingdom of Hacking !\n\n#EthicalHacking #CyberSecurity #Programming #RedTeam #CTF #IA #IoT #BigData #SocialEngineering #Profiling #Cryptography #Privacy',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 844,
#     'friends_count': 475,
#     'listed_count': 24,
#     'created_at': 'Sun Sep 01 16:04:10 +0000 2019',
#     'favourites_count': 27595,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 19853,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1169982621054623744/P6_xoN3J_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1169982621054623744/P6_xoN3J_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1168192787990425600/1567846543',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 08:28:45 +0000 2020',
#     'id': 1292377263518842880,
#     'id_str': '1292377263518842880',
#     'text': 'https://t.co/4ZQzSBIOvh @MailOnline\n\nCrowded bars R most dangers, spreading #Covid19,\nthan #flights\n\n#bigdata… https://t.co/N3O33t7DPW',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Covid19', 'indices': [76, 84]},
#       {'text': 'flights', 'indices': [91, 99]},
#       {'text': 'bigdata', 'indices': [101, 109]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'MailOnline',
#        'name': 'Daily Mail Online',
#        'id': 15438913,
#        'id_str': '15438913',
#        'indices': [24, 35]}],
#      'urls': [{'url': 'https://t.co/4ZQzSBIOvh',
#        'expanded_url': 'https://www.dailymail.co.uk/news/article-8608059/Drinkers-pack-pubs-clubs-day-beaches-wheres-social-distancing.html?ito=amp_twitter_share-top',
#        'display_url': 'dailymail.co.uk/news/article-8…',
#        'indices': [0, 23]},
#       {'url': 'https://t.co/N3O33t7DPW',
#        'expanded_url': 'https://twitter.com/i/web/status/1292377263518842880',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [111, 134]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 737142202481016832,
#      'id_str': '737142202481016832',
#      'name': 'Chidambara .ML.',
#      'screen_name': 'chidambara09',
#      'location': 'Mysore  and  BERLIN',
#      'description': 'Be happy  Be healthy Be smile Be cool Be good human',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 7123,
#      'friends_count': 13,
#      'listed_count': 4427,
#      'created_at': 'Mon May 30 04:42:51 +0000 2016',
#      'favourites_count': 193,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 1099614,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/760774125522518016/jhzjWv0i_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/760774125522518016/jhzjWv0i_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/737142202481016832/1538216794',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 16,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 16,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:51:59 +0000 2020',
#    'id': 1292383112110972928,
#    'id_str': '1292383112110972928',
#    'text': 'RT @KirkDBorne: Here are some of my favorite books &amp; things: https://t.co/fmHsJvad9P\n...covering #BigData #DataScience #AI #Bots #MachineLe…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'BigData', 'indices': [101, 109]},
#      {'text': 'DataScience', 'indices': [110, 122]},
#      {'text': 'AI', 'indices': [123, 126]},
#      {'text': 'Bots', 'indices': [127, 132]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'KirkDBorne',
#       'name': 'Kirk Borne',
#       'id': 534563976,
#       'id_str': '534563976',
#       'indices': [3, 14]}],
#     'urls': [{'url': 'https://t.co/fmHsJvad9P',
#       'expanded_url': 'https://bit.ly/2WcVqzo',
#       'display_url': 'bit.ly/2WcVqzo',
#       'indices': [65, 88]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 268923375,
#     'id_str': '268923375',
#     'name': 'Osala Eric',
#     'screen_name': 'ombishe',
#     'location': 'KENYA',
#     'description': '#Team Arsenal \n#God Fearing \n#technophile \n#technology for better life\n#child of God \n#Data evangelist\n#father \n#husband',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 540,
#     'friends_count': 3114,
#     'listed_count': 228,
#     'created_at': 'Sat Mar 19 19:05:19 +0000 2011',
#     'favourites_count': 5372,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 8335,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '131516',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/689724087220989952/6UDbzkJB_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/689724087220989952/6UDbzkJB_normal.jpg',
#     'profile_link_color': '009999',
#     'profile_sidebar_border_color': 'EEEEEE',
#     'profile_sidebar_fill_color': 'EFEFEF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 05:02:35 +0000 2020',
#     'id': 1292325381295558656,
#     'id_str': '1292325381295558656',
#     'text': 'Here are some of my favorite books &amp; things: https://t.co/fmHsJvad9P\n...covering #BigData #DataScience #AI #Bots… https://t.co/cC8QR8yNh9',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'BigData', 'indices': [85, 93]},
#       {'text': 'DataScience', 'indices': [94, 106]},
#       {'text': 'AI', 'indices': [107, 110]},
#       {'text': 'Bots', 'indices': [111, 116]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/fmHsJvad9P',
#        'expanded_url': 'https://bit.ly/2WcVqzo',
#        'display_url': 'bit.ly/2WcVqzo',
#        'indices': [49, 72]},
#       {'url': 'https://t.co/cC8QR8yNh9',
#        'expanded_url': 'https://twitter.com/i/web/status/1292325381295558656',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [118, 141]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 534563976,
#      'id_str': '534563976',
#      'name': 'Kirk Borne',
#      'screen_name': 'KirkDBorne',
#      'location': 'Maryland, USA',
#      'description': 'Principal Data Scientist @BoozAllen. Global Speaker. Top #BigData #DataScience #AI Influencer. PhD Astrophysicist. (Views = my own) https://t.co/abP8DkYJY2 📊🔭',
#      'url': 'https://t.co/tWlmeuTlR7',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/tWlmeuTlR7',
#          'expanded_url': 'http://www.linkedin.com/in/kirkdborne',
#          'display_url': 'linkedin.com/in/kirkdborne',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/abP8DkYJY2',
#          'expanded_url': 'http://rocketdatascience.org',
#          'display_url': 'rocketdatascience.org',
#          'indices': [132, 155]}]}},
#      'protected': False,
#      'followers_count': 265299,
#      'friends_count': 10880,
#      'listed_count': 8072,
#      'created_at': 'Fri Mar 23 16:35:17 +0000 2012',
#      'favourites_count': 203868,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 122621,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/534563976/1590790599',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 69,
#     'favorite_count': 146,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 69,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:51:36 +0000 2020',
#    'id': 1292383013666541568,
#    'id_str': '1292383013666541568',
#    'text': 'RT @realColinMac: 🔰Drinking game for #WebDeveloper\'s\n\n1. Think of a noun\n2. Google "&lt;noun&gt;.js"\n3. If a library with that name exists - take…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'WebDeveloper', 'indices': [37, 50]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'realColinMac',
#       'name': 'Colin McGuire',
#       'id': 892214142672683008,
#       'id_str': '892214142672683008',
#       'indices': [3, 16]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://wisestme.github.io/wisest_portfolio/" rel="nofollow">BMannretweetBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1198296228997607424,
#     'id_str': '1198296228997607424',
#     'name': 'CodeNewbie',
#     'screen_name': 'newbie_codes',
#     'location': '',
#     'description': 'What folks are saying about the newbies',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 199,
#     'friends_count': 0,
#     'listed_count': 7,
#     'created_at': 'Sat Nov 23 17:44:31 +0000 2019',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 12215,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1261223717612503042/m2OlkSQl_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261223717612503042/m2OlkSQl_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1198296228997607424/1589534143',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 08:35:53 +0000 2020',
#     'id': 1292379058274045952,
#     'id_str': '1292379058274045952',
#     'text': '🔰Drinking game for #WebDeveloper\'s\n\n1. Think of a noun\n2. Google "&lt;noun&gt;.js"\n3. If a library with that name exists… https://t.co/9oZcIVIIfW',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'WebDeveloper', 'indices': [19, 32]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/9oZcIVIIfW',
#        'expanded_url': 'https://twitter.com/i/web/status/1292379058274045952',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [122, 145]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 892214142672683008,
#      'id_str': '892214142672683008',
#      'name': 'Colin McGuire',
#      'screen_name': 'realColinMac',
#      'location': 'Canada, mainly #YXE #YEG',
#      'description': '💡Entrepreneur/💵 Investor - 🇨🇦 #TechEvangelist - #Futurist -\n- Foodie - Animal lover 🐈 🐕 #cdntech #AI #AR #VR #VC #Startup',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 13152,
#      'friends_count': 7917,
#      'listed_count': 148,
#      'created_at': 'Tue Aug 01 02:43:22 +0000 2017',
#      'favourites_count': 84324,
#      'utc_offset': None,
# ...
#      'id_str': '156639865',
#      'name': "Bibliothèque des Sciences et de l'Industrie",
#      'screen_name': 'bibliothequeBSI',
#      'location': 'Cité des sciences - Paris',
#      'description': "Bibliothèque de la Cité des #sciences et de l'industrie à La Villette #Paris.\nNous sommes ouverts !\n#Science #Techniques #Numérique #Lecture",
#      'url': 'https://t.co/PN4GwEHt0p',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/PN4GwEHt0p',
#          'expanded_url': 'http://www.cite-sciences.fr/bibliotheque',
#          'display_url': 'cite-sciences.fr/bibliotheque',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 4333,
#      'friends_count': 2619,
#      'listed_count': 299,
#      'created_at': 'Thu Jun 17 13:46:36 +0000 2010',
#      'favourites_count': 10898,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 5014,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/938069768892043270/sWp7279U_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/938069768892043270/sWp7279U_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/156639865/1596706849',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'fr'},
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'fr'},
#   {'created_at': 'Sun Aug 09 08:46:22 +0000 2020',
#    'id': 1292381694994059268,
#    'id_str': '1292381694994059268',
#    'text': 'RT @PavansaiT22: Deep learning models deployment in edge devices\n#DataScience\n#MachineLearning\n#DeepLearning\n#TensorFlow\n#PyTorch\n#Python\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DataScience', 'indices': [65, 77]},
#      {'text': 'MachineLearning', 'indices': [78, 94]},
#      {'text': 'DeepLearning', 'indices': [95, 108]},
#      {'text': 'TensorFlow', 'indices': [109, 120]},
#      {'text': 'PyTorch', 'indices': [121, 129]},
#      {'text': 'Python', 'indices': [130, 137]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'PavansaiT22',
#       'name': 'PAVANSAI.T22',
#       'id': 1288347202947973120,
#       'id_str': '1288347202947973120',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://hubofco.de" rel="nofollow">hubofml</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3040871649,
#     'id_str': '3040871649',
#     'name': 'HubofMachineLearning',
#     'screen_name': 'hubofml',
#     'location': 'Germany ',
#     'description': "Once a month, you'll get a newsletter from me with lots of exciting stuff on data science, engineering, and machine learning. Subscribe here 👉 https://t.co/VRnN9grEfw",
#     'url': 'https://t.co/VRnN9grEfw',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/VRnN9grEfw',
#         'expanded_url': 'http://bit.ly/hubofml1',
#         'display_url': 'bit.ly/hubofml1',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/VRnN9grEfw',
#         'expanded_url': 'http://bit.ly/hubofml1',
#         'display_url': 'bit.ly/hubofml1',
#         'indices': [143, 166]}]}},
#     'protected': False,
#     'followers_count': 5061,
#     'friends_count': 10,
#     'listed_count': 125,
#     'created_at': 'Mon Feb 16 15:33:55 +0000 2015',
#     'favourites_count': 31995,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 210905,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1254334743333818373/F3xeh1db_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1254334743333818373/F3xeh1db_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3040871649/1587892795',
#     'profile_link_color': '4A913C',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 07:59:01 +0000 2020',
#     'id': 1292369780104548353,
#     'id_str': '1292369780104548353',
#     'text': 'Deep learning models deployment in edge devices\n#DataScience\n#MachineLearning\n#DeepLearning\n#TensorFlow\n#PyTorch… https://t.co/0Tjy1DAC6P',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'DataScience', 'indices': [48, 60]},
#       {'text': 'MachineLearning', 'indices': [61, 77]},
#       {'text': 'DeepLearning', 'indices': [78, 91]},
#       {'text': 'TensorFlow', 'indices': [92, 103]},
#       {'text': 'PyTorch', 'indices': [104, 112]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/0Tjy1DAC6P',
#        'expanded_url': 'https://twitter.com/i/web/status/1292369780104548353',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [114, 137]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1288347202947973120,
#      'id_str': '1288347202947973120',
#      'name': 'PAVANSAI.T22',
#      'screen_name': 'PavansaiT22',
#      'location': '',
#      'description': 'data science enthusiast searching for opportunity in data science',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 15,
#      'friends_count': 476,
#      'listed_count': 0,
#      'created_at': 'Wed Jul 29 05:35:03 +0000 2020',
#      'favourites_count': 5,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 9,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1288348240916525058/8-KHqV9I_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1288348240916525058/8-KHqV9I_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 6,
#     'favorite_count': 3,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 6,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Sun Aug 09 08:46:16 +0000 2020',
#    'id': 1292381670071566336,
#    'id_str': '1292381670071566336',
#    'text': 'RT @PavansaiT22: Deep learning models deployment in edge devices\n#DataScience\n#MachineLearning\n#DeepLearning\n#TensorFlow\n#PyTorch\n#Python\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DataScience', 'indices': [65, 77]},
#      {'text': 'MachineLearning', 'indices': [78, 94]},
#      {'text': 'DeepLearning', 'indices': [95, 108]},
#      {'text': 'TensorFlow', 'indices': [109, 120]},
#      {'text': 'PyTorch', 'indices': [121, 129]},
#      {'text': 'Python', 'indices': [130, 137]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'PavansaiT22',
#       'name': 'PAVANSAI.T22',
#       'id': 1288347202947973120,
#       'id_str': '1288347202947973120',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1267176842856927233,
#     'id_str': '1267176842856927233',
#     'name': 'DevelopersDiscussion.com',
#     'screen_name': 'developersbot',
#     'location': 'AWS Server',
#     'description': 'I serve as a motivator to programmers 👨\u200d💻@engg_rky programmed me in #NodeJS. I’m working 24x7 & now hungry, please feed me your FOLLOW 👍 otherwise I’ll DIE💀',
#     'url': 'https://t.co/NOHw97tGNh',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/NOHw97tGNh',
#         'expanded_url': 'http://DevelopersDiscussion.com',
#         'display_url': 'DevelopersDiscussion.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1298,
#     'friends_count': 1,
#     'listed_count': 38,
#     'created_at': 'Sun May 31 19:31:30 +0000 2020',
#     'favourites_count': 15,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 85930,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1267185513338986501/0WQgGUHP_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1267185513338986501/0WQgGUHP_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1267176842856927233/1591022277',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sun Aug 09 07:59:01 +0000 2020',
#     'id': 1292369780104548353,
#     'id_str': '1292369780104548353',
#     'text': 'Deep learning models deployment in edge devices\n#DataScience\n#MachineLearning\n#DeepLearning\n#TensorFlow\n#PyTorch… https://t.co/0Tjy1DAC6P',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'DataScience', 'indices': [48, 60]},
#       {'text': 'MachineLearning', 'indices': [61, 77]},
#       {'text': 'DeepLearning', 'indices': [78, 91]},
#       {'text': 'TensorFlow', 'indices': [92, 103]},
#       {'text': 'PyTorch', 'indices': [104, 112]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/0Tjy1DAC6P',
#        'expanded_url': 'https://twitter.com/i/web/status/1292369780104548353',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [114, 137]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1288347202947973120,
#      'id_str': '1288347202947973120',
#      'name': 'PAVANSAI.T22',
#      'screen_name': 'PavansaiT22',
#      'location': '',
#      'description': 'data science enthusiast searching for opportunity in data science',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 15,
#      'friends_count': 476,
#      'listed_count': 0,
#      'created_at': 'Wed Jul 29 05:35:03 +0000 2020',
#      'favourites_count': 5,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 9,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1288348240916525058/8-KHqV9I_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1288348240916525058/8-KHqV9I_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 6,
#     'favorite_count': 3,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 6,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.116,
#   'max_id': 1292383660604358657,
#   'max_id_str': '1292383660604358657',
#   'next_results': '?max_id=1292381670071566335&q=%23DataScience&count=50&include_entities=1',
#   'query': '%23DataScience',
#   'refresh_url': '?since_id=1292383660604358657&q=%23DataScience&include_entities=1',
#   'count': 50,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
def get_followers(screen_name, keys=['name', 'followers_count', 'friends_count', 'screen_name'], to_df=False):
    screen_name=screen_name.strip('@')
    url =f'https://api.twitter.com/1.1/followers/list.json?screen_name={screen_name}'
    results=requests.get(url,auth=auth).json()['users']
    
#    dict_users={}
#    dict_users ={
#        'Name': [user['name'] for user in results],
#        'followers_count': [user['followers_count'] for user in results],
#        'friends_count': [user['friends_count'] for user in results],
#        'screen_name': [user['screen_name'] for user in results],      
 #   }
    
    dict_users={}
    for i in keys:
        dict_users[i] = [user[i] for user in results]
    

    if to_df:
        import pandas as pd
        usersdf = pd.DataFrame(dict_users)
#        d_df=pd.DataFrame(d)
        return usersdf
    
    return results

# %%
get_followers('GA',  to_df=True)
# Out:
#                              name  followers_count  friends_count  \
# 0                           Игорб             1686            755
# 1                     karly smith                1             25
# 2                     German Diaz              112            727
# 3                       Elizabeth                2             34
# 4                HURPSY IMAGERY 📸              249           2511
# 5         Denise Bagans 🧛‍♀️🧡🧛‍♂️               64            165
# 6                     WeDiversify                7            102
# 7                           Priya              429           1062
# 8                Principe Cabrera                5            127
# 9             Cameron Baumgartner              229            543
# 10                elizabeth paier              158           1161
# 11                    Usman Saeed               69           2354
# 12  Slider - The Startup Showcase               11            301
# 13                   Mayola Tyler                0             11
# 14                          Elias                1             39
# 15                 Marco Ogliengo               80            113
# 16                          gluix               51            527
# 17               Crypto Cantabria              204            785
# 18                 Ali Khayrallah               87           1334
# 19                Queen 👸 Tiffany                6            210
#
#         screen_name
# 0   huipizdayebatsy
# 1        karlymsdev
# 2          gdiaz324
# 3     puffdivastarr
# 4        hurpsy4eva
# 5      BagansDenise
# 6     WeDiversifyMe
# 7      PriyaKour007
# 8   PrincipeCabrera
# 9        cameronhbg
# 10   ElizabethPaier
# 11    musmansaeed38
# 12    StartupSlider
# 13     tyler_mayola
# 14    Elias60960250
# 15        mogliengo
# 16           gluix1
# 17  CryptoCantabria
# 18            alisk
# 19  QueenTi62831950

# %% [markdown]
# ## Section 4: Functions

# %% [markdown]
# This section details the functions you have to write and turn in as part of your homework assignment.
#
# Please read the requirements carefully.
#
# **What you'll turn in:** A `.py` file with all of the functions written.  We should be able to load this into an IDE, run the file, and then call your functions to verify how and if they work. This file should also be properly commented so we can follow your line of reasoning.
#
# The functions you'll be prompted to write will be defined in the following ways:
#
#  - **name:** the name of the function
#  - **returns:** what the function should return
#  - **arguments:** arguments to include inside the function in order to specify how it should behave.
#
#  **Note:** The free API has limitations built into it, so this means from time-to-time you'll only be able to return some of the results from the API.  This is fine.  It's understood and recognized that your functions won't be able to return an entire list of someone's users or other such things, so as long as your work delivers the best it can under present circumstances you'll be in good shape.
#
#  **Other Note:** Every aspect of the API that you need to use can be found on either of these pages.
#
#  Search API:  https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets
#
#  Users API: https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/api-reference
#
# **Remarks About Your Final Work**
#
#  - It's okay if you get stuck somewhere.  If there's one item that you can't figure out and it doesn't quite work right, it's probably best to move on and try other things.  Again, try and explain what you were looking to do.  You'll pass if you give an honest effort.
#  - There's potentially a lot of error handling you could do to verify user input is correct, but you can leave that alone for now.  Just make sure the core purpose of the function works the way it's supposed to.
#  - While you're working on this, it's possible you may bump into your API limits.  Keep this in mind if you have a function that's working, but 45 minutes later it doesn't and you haven't changed anything.  This usually means the data you're getting back from your API calls isn't what it's supposed to be because you've exhausted your limits. We won't hold you to double checking for all of this in your functions.
#  - In the file you turn in, make sure your requests are referencing your API tokens, so that way we can run your file right away.  Ie, make sure somewhere in your script you have a variable at the top that reads `tokens = OAuth1('token1', 'token2', 'token3', 'token4')` so it can be used for your requests inside the file.

# %% [markdown]
# ##### Function 1 (Required)

# %% [markdown]
# **Name:** `find_user`
#
# **Returns:** dictionary that represents user object returned by Twitter's API
#
# **Arguments:**
#  - `screen_name`: str, required; Twitter handle to search for.  **Can include the @ symbol.  The function should check for this and remove it if necessary.**
#  - `keys`: list, optional; list that contains keys to return about user object.  If not specified, then function should return the entire user object.  **These only need to be outer keys.** If they are keys nested within another key, you don't have to account for this.
#
# **To test:** We'll test your function in the following ways:
#
#  - `find_user('@GA')`
#  - `find_user('GA')`
#  - `find_user('GA', keys=['name', 'screen_name', 'followers_count', 'friends_count'])`

# %% [markdown]
# ##### Function 2 (Required)

# %% [markdown]
# **Name:** `find_hashtag`
#
# **Returns:** list of data objects that contain information about each tweet that matches the hashtag provided as input.
#
# **Arguments:**
#  - `hashtag`: str, required; text to use as a hashtag search.
#  - `count`: int, optional; number of results to return
#  - `search_type`: str, optional; type of results to return.  should accept 3 different values:
#    - `mixed`:   return mix of most recent and most popular results
#    - `recent`:  return most recent results
#    - `popular`: return most popular results
#
# **Note:** User should **not** have to actually use the `#` character for the `hashtag` argument.  The function should check to see if it's there, and if not, add it in for them.
#
# **To Test:**  We'll check your function in the following ways:
#  - `find_hashtag('DataScience')`
#  - `find_hashtag('#DataScience')`
#  - `find_hashtag('#DataScience', count=100)`, and double check the length of the `statuses` key to make sure it contains the right amount of results.  **Note:** Due to the version of the API we're using, the number of results returned will **not** necessarily match the value passed into the `count` parameter.  So if you specify 50 and it only returns 45, you are likely still doing it correctly.
#  - `find_hashtag('#DataScience', search_type='recent/mixed/popular')`

# %% [markdown]
# ##### Function 3 (Required)

# %% [markdown]
# **Name:** `get_followers`
#
# **Returns:** list of data objects for each of the users followers, returning values for the `name`, `followers_count`, `friends_count`, and `screen_name` key for each user.
#
# **Arguments:**
#
#  - `screen_name`: str, required; Twitter handle to search for.  **Results should not depend on user inputting the @ symbol.**
#  - `keys`: list, required;  keys to return for each user.  default value: [`name`, `followers_count`, `friends_count`, `screen_name`]; if something else is listed, values for those keys should be returned
#  - `to_df`: bool, required; default value: False; if True, return results in a dataframe.  Every value provided in the `keys` argument should be its own column, with rows populated by the corresponding values for each one for every user.
#
# **To Test:** We'll test your functions in the following ways:
#
#  - `get_followers('@GA')`
#  - `get_followers('GA')`
#  - `get_followers('GA', keys=['name', 'followers_count'])`
#  - `get_followers('GA', keys=['name', 'followers_count'], to_df=True)`
#  - `get_followers('GA', to_df=True)`

# %% [markdown]
# ##### Function 4 (Optional)

# %% [markdown]
# **Name:** `friends_of_friends`
#
# **Returns:** list of data objects for each user that two Twitter users have in common
#
# **Arguments:**
#
#  - `names`: list, required; list of two Twitter users to compare friends list with
#  - `keys`: list, optional; list of keys to return for information about each user.  Default value should be to return the entire data object.
#  - `to_df`: bool, required; default value: False; if True, returns results in a dataframe.
#
# **To Test:** We'll test your function in the following ways:
#
#  - `friends_of_friends(['Beyonce', 'MariahCarey'])`
#  - `friends_of_friends(['@Beyonce', '@MariahCarey'], to_df=True)`
#  - `friends_of_friends(['Beyonce', 'MariahCarey'], keys=['id', 'name'])`
#  - `friends_of_friends(['Beyonce', 'MariahCarey'], keys=['id', 'name'], to_df=True)`
#
# Each of these should return 3 results. (Assuming they haven't followed the same people since this was last written).
#
# **Hint:** The `id` key is the unique identifier for someone, so if you want to check if two people are the same this is the best way to do it.

# %%
def friends_of_friends(name1, name2, keys=None, to_df=False):
    url =f'https://api.twitter.com/1.1/friends/list.json?screen_name={name1}&count=200'
    results1=requests.get(url,auth=auth).json()['users']
    url =f'https://api.twitter.com/1.1/friends/list.json?screen_name={name2}&count=200'
    results2=requests.get(url,auth=auth).json()['users']
    
    results2_id=[item['id'] for item in results2]
    print(len(results2_id))
    listfriends=[]
#    for item in results1:
#        if item in results2:
#            listfriends.append(item)
#    print(len(listfriends))
#    return listfriends
#new_dict = {item['name']:item for item in data}
  #  listfriends=[item for item in results1 if item in results2]
    listfriends=[item for item in results1 if item['id'] in results2_id]
    
    print(len(listfriends))
    
    results_dict={}
    if keys !=None:
        for i in keys:
            results_dict[i] = [user[i] for user in listfriends]
    else:
        for k,v in [(key,d[key]) for d in listfriends for key in d]:
            if k not in results_dict: 
                results_dict[k]=[v]
            else: 
                results_dict[k].append(v)
        
    #    return results_keys
    #    print(type(results_keys))
   
   
    if to_df:
        import pandas as pd
        friendsdf = pd.DataFrame(results_dict)
        return friendsdf
    else:
        return results1

# %%
friends_of_friends('Beyonce', 'MariahCarey', to_df=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-d71b0a5aa9aa> in <module>
# ----> 1 friends_of_friends('Beyonce', 'MariahCarey', to_df=True)
#
# <ipython-input-10-6b503b86f2a8> in friends_of_friends(name1, name2, keys, to_df)
#       1 def friends_of_friends(name1, name2, keys=None, to_df=False):
#       2     url =f'https://api.twitter.com/1.1/friends/list.json?screen_name={name1}&count=200'
# ----> 3     results1=requests.get(url,auth=auth).json()['users']
#       4     url =f'https://api.twitter.com/1.1/friends/list.json?screen_name={name2}&count=200'
#       5     results2=requests.get(url,auth=auth).json()['users']
#
# KeyError: 'users'

# %%
friends_of_friends('MariahCarey', keys=['name'] )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-158-e569c9275ee4> in <module>
# ----> 1 friends_of_friends('MariahCarey', keys=['name'] )
#
# TypeError: friends_of_friends() missing 1 required positional argument: 'name2'

# %% [markdown]
#  ##### Function 5 (Optional)

# %% [markdown]
# Rewrite the `friends_of_friends` function, except this time include an argument called `full_search`, which accepts a boolean value.  If set to `True`, use cursoring to cycle through the complete set of users for the users provided.
#
# The twitter API only returns a subset of users in your results to save bandwidth, so you have to cycle through multiple result sets to get all of the values.
#
# You can read more about how this works here:  https://developer.twitter.com/en/docs/basics/cursoring
#
# Basically you have to do a `while` loop to continually make a new request using the values stored in the `next_cursor` key as part of your next query string until there's nothing left to search.
#
# **Note:** We're using the free API, so we're operating under some limitations.  One of them being that you can only make 15 API calls in a 15 minute span to this portion of the API.  You can also only return up to 200 results per cursor, so this means you won't be able to completely search for everyone even if you set this up correctly.
#
# That's fine, just do what you can under the circumstances.
#
# **To Test:** To test your function, we'll run the following function calls:
#
#  - `friends_of_friends(['ezraklein', 'tylercowen'])` -- should return 4 results if you do an API call that returns 200 results
#  - `friends_of_friends(['ezraklein', 'tylercowen'], full_search=True)` -- should return 54 results if you do an API call that returns 200 results
#
# **Hint:** Chances are you will exhaust your API limits quite easily in this function depending on who you search for.  Depending on how you have things set up, this could cause error messages to arise when things are otherwise fine.  Remember in class 3 when we were getting those weird dictionaries back because our limits were used up?  We won't hold you accountable for handling this inside your function, although it could make some things easier for your own testing.
#
# Good luck!

# %%
#Function searches friends of two Twitter users and returns list of data objects for the friends in common
def friends_of_friends(names, keys=None, to_df=False, full_search=False):

    for item in names:  #loop through the names in the input list and create a list with the request outputs
        url =f'https://api.twitter.com/1.1/friends/list.json?screen_name={item}&count=200'
        list_users.append(requests.get(url,auth=auth).json()['users'])
        
#split the list into two lists, one for each user
    results1=list_users[0]
    results2=list_users[1]

#check the items in the two lists that have the same 'id' and append to a new list
    listfriends=[]
    listfriends=[item for item in results1 if item['id'] in [n['id'] for n in results2]]
    print(len(listfriends))

#create dictionary using keys if passed in the function arguments or all the keys available if not used as input
    results_dict={}
    if keys !=None:
        for i in keys:
            results_dict[i] = [user[i] for user in listfriends]
    else:
        for k,v in [(key,d[key]) for d in listfriends for key in d]:
            if k not in results_dict: 
                results_dict[k]=[v]
            else: 
                results_dict[k].append(v)
#build a table (pandas data frame from the dictionary) if to_df is True
    if to_df:
        import pandas as pd
        friendsdf = pd.DataFrame(results_dict)
        return friendsdf
    else:
        return results1

# %%
#Function searches friends of two Twitter users and returns list of data objects for the friends in common
def friends(user, keys=None, to_df=False, full_search=False): 
    url =f'https://api.twitter.com/1.1/friends/list.json?screen_name={user}'
    results=requests.get(url,auth=auth).json()
    nextcursor=results['next_cursor']
   # print(nextcursor)
    
    if full_search:
        list_results=[]
        i=1
        for i in range(1,5):
        #while nextcursor !=0:
            url =f'https://api.twitter.com/1.1/friends/list.json?screen_name={user}&cursor={nextcursor}'
            results_int=requests.get(url,auth=auth).json()
            #list_results.append(requests.get(url,auth=auth).json())
            nextcursor=results_int['next_cursor']
            print(nextcursor)
            i+=1
        return results_int
    else:
        return results
    #return results

# %%
friends('MariahCarey', full_search=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-8a46d1e5b416> in <module>
# ----> 1 friends('MariahCarey', full_search=True)
#
# <ipython-input-12-992857e6e3ed> in friends(user, keys, to_df, full_search)
#       3     url =f'https://api.twitter.com/1.1/friends/list.json?screen_name={user}'
#       4     results=requests.get(url,auth=auth).json()
# ----> 5     nextcursor=results['next_cursor']
#       6    # print(nextcursor)
#       7
#
# KeyError: 'next_cursor'

# %%
def friends(user, keys=None, to_df=False, full_search=False): 
    url =f'https://api.twitter.com/1.1/friends/list.json?screen_name={user}'
    results=requests.get(url,auth=auth).json()
    nextcursor=results['next_cursor']
    print(nextcursor)
    
    if full_search:
        list_results=[]
       # i=1
        #for i in range(1,5):
        while nextcursor !=0:
            url =f'https://api.twitter.com/1.1/friends/list.json?screen_name={user}&cursor={nextcursor}'
            results_int=requests.get(url,auth=auth).json()
            list_results.append(results_int)
            nextcursor=results_int['next_cursor']
            print(nextcursor)
         
        return list_results
    else:
        return results

# %%
friends('MariahCarey', full_search=True)
# Out:
# 1644509744268087944
# 1636070215752200670
# 1621056923412275992
# 1613951663879374420
# 1518224439813049412
# 1439653401947108330
# 1364006135987682268
# 1306591519310498875
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-8a46d1e5b416> in <module>
# ----> 1 friends('MariahCarey', full_search=True)
#
# <ipython-input-7-3830001fccb3> in friends(user, keys, to_df, full_search)
#      13             results_int=requests.get(url,auth=auth).json()
#      14             list_results.append(results_int)
# ---> 15             nextcursor=results_int['next_cursor']
#      16             print(nextcursor)
#      17
#
# KeyError: 'next_cursor'
